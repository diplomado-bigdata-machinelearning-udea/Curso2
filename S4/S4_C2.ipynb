# %% [markdown]
# <p><img alt="Colaboratory logo" height="140px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <h1> Diplomado de Análisis de datos y Machine Learning en Python</h1>
#
#
# El presente diplomado hace parte del centro de Big Data de la facultad de ciencias exactas y naturales (FCEN) de la Universidad de Antioquia.

# %% [markdown]
# Empecemos por usar la versión 2 de de tensor flow:

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ## 1. Problema del desvanecimiento/explosión del gradiente.
#
# Como hemos visto, las redes neuronales son entrenadas usando el algoritmo del **descenso del gradiente estocástico** (hasta ahora) conjuntamente con el de **propagación hacia atrás** (o retropropagación).
#
# Lo anterior consiste, en primer lugar, en el cálculo del error de la predicción realizada por el modelo y el uso de este error para estimar un gradiente que es usado para actualizar cada peso en la red, de tal forma que se reduzca el error en la siguiente iteración. Este error del gradiente es propagado hacia atrás a lo largo de la red, desde la salida a la capa de entrada.
#
# Normalmente, se desea entrenar la red neuronal con muchas capas, con la intensión de que el incremento del número de capas aumente la capacidad predictiva de la red, haciéndola capaz de aprender un dataset de gran tamaño. Por otra parte, se espera también que al aumentar el número de capas se logre representar de forma eficiente funciones de mapeo más complejas de los datos de entrada a las predicciones a la salida de la red.
#
# Un problema en el entrenamiento de redes con muchas capas, **deep neural networks**, es que el gradiente se **desvanece o explota** dramáticamente a medida que se propaga hacia atrás a lo largo de la red. En el caso del desvanecimiento del gradiente, la actualización del error alcanzado en las capas cercanas a la entrada puede ser tan pequeño que tenga un efecto despreciable. El desvanecimiento del gradiente dificulta saber en qué dirección se deben variar los parámetros para obtener una mejora en la función de coste.
#
# El término del **desvanecimiento/explosión** del gradiente se refiera al hecho de que en un red neuronal alimentada hacia adelante el error retropropagado normalmente decrece (o incrementa) en función de la distancia desde la capa final.
#
# Además del problema de desvanecimiento, el error del gradiente puede ser inestable en redes neuronales profundas, sufriendo cambios abruptos o explosiones (divergencias), en donde el gradiente crece exponencialmente a medida que se propaga hacia atrás. Este problema se conce como problema del gradiente explosivo:
#
# El problema de los gradientes que se desvanecen es un problema particular en las redes neuronales recurrentes, ya que la actualización de la red implica “desenrrollar” la red, creando una red muy profunda que requiere la actualización de los pesos. Una red neuronal recurrente modesta puede tener entre 200 a 400 pasos de tiempo de entrada, lo que resulta conceptualmente en una red muy profunda.
#
# El problema de los gradientes que se desvanecen se puede manifestar en un perceptrón multicapas mediante una rata baja de la mejora del modelo durante el entrenamiento, y, quizas, en una convergencia temprana, es decir, el entrenamiento continuo no implica una mejora de la precisión del modelo. La inspección de los cambios de los pesos durante el entrenamiento, nos debería llevar a mayores cambios (que implica un mayor aprendizaje) en las capas cercanas a la salida  y cambios menores en las capas para cada paso de tiempo de entrada.
#
# Existen varias técnicas que pueden ser usadas para reducir el impacto de los gradientes que se desvanecen en el caso de redes neuronales alimentadas hacia adelante, los más notables de ellos son :
#
# -	Los esquema de inicialización de pesos alternantes.
# -	El uso de funciones de activación alternativas.
#
# Se han estudiado diferentes aproximaciones para el entrenamiento de redes neuronales profundas (tanto para redes alimentadas hacia adelante como las recurrentes), en un esfuerzo para abordar los gradientes que se desvanecen, como el pre-entrenamiento, una mejora en el escalado aleatorio inicial, las mejoras en los métodos de optimización, el estudio de arquitecturas específicas, las inicializaciones ortogonales, etc.
#
# En esta sección echaremos una mirada más cerca al uso de funciones de activación y esquemás alternativos de inicialización de los pesos, para poder entrenar redes neuronales más profundas.

# %% [markdown]
# ## Problema inducido por la funciones de activación:
#
# Como vimos en la clase anterior, el algoritmo de retropropagación requiere de las derivadas de las funciones de activación, lo que implica que algunas de ellas favorecen el desvanecimento del gradiente.
#
# Veamos que ocurre con las derivadas de las funciones de activación usadas en las capas ocultas.

# %% [markdown]
# ### Función sigmoide:
#
# La función sigmoide se define de la forma
#
# $$S(x)=\frac{1}{1+e^{-x}}$$
#
# en donde la gráfica tiene la siguiente forma:

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
  return 1/(1+np.exp(-x))

x = np.linspace(-10,10,100)

plt.plot(x,sigmoid(x),'-')

# %% [markdown]
# La cual tiene un rango definido en el intervalo abierto $(0,1)$.
#
# La derivada de esta función, podemos calcularla como:

# %%
from sympy import *

x = Symbol('x')
f = 1/(1+exp(-x))
f.diff(x)
# Out:
# exp(-x)/(1 + exp(-x))**2

# %%
def sigmoid_deff(x):
  return np.exp(-x)/(1 + np.exp(-x))**2

x = np.linspace(-10,10,100)
plt.plot(x,sigmoid_deff(x),'-')

# %% [markdown]
# Veamos además, que el mapero de la función de activación **sigmoide** genera una concentración en las colas de la función, en donde la derivada se hace cero:

# %%
import tensorflow as tf
from tensorflow import keras

x=np.linspace(-5,5,100)

y_sigmoid = keras.activations.sigmoid(x)

y_sigmoid_diff = np.gradient(y_sigmoid)

plt.figure(figsize=(14,5))

plt.subplot(121)
plt.plot(x,y_sigmoid,'.')
plt.title('Función de Activación sigmoide')
plt.subplot(122)
plt.plot(x,y_sigmoid_diff,'.')
plt.title('Derivada de la función de Activación sigmoide')
# Out:
# Text(0.5, 1.0, 'Derivada de la función de Activación sigmoide')

# %% [markdown]
# **Problemas de la función sigmoide:**
#
# **1) Desvanecimiento del gradiente:** Vemos que la derivada de esta función está muy cerca a cero en todas partes, excepto en el ancho representado por la gaussian. Lo anterior representa el caso a favor del desvanecimiento del gradiente. Por este motivo, la función tangente hiperbólica fue usada en su lugar.
#
# **2) Función no centrada en cero:** La función sigmoide representa una función no centrada en cero, generando valores positivos después de que la activación tenga lugar. Sin entrar en detalles, este hecho ocaciona que el gradiente de los pesos los convierta a todos en positivos o negativos, lo que dificulta la actualización del gradiente, comportándose de forma erratica. A este problema se le conoce como el [problema de funciones no centradas en cero](https://stats.stackexchange.com/questions/237169/why-are-non-zero-centered-activation-functions-a-problem-in-backpropagation).

# %% [markdown]
# #### Función de activación Tanh:
#
# La función de activación tangente hiperbólica se define como:
#
# $$\text{Tanh}(x)=\frac{e^x-​e^{​‑x}}{e^x+​e^{‑x}}$$
#
# cuya gráfica es:

# %%
x = np.linspace(-7,7,100)

plt.plot(x,np.tanh(x),'-')

# %% [markdown]
# Cuyo rango es el intervalo abierto $(-1,1)$.
#
# La derivada de esta función es:

# %%
x = Symbol('x')
f = (exp(x)-exp(-x))/(exp(x)+exp(-x))
f.diff(x)
# Out:
# (-exp(x) + exp(-x))*(exp(x) - exp(-x))/(exp(x) + exp(-x))**2 + 1

# %%
def tanh_diff(x):
  return (-np.exp(x)+np.exp(-x))*(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))**2 + 1

x = np.linspace(-7,7,100)

plt.plot(x,tanh_diff(x),'-')

# %% [markdown]
# Veamos además, que el mapeo de la función de activación la función **tanh** genera una concentración de puntos en las colas de la función, en donde su derivada se hace cero:

# %%
# función tanh
x=np.linspace(-5,5,100)

y_tanh = keras.activations.tanh(x)

#Derivada
y_tanh_diff = np.gradient(y_tanh)

# Gráfica de la función de activación y su derivada:
plt.figure(figsize=(14,5))

plt.subplot(121)
plt.plot(x,y_tanh,'.')
plt.title('Función de Activación Tanh')
plt.subplot(122)
plt.plot(x,y_tanh_diff,'.')
plt.title('Derivada de la función de Activación Tanh')
# Out:
# Text(0.5, 1.0, 'Derivada de la función de Activación Tanh')

# %% [markdown]
# **Problemas de la función de activación tanh**
#
# **1) Desvanecimiento del gradiente:** A pesar de se ha demostrado que el desempeño de la función de activación es mejor, dado su rango $(-1,1)$, la derivada de esta función es muy cercana a cero en todo el dominio, excepto dentro de un intervalo pequeño centrado en el origen y determinado por el ancho de la gaussiana. Problema similar al de la función sigmoide.

# %% [markdown]
# ### Función de activación ReLU:
#
# Con el fin de corregir el problema introduccido por el desvanecimiento del gradiente al usar las funciones de activación **sigmoide** y **tangente hiperbólica**, se introduce la función **ReLU**.
#
# Vemos las características de esta función y su derivada:

# %%
x=np.linspace(-50,50,101)

# Función de activación ReLU
y_relu = keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)

# Derivada de la función de activación ReLU
y_relu_diff = np.gradient(y_relu)

# Gráfica de la función de activación ReLU y su derivada:
plt.figure(figsize=(14,5))

plt.subplot(121)
plt.plot(x,y_relu,'.')
plt.title('Función de Activación ReLU')
plt.subplot(122)
plt.plot(x,y_relu_diff,'.')
plt.title('Derivada de la función de Activación ReLU')
# Out:
# Text(0.5, 1.0, 'Derivada de la función de Activación ReLU')

# %% [markdown]
# **Problemas de la función de activación ReLU**
#
# **1) Dying ReLU:**  El problema principal de la función de activación ReLU está asociaado con el hecho de asignar un valor cero a todos los valores negativos provenientes del ajuste lineal. Decimos que una neurona se encuentra muerta cuando el ajuste arroja valores negativos. Como vemos en la gráfica de la derivada ReLU, ésta es cero en los valores negativos de la función. Una vez que la neurona se vuelve "negativa", es muy poco probable que se recupere, y se convertirá en una neurona muerta. El problema de las neuronas muertas es que corresponenden a unidades inservibles, incapaces de contribuir en la clasificación. A este problema se le conoce con el nombre en inglés de [Dying ReLU](https://medium.com/@danqing/a-practical-guide-to-relu-b83ca804f1f7). Una solución a este problema es aplicar una función de activación conocida como LeakyReLU, la cual puede ser consultada en la referencia anterior y no abordaremos en este módulo.
#
# A pesar de este problema, veremos que la función de activación resuelve el problema del desvanecimiento del gradiente en redes neuronales profundas.

# %% [markdown]
# ### Función de activación SeLU:
#
# A continuación, hablaremos brevemente de la funciones SELU (Scaled Exponencial Linear Units), Las cuales aparecen por primera vez en el siguiente
# [artículo](https://arxiv.org/pdf/1706.02515.pdf).
#
# Para una explicación detallada de la función de activación SELU, pueden consultar la siguiente
# [referencia](https://towardsdatascience.com/gentle-introduction-to-selus-b19943068cd9).
#
# La forma de la función SELU y su derivada es la siguiente:

# %%
x=np.linspace(-20,20,100)

y_selu = keras.activations.selu(x)

y_selu_diff = np.gradient(y_selu)

plt.figure(figsize=(14,5))

plt.subplot(121)
plt.plot(x,y_selu,'.')
plt.title('Función de Activación ReLU')
plt.subplot(122)
plt.plot(x,y_selu_diff,'.')
plt.title('Derivada de la función de Activación ReLU')
# Out:
# Text(0.5, 1.0, 'Derivada de la función de Activación ReLU')

# %% [markdown]
# De esta  gráfica podemos extraer dos características principales de la función de activación SELU:
#
# 1. El lado derecho de la función, es similar a la función de activación ReLU.
#
# 2. El lado izquierdo, parace aproximarse a un gradiente zero, que es justo lo que queriamos evitar. No obstante la función SELU realiza un proceso aparte del control del gradiente conocído como **normalización**.
#
# Respecto a la normalización podemos tener tres casos:
#
# 1. Que la normalización tenga lugar a la entrada de la red, por ejemplo cuando se reescala un intervalo de valor de píxeles que va de 0-255 a uno entre 0-1. Este tipo de normalización es una buena practica en ML.
#
# 2. En el caso de  NN, existe un normalización relevante conocida como **batch normalization**, la cual tiene lugar entre las capas de la red, transformandose las salidas de tal manera que el valor medio es cero y la desviación estándar sea uno. La principal ventaja de este procedimiento es que limita los valores y hace menos probable que ocurran valores extremales donde se hace cero la derivada.
#
# 3. También en el caso de NN, la normalización puede tener lugar **internamente**, como en el caso de la función SELU. La idea principal es que cada capa preserva el valor medio y la varianza de la capa anterior, evitándose de esta forma valores extremales.

# %% [markdown]
# **Problemas de la función SELU**
#
# 1) Función reciente que necesita ser estudiada.
#
# 2) Computacionalmente costosa.

# %% [markdown]
# # Redes Neuronales Profundas
#
# En las clases previas introdujimos las redes neuronales artificiales y vimos algunos ejemplos de cómo entrenarlas. Pero estas eran redes muy poco profundas, con solo unas pocas capas ocultas. ¿Qué sucede si necesita abordar un problema muy complejo, como detectar cientos de tipos de objetos en imágenes de alta resolución? (Como ejemplo, considere el DIUx xView 2018 Detection Challenge http://xviewdataset.org/). Para estos casos, es posible que se necesite entrenar un DNN mucho más profunda, tal vez con 10 capas o más, cada una con cientos de neuronas, conectadas por cientos de miles de conexiones. Aparecerán algunos problemas cuando intentes entrenar redes neuronales realmente profundas, algunos de ellos son:
#
# * Vanishing gradients y exploding gradients que afecta las redes neuronales profundas y hace que las capas inferiores sean muy difíciles de entrenar.
#
# * Es posible que no tengas suficientes datos de entrenamiento para una red tan grande, o puede ser demasiado costoso etiquetarlos.
#
# * El entrenamiento puede ser extremadamente lento.
#
# * un modelo con millones de parámetros correría el riesgo de generar overfitting, especialmente si no hay suficientes instancias de entrenamiento o si son demasiado ruidosas.
#
# En ésta lección veremos algunas técnicas para resolver algunos de estos problemas.

# %% [markdown]
# ## Ejemplificación del desvanecimiento del gradiente:
#
# A continuación haremos uso de un ejemplo de juguete para ilustrar el problema del desvanecimiento del gradiente dos gupos de puntos (clase 1 y clase 0) con una distribución circular.
#
# Recordemos como crear un dataset a partir de la clase `make_circles` del módulo `datasets` de la librería `sklean`:

# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt

# Generacíon de dos grupos de círculos.

X, y= make_circles(n_samples = 1000, noise=0.1, random_state=1)

# selección de las clases para graficarlas 
plt.scatter(X[y == 0, 0], X[y == 0, 1], label=str(0),c='k') # extacción puntos según clase (0)
plt.scatter(X[y == 1, 0], X[y == 1, 1], label=str(1),c='g') # extacción puntos según clase (1)

plt.legend()
plt.show()

# %% [markdown]
# **Explicación del código:**
#
# En la primeta parte buscamos todos indices con etiquetas`y==0` y etiquetas `y==1`. Para eso usamos la función de `numpy` `where`. Para el caso en que `y == 0`, tenemos que:

# %%
np.where(y == 0)
# Out:
# (array([  2,   3,   4,   6,   8,   9,  10,  11,  13,  15,  16,  17,  19,
#          21,  24,  25,  26,  29,  33,  34,  35,  36,  42,  43,  44,  47,
#          48,  51,  53,  54,  55,  58,  60,  61,  62,  66,  69,  71,  72,
#          74,  75,  76,  78,  80,  86,  91,  94,  98,  99, 100, 101, 103,
#         104, 106, 108, 110, 113, 115, 117, 118, 120, 121, 122, 123, 124,
#         131, 133, 138, 140, 141, 144, 150, 152, 154, 158, 159, 160, 161,
#         162, 165, 166, 169, 170, 171, 172, 173, 175, 176, 180, 181, 185,
#         186, 187, 192, 195, 199, 200, 203, 206, 207, 208, 211, 213, 215,
#         216, 217, 219, 220, 222, 226, 230, 231, 233, 236, 238, 239, 241,
#         242, 245, 247, 248, 250, 251, 252, 259, 260, 262, 263, 265, 266,
#         267, 268, 269, 270, 271, 273, 279, 282, 283, 285, 287, 288, 291,
#         292, 295, 296, 297, 298, 299, 305, 307, 311, 316, 317, 318, 321,
#         323, 324, 326, 327, 328, 330, 333, 336, 337, 338, 342, 345, 347,
#         348, 350, 351, 354, 356, 357, 360, 361, 362, 363, 365, 366, 367,
#         368, 369, 371, 372, 373, 375, 379, 381, 385, 386, 387, 388, 392,
#         393, 394, 395, 397, 400, 401, 404, 407, 408, 409, 412, 413, 414,
#         416, 422, 423, 425, 426, 427, 429, 431, 433, 436, 440, 441, 446,
#         447, 448, 451, 454, 460, 461, 462, 464, 465, 466, 467, 468, 470,
#         471, 476, 477, 480, 482, 484, 485, 486, 487, 488, 489, 490, 491,
#         492, 494, 495, 496, 499, 501, 502, 503, 504, 505, 506, 509, 510,
#         512, 518, 519, 520, 523, 524, 525, 526, 529, 534, 536, 539, 540,
#         541, 542, 544, 545, 546, 558, 559, 562, 563, 567, 568, 570, 571,
#         572, 577, 578, 580, 582, 583, 584, 589, 590, 594, 595, 596, 597,
#         599, 601, 604, 605, 606, 607, 609, 610, 612, 613, 614, 615, 616,
#         617, 619, 621, 624, 626, 630, 632, 633, 640, 642, 646, 648, 649,
#         650, 654, 657, 658, 659, 662, 664, 669, 670, 675, 676, 677, 678,
#         679, 681, 682, 684, 685, 686, 688, 690, 691, 692, 694, 697, 698,
#         700, 701, 705, 706, 707, 708, 709, 711, 712, 720, 725, 728, 729,
#         730, 732, 733, 737, 738, 739, 741, 742, 743, 744, 745, 747, 752,
#         754, 755, 756, 757, 758, 759, 761, 765, 770, 772, 773, 774, 776,
#         777, 779, 782, 783, 785, 788, 790, 791, 793, 794, 795, 796, 797,
#         803, 809, 810, 813, 814, 820, 821, 823, 824, 825, 828, 829, 831,
#         832, 835, 838, 839, 840, 842, 845, 846, 847, 849, 851, 854, 855,
#         856, 857, 867, 868, 870, 871, 873, 877, 880, 881, 884, 885, 887,
#         889, 890, 892, 893, 895, 900, 901, 903, 906, 907, 908, 909, 910,
#         913, 916, 918, 920, 921, 922, 923, 924, 925, 926, 929, 931, 933,
#         934, 940, 941, 942, 944, 946, 950, 951, 952, 955, 958, 959, 960,
#         961, 962, 964, 967, 970, 973, 974, 976, 978, 979, 980, 981, 982,
#         983, 988, 989, 996, 998, 999]),)

# %% [markdown]
# Si este array (tupla en realidad), se la pasamos en la indexación `X`, obtenemos las instancias (puntos `(X[idx,0],X[idx,1])`), tenemos los valores de las instancias para cada clase (0 y 1):

# %%
X[np.where(y==0)]
# Out:
# array([[ 0.9246533 , -0.71492522],
#        [-0.10217077, -0.89283523],
#        [-1.01719242,  0.24737775],
#        [-0.90332353, -0.16419676],
#        [-0.82033072, -0.35839111],
#        [ 0.88120362,  0.58830703],
#        [ 0.63858102, -0.61951458],
#        [-0.25800139,  1.04170349],
#        [-0.35389942, -0.87842594],
#        [-0.11870173,  1.10505104],
#        [ 0.33884422,  0.90243748],
#        [ 0.88581529,  0.0685858 ],
#        [ 1.17338047, -0.12775135],
#        [ 0.87916707, -0.37555506],
#        [ 0.73217998, -0.64730593],
#        [ 0.02871132,  1.13565803],
#        [ 0.10471068,  1.02678398],
#        [ 0.02254565, -1.00679809],
#        [ 0.8026542 , -0.16686924],
#        [ 0.47892746, -1.03968355],
#        [-0.87326018, -0.35828228],
#        [ 0.59618654,  0.64820391],
#        [ 0.42186147,  0.88195164],
#        [ 0.27908035,  1.00503706],
#        [ 0.32044472,  0.97610797],
#        [ 0.76046832,  0.57659082],
#        [ 0.72667767, -0.48357329],
#        [ 1.05246741,  0.5047755 ],
#        [ 0.8765407 ,  0.3991466 ],
#        [-0.1781221 ,  0.96255893],
#        [ 0.82862856, -0.66934707],
#        [ 1.05382177, -0.22289029],
#        [-0.85915816, -0.62491987],
#        [-1.17817844,  0.1591985 ],
#        [ 0.28971646, -0.88259606],
#        [ 0.93919329, -0.53671686],
#        [ 1.0222899 ,  0.27475082],
#        [-0.15547771, -1.01626877],
#        [-1.04272382,  0.1262937 ],
#        [ 0.9593819 , -0.39138371],
#        [ 0.56643679,  0.68297562],
#        [-0.81659311,  0.79770503],
#        [-0.57293272, -0.84839448],
#        [-1.03428794, -0.21130616],
#        [ 0.68616122, -0.3536331 ],
#        [-0.62368694,  0.76624499],
#        [ 0.51430255, -0.95103997],
#        [-1.0088862 , -0.17321546],
#        [-0.3032955 ,  0.93472903],
#        [-0.44962708, -0.94882817],
#        [ 1.14033958,  0.16259966],
#        [-0.32077515,  0.85713883],
#        [ 0.52276869, -0.85672347],
#        [-0.82334742, -0.32687753],
#        [-0.92368597, -0.01311803],
#        [ 0.75093723, -0.29779775],
#        [ 0.8408582 ,  0.66070548],
#        [-0.53352072,  0.61320009],
#        [ 0.76564458, -0.54736679],
#        [ 0.18458461,  0.80395863],
#        [-0.69703262,  0.85667555],
#        [-0.92894808, -0.65747314],
#        [ 1.04188149,  0.04259822],
#        [-0.65221884,  0.52409854],
#        [ 0.81351165, -0.78182772],
#        [-1.05659905, -0.08104958],
#        [ 1.23869879,  0.04967238],
#        [-0.31879477, -0.98493606],
#        [ 0.60614854,  0.73397652],
#        [ 0.11503824,  1.0521315 ],
#        [ 0.13120303,  1.0031179 ],
#        [-0.28230689, -0.86325683],
#        [ 0.991352  ,  0.20406561],
#        [ 0.86301118,  0.68241268],
#        [ 0.4404917 ,  0.83325816],
#        [-0.93546343,  0.24690533],
#        [-0.36986591,  0.9199172 ],
#        [-0.73829517,  0.36471003],
#        [ 0.16571246,  1.1417674 ],
#        [ 0.95945704, -0.25500213],
#        [-0.96617722,  0.18045888],
#        [-0.81648501,  0.80797234],
#        [-0.79948204,  0.4673263 ],
#        [ 0.56503447,  0.83179411],
#        [ 0.67447861, -0.15172474],
#        [ 0.5989815 , -0.59873931],
#        [-0.76690509,  0.42815333],
#        [-0.73832323,  0.74074676],
#        [-0.72974707,  0.36912308],
#        [ 0.92514556,  0.69478181],
#        [-0.73312227, -0.83749036],
#        [-0.71061577,  0.53181711],
#        [-0.80501472,  0.39306463],
#        [-1.06528703,  0.21010706],
#        [ 0.72997411, -0.81621203],
#        [-0.88921678,  0.57853812],
#        [ 0.20983863, -1.10951281],
#        [ 0.73575193,  0.51452779],
#        [ 0.98203707,  0.28929934],
#        [-0.14431277, -1.12811231],
#        [-0.55530508, -0.897395  ],
#        [-0.75130878, -0.64900822],
#        [ 0.7733441 , -0.74679858],
#        [-0.73908353, -0.65050543],
#        [-0.19065688, -1.06590992],
#        [-0.59041352,  0.78864203],
#        [ 0.74894458,  0.77781925],
#        [-0.7905251 , -0.71605681],
#        [-0.76300676, -0.52607591],
#        [ 0.20894714,  0.73127602],
#        [ 0.37710742,  1.09857334],
#        [-0.93520752, -0.13516494],
#        [ 1.10376693, -0.34471842],
#        [ 0.06464296, -1.04708866],
#        [-0.57912585,  0.90519721],
#        [ 0.99227149,  0.35322534],
#        [ 0.52052714,  0.8408268 ],
#        [-0.51971876, -0.83462402],
#        [ 0.10506384, -0.97754952],
#        [ 0.76839364, -0.68272147],
#        [-0.27977281,  0.8374586 ],
#        [-0.66408613, -0.6568131 ],
#        [-0.52885909,  0.87763317],
#        [-1.17209989, -0.28316388],
#        [ 0.1764679 , -1.13252234],
#        [ 0.02617427,  0.91316982],
#        [-0.54678114,  0.9485087 ],
#        [ 1.13609701,  0.11262983],
#        [ 0.79735066, -0.00172235],
#        [-0.35165788, -0.89382515],
#        [ 0.62676665, -0.79573625],
#        [ 1.07843476, -0.44308532],
#        [ 0.21650506,  0.97237063],
#        [ 0.43047284, -1.09156615],
#        [ 1.09731917,  0.30763924],
#        [ 0.62841183,  0.72691836],
#        [-0.61457537, -0.93062822],
#        [ 0.64388315,  0.78093389],
#        [-0.91811466,  0.43423954],
#        [-1.02019921, -0.00758938],
#        [-0.06411115,  1.06374975],
#        [ 0.71215738, -0.75367028],
#        [-0.86332088,  0.71038754],
#        [-0.67593308, -0.43243115],
#        [ 0.84406356, -0.406401  ],
#        [ 0.38944588, -0.8893262 ],
#        [ 0.7708144 ,  0.66695289],
#        [-0.46703089, -0.88290744],
#        [-0.41915971, -0.99182912],
#        [-0.43361921, -0.83249872],
#        [-0.17453103,  0.99228089],
#        [ 0.75061352,  0.84666369],
#        [-1.00160386, -0.51690753],
#        [ 0.83660789,  0.61305542],
#        [-0.93295136, -0.30068696],
#        [-1.02464535,  0.51069469],
#        [-0.7917885 , -0.38380881],
#        [ 0.9353509 , -0.14489915],
#        [ 0.94412347,  0.00161948],
#        [ 0.69369617,  0.72887043],
#        [ 0.32324415, -0.82414112],
#        [ 1.02852214, -0.04361897],
#        [-0.94233882, -0.58756515],
#        [-1.0377393 ,  0.15139951],
#        [-0.96423643, -0.06136443],
#        [-0.33311192,  0.9567318 ],
#        [ 0.82275264, -0.71232506],
#        [-0.94649442, -0.11842181],
#        [-0.91863979,  0.06317292],
#        [-0.74254616,  0.44490637],
#        [ 0.38018118,  0.84249356],
#        [ 0.03541036,  1.0472379 ],
#        [ 0.72721323,  0.98341217],
#        [ 0.13749975, -0.99652446],
#        [ 0.00855107,  1.04022921],
#        [ 0.75093339,  0.68795962],
#        [-1.00240679, -0.50061343],
#        [-1.02999726,  0.06036463],
#        [-0.2489721 , -1.1091166 ],
#        [ 0.96521062,  0.66423555],
#        [ 0.47907529,  0.89029738],
#        [-0.69772357,  0.47808317],
#        [ 0.4470673 , -0.75473219],
#        [ 0.6598473 ,  0.62648775],
#        [ 0.02909777, -1.00231915],
#        [-0.25862801,  0.99532383],
#        [ 0.2053296 , -1.02254482],
#        [ 0.12116265,  0.79287963],
#        [-0.40571823, -0.82928489],
#        [ 0.5505594 , -0.59128632],
#        [ 1.03923736,  0.12728489],
#        [ 0.06640795, -1.13113244],
#        [ 0.61484884,  0.94482724],
#        [ 1.13301941, -0.17173435],
#        [ 0.54795361,  0.83099517],
#        [-0.11627681, -0.95935863],
#        [-0.88278898, -0.29230849],
#        [-0.54414415,  0.82350093],
#        [ 0.24027748,  1.24475765],
#        [-0.04910066, -0.85564368],
#        [ 1.0131663 ,  0.55955923],
#        [ 0.41020235, -0.80843222],
#        [ 0.99851746,  0.22953227],
#        [-0.93661844,  0.52867766],
#        [-0.3817107 , -0.89813746],
#        [-0.20088334,  0.80748291],
#        [-0.65244309, -0.71012183],
#        [-0.82487023, -0.45932283],
#        [ 0.47874219, -0.97392013],
#        [-0.62289575,  0.56346842],
#        [ 0.92778074, -0.86406624],
#        [-0.88964658,  0.2738931 ],
#        [-0.75159337, -0.51503039],
#        [ 0.89498414,  0.40491006],
#        [ 0.9347698 , -0.06683922],
#        [-0.98241653, -0.52633901],
#        [ 0.75745577, -0.28581992],
#        [ 0.25018963,  0.94086936],
#        [ 0.39550726,  0.91276813],
#        [-1.12270572, -0.07750399],
#        [ 0.49640164,  0.99097714],
#        [ 0.76207202,  0.75413645],
#        [-0.92550102,  0.76171769],
#        [-0.58957805,  0.7513016 ],
#        [ 0.55443737,  0.76008828],
#        [ 0.5816603 , -1.16150642],
#        [-0.46075184, -0.88243201],
#        [ 1.01573659, -0.1166481 ],
#        [ 1.08725373,  0.42506014],
#        [ 0.95017117,  0.54726366],
#        [ 1.01671131, -0.20559673],
#        [ 0.96288256,  0.44874872],
#        [-0.41655889,  0.78758288],
#        [-0.16002195,  0.66377844],
#        [-1.09629351,  0.55692593],
#        [ 0.36662148, -1.00287094],
#        [ 0.76686753,  0.79422161],
#        [-0.21631197, -0.86296241],
#        [ 0.35167488, -0.9383074 ],
#        [ 0.343105  , -0.88236021],
#        [ 0.61359604, -0.58096041],
#        [-0.44628763,  0.79670016],
#        [-0.82997521, -0.37479253],
#        [ 0.565184  ,  0.80818754],
#        [-0.91124249,  0.39043997],
#        [ 0.72024411, -0.69954406],
#        [-0.15405086, -1.19387052],
#        [-0.99069764, -0.86601981],
#        [-0.94396081, -0.10525866],
#        [-0.45419232, -0.63641205],
#        [ 1.10951237, -0.00272364],
#        [ 0.93084773,  0.42253696],
#        [-0.78029488,  0.70225382],
#        [ 0.8652267 ,  0.41124686],
#        [ 0.88331309,  0.3840398 ],
#        [-0.50842085, -0.76049894],
#        [-0.01141155, -0.94185848],
#        [-0.88235724, -0.37418938],
#        [ 0.85462366,  0.12548115],
#        [-0.75630591,  0.43219547],
#        [ 0.28034274, -0.91641012],
#        [-0.02443055,  0.96766554],
#        [ 0.13308941, -1.07560373],
#        [ 1.00383194,  0.51363318],
#        [-0.61645066,  0.71266605],
#        [ 0.55228143,  0.66563388],
#        [ 0.14406012,  0.99809529],
#        [ 1.02783741,  0.15773429],
#        [ 0.77125792, -0.76811615],
#        [ 0.04304604, -1.0438607 ],
#        [-0.30737675, -1.06565978],
#        [-1.00575195, -0.26226127],
#        [-0.37636087, -0.96378006],
#        [-0.28888966,  0.89446832],
#        [ 0.26894983, -0.6221153 ],
#        [ 0.01239345, -1.00187887],
#        [-0.75214277, -0.77149072],
#        [ 0.9229728 ,  0.61136086],
#        [ 0.73191443, -0.81186123],
#        [-0.89047399, -0.10986131],
#        [-0.03213009, -1.16465922],
#        [ 1.21313935, -0.02782653],
#        [ 0.50949803,  1.08461118],
#        [-0.24031082,  0.99939495],
#        [ 0.23146203, -1.05048594],
#        [-0.68127362,  0.46401119],
#        [-0.17414662, -1.00279724],
#        [ 0.98759913, -0.18904968],
#        [-0.93776402,  0.05095394],
#        [ 0.02987259, -0.75050036],
#        [-0.99222053, -0.00199077],
#        [ 0.70396936, -0.78861886],
#        [ 0.3289713 ,  0.89471785],
#        [-1.03334746,  0.4767118 ],
#        [-0.0543307 , -0.98329623],
#        [-1.02562092,  0.31382207],
#        [ 0.90466981, -0.00863335],
#        [-0.48094802,  1.02776966],
#        [-0.90112989, -0.49519346],
#        [ 0.28656238, -0.85473456],
#        [-0.653012  , -0.97329746],
#        [ 0.31060143,  1.04357434],
#        [-0.89607736,  0.30833622],
#        [-0.37232196, -0.85712619],
#        [ 0.55867204, -0.74824547],
#        [-0.01715286,  0.90177043],
#        [-0.54059474,  0.87358527],
#        [ 0.16311395,  1.0421112 ],
#        [ 0.91405846,  0.46230174],
#        [ 0.40912228,  0.94193411],
#        [-0.30847076, -0.89154776],
#        [ 0.05825372, -0.97338583],
#        [ 0.82146654, -0.74089448],
#        [-0.25918402, -1.00883431],
#        [-0.90690122,  0.05314394],
#        [ 0.59582467, -0.72517801],
#        [-0.60150107,  1.02953086],
#        [ 0.63854597,  0.73641203],
#        [-0.89949595, -0.56748996],
#        [ 0.59292449,  0.64888614],
#        [-0.05724489,  1.00299058],
#        [ 0.89647475, -0.02136994],
#        [-0.76020017, -0.63941885],
#        [ 0.4645714 , -0.75787828],
#        [-0.49505785,  0.92397821],
#        [ 0.53677587, -0.96810045],
#        [ 1.08027391, -0.32207648],
#        [ 0.75209229, -0.73132156],
#        [-0.69471802, -0.90889854],
#        [-0.08402948, -0.96805179],
#        [ 0.66570547, -0.85792056],
#        [-0.46418276,  1.09337423],
#        [ 0.56356532, -0.90710482],
#        [-0.20262733,  0.89218248],
#        [-0.75010614,  0.53316717],
#        [ 0.82233159, -0.86092458],
#        [-0.11634849,  0.95179219],
#        [ 0.00384755, -0.95400328],
#        [-0.48798056,  0.70566136],
#        [-0.85382249, -0.30016338],
#        [ 0.38123559, -0.95345292],
#        [ 0.06343278,  1.09381675],
#        [-0.18517917,  0.9569772 ],
#        [ 0.74301481,  0.74671914],
#        [-0.88615916, -0.36760137],
#        [-0.44087533, -0.95234432],
#        [-0.8270354 , -0.06056656],
#        [-0.5481439 ,  0.74324168],
#        [-0.87166265, -0.7196375 ],
#        [-1.2120205 ,  0.21834893],
#        [-0.93857804,  0.1923426 ],
#        [-0.38636583, -0.82937344],
#        [ 0.99190343, -0.5487988 ],
#        [ 0.91616188, -0.45825352],
#        [-0.49688188,  0.75490592],
#        [-0.70721345,  0.79783257],
#        [-0.36521169,  0.92604126],
#        [-0.84219087,  0.45099861],
#        [-0.78771915,  0.60669679],
#        [-0.62782031, -0.77301784],
#        [ 0.42055936,  0.77414883],
#        [-0.90064413,  0.39952407],
#        [ 0.10602249,  1.01185117],
#        [-0.91171757, -0.46649553],
#        [ 0.81257   , -0.72569624],
#        [ 0.93598796,  0.63475338],
#        [ 0.23157245, -1.00719277],
#        [-1.21713332,  0.00647268],
#        [ 0.85939829,  0.02442001],
#        [ 0.92487835, -0.39228835],
#        [-0.93431926, -0.27338623],
#        [ 0.91761886,  0.4463416 ],
#        [ 0.31082494,  0.9648564 ],
#        [ 0.870345  ,  0.4280575 ],
#        [-0.74653458,  0.461687  ],
#        [-0.61458833,  0.94451364],
#        [ 0.83182129,  0.26118418],
#        [ 0.34722833,  0.99099322],
#        [-0.13821792,  1.06029605],
#        [-0.69701226, -0.77207128],
#        [-0.84719624,  0.43535731],
#        [ 0.90543445,  0.22111792],
#        [-0.99233427, -0.42363783],
#        [ 0.92265665,  0.72454882],
#        [ 0.69797254,  0.67193509],
#        [ 0.94485798, -0.42140606],
#        [ 0.69992649,  0.60702178],
#        [ 0.42460169, -0.86128373],
#        [ 0.0973514 , -0.7823491 ],
#        [-0.56959982, -0.89683167],
#        [ 0.85841477, -0.41589328],
#        [-0.90314374,  0.03037511],
#        [ 0.86487616, -0.37928619],
#        [ 0.59266525, -0.75936412],
#        [-0.98783823, -0.58145019],
#        [-0.86723615,  0.29016605],
#        [-0.95310721, -0.43515948],
#        [ 1.20754057,  0.19343978],
#        [ 0.58916354, -0.86249845],
#        [-0.36691909, -0.84145018],
#        [-0.72217394,  0.6586416 ],
#        [ 0.70062098, -0.80381219],
#        [-0.09231687,  1.07310359],
#        [-0.69621957,  0.50736932],
#        [-0.84571838,  0.16130125],
#        [ 0.33981927, -1.05905023],
#        [-0.56070763, -0.68341933],
#        [-0.59018592,  0.78631355],
#        [ 0.89099271, -0.19792032],
#        [-1.01383695, -0.38053965],
#        [ 0.89691876,  0.17782439],
#        [-0.62307704,  0.73494888],
#        [ 0.1674736 , -1.03222452],
#        [-0.6758988 ,  0.72588326],
#        [-0.54769436, -0.83937984],
#        [-0.70266451,  0.70218161],
#        [ 0.90352972, -0.4303783 ],
#        [-0.90061098, -0.32642071],
#        [ 0.93827345, -0.16835609],
#        [-0.04000783,  1.09041194],
#        [-0.60286924, -0.84596691],
#        [ 0.9744179 , -0.27393569],
#        [-0.8586124 ,  0.89432064],
#        [-0.18554959,  0.9699477 ],
#        [ 0.6131267 , -0.84410375],
#        [ 0.91725597, -0.29057601],
#        [-0.20269936,  0.94258023],
#        [ 0.88488149, -0.02537433],
#        [-0.81316553, -0.1229506 ],
#        [ 0.40874917,  0.8866358 ],
#        [-0.72595056,  0.3450369 ],
#        [-0.38408199, -0.84366711],
#        [ 0.79619754,  0.84709134],
#        [ 0.55823451,  0.77465551],
#        [-0.95874581, -0.15115878],
#        [-0.18184092,  0.97245733],
#        [ 0.86503215, -0.47103777],
#        [ 0.81690877, -0.43475783],
#        [-0.92942467, -0.26935191],
#        [ 0.04508595, -1.19146884],
#        [-0.78418424, -0.68324409],
#        [-0.41970568,  1.01304019],
#        [-0.63457666, -0.57815039],
#        [-0.91091351,  0.7098785 ],
#        [-0.23462018, -0.89913434],
#        [-0.90335162,  0.28427914],
#        [ 0.35024947,  0.91058152],
#        [ 0.51184792, -1.05294584],
#        [-0.86951407, -0.45996285],
#        [-0.7092201 ,  1.06136671],
#        [-0.36148528,  0.98383671],
#        [-0.36838868, -0.88708909],
#        [ 0.08843603, -0.96225053],
#        [-0.89392213, -0.30516846],
#        [ 0.09947014,  1.08596649],
#        [ 0.81715244,  0.26881425],
#        [-0.84271124, -0.43318606],
#        [ 0.79596108, -0.4431074 ],
#        [-0.07538247, -1.1107027 ],
#        [ 0.85907912,  0.478463  ],
#        [-0.74683537,  0.56584724],
#        [ 0.64522555,  1.09433392],
#        [ 1.11631444,  0.02373391],
#        [ 0.86422847, -0.34209331],
#        [-0.85814401, -0.44297029],
#        [-0.38242403, -0.73229871],
#        [ 1.02253461,  0.26306822],
#        [ 0.96333953,  0.5123336 ],
#        [ 0.99605568,  0.00538758],
#        [ 0.90919647, -0.56557203],
#        [ 0.17793947, -0.86586087],
#        [ 0.51857231,  0.70482459],
#        [ 0.78063298, -0.60448916],
#        [ 0.78678329, -0.79195604],
#        [-0.95052884, -0.22149251],
#        [-0.86184044,  0.55276679],
#        [-0.85295015, -0.64640487],
#        [-0.5845361 , -0.54742206],
#        [-0.57103079, -0.8421489 ],
#        [ 0.94437556,  0.10899469],
#        [ 0.00644825, -1.00651913],
#        [ 0.00175491,  1.03854353],
#        [ 0.37079298,  0.98689274],
#        [ 0.90356659, -0.33871155],
#        [-0.99235099,  0.45786117],
#        [ 0.40405159, -0.91472998],
#        [ 0.94745204, -0.14562408],
#        [-0.98369401, -0.04739134],
#        [ 1.02862705, -0.39268321],
#        [-0.30120912, -0.99995794],
#        [-0.87853102, -0.17743168],
#        [-0.84308303, -0.33012003],
#        [-0.70100412,  0.65437931],
#        [-0.87017769, -0.57040238],
#        [ 0.14123002, -1.02632344],
#        [-0.01337775,  1.00920019],
#        [-0.27092791,  0.96554999],
#        [ 0.70853625,  0.80114409],
#        [-0.92836187,  0.06693357],
#        [ 1.03502248,  0.54878286]])

# %%
# Preprocesado de los datos:
from sklearn.preprocessing import MinMaxScaler

# scale input data to [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# %%
# División de los datos en entrenamiento y evaluación
n_train = 500
train_X, test_X = X[:n_train, :], X[n_train:, :]
train_y, test_y = y[:n_train], y[n_train:]

# %% [markdown]
# ### Modelo del perceptrón multicapas para el problema de dos círculos:
#
# Empecemos por ilustrar el caso en que temos un ajuste adecuado del modelo de de una red neuronal poco profunda consituida por una capa de entrada, con una función de activación `tanh` y una capa de salida `sigmoid`. Este modelo, no debe sufrir de problemas de desvanecimiento/explosión del gradiente:

# %%
from tensorflow import keras

keras.backend.clear_session()

# Definición del modelo poco profundo
modelA= keras.models.Sequential()
init = keras.initializers.RandomUniform(minval=0, maxval=1)
modelA.add(keras.layers.Dense(5, input_dim=2, activation='tanh', kernel_initializer=init))
modelA.add(keras.layers.Dense(1, activation='sigmoid', kernel_initializer=init))

# Compilación del modelo
opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
modelA.compile(loss = 'binary_crossentropy', optimizer = opt, metrics = ['accuracy'])
modelA.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 15
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Ajuste del modelo:
history = modelA.fit(train_X, train_y, validation_data=(test_X, test_y), epochs=500)
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/500
# 500/500 [==============================] - 0s 144us/sample - loss: 0.4832 - accuracy: 0.8080 - val_loss: 0.4853 - val_accuracy: 0.7860
# Epoch 2/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4833 - accuracy: 0.7980 - val_loss: 0.4838 - val_accuracy: 0.8160
# Epoch 3/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4824 - accuracy: 0.7860 - val_loss: 0.4827 - val_accuracy: 0.7880
# Epoch 4/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4846 - accuracy: 0.8080 - val_loss: 0.4822 - val_accuracy: 0.7940
# Epoch 5/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4822 - accuracy: 0.7920 - val_loss: 0.4818 - val_accuracy: 0.8200
# Epoch 6/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4818 - accuracy: 0.8040 - val_loss: 0.4834 - val_accuracy: 0.7900
# Epoch 7/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4804 - accuracy: 0.7920 - val_loss: 0.4824 - val_accuracy: 0.8080
# Epoch 8/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4793 - accuracy: 0.8020 - val_loss: 0.4822 - val_accuracy: 0.7920
# Epoch 9/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4799 - accuracy: 0.7940 - val_loss: 0.4809 - val_accuracy: 0.8020
# Epoch 10/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4791 - accuracy: 0.8100 - val_loss: 0.4799 - val_accuracy: 0.7920
# Epoch 11/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4787 - accuracy: 0.7980 - val_loss: 0.4804 - val_accuracy: 0.8060
# Epoch 12/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4797 - accuracy: 0.8120 - val_loss: 0.4803 - val_accuracy: 0.7980
# Epoch 13/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4784 - accuracy: 0.7960 - val_loss: 0.4806 - val_accuracy: 0.8000
# Epoch 14/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4819 - accuracy: 0.8060 - val_loss: 0.4771 - val_accuracy: 0.8080
# Epoch 15/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4777 - accuracy: 0.8000 - val_loss: 0.4779 - val_accuracy: 0.8140
# Epoch 16/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4764 - accuracy: 0.7980 - val_loss: 0.4782 - val_accuracy: 0.8000
# Epoch 17/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4773 - accuracy: 0.8180 - val_loss: 0.4778 - val_accuracy: 0.8120
# Epoch 18/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4782 - accuracy: 0.7920 - val_loss: 0.4782 - val_accuracy: 0.8040
# Epoch 19/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4761 - accuracy: 0.7940 - val_loss: 0.4789 - val_accuracy: 0.7940
# Epoch 20/500
# 500/500 [==============================] - 0s 150us/sample - loss: 0.4760 - accuracy: 0.8080 - val_loss: 0.4764 - val_accuracy: 0.8120
# Epoch 21/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4760 - accuracy: 0.7940 - val_loss: 0.4783 - val_accuracy: 0.7940
# Epoch 22/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4765 - accuracy: 0.8060 - val_loss: 0.4756 - val_accuracy: 0.8140
# Epoch 23/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4810 - accuracy: 0.7960 - val_loss: 0.4800 - val_accuracy: 0.7900
# Epoch 24/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4783 - accuracy: 0.7860 - val_loss: 0.4775 - val_accuracy: 0.8060
# Epoch 25/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4793 - accuracy: 0.8080 - val_loss: 0.4793 - val_accuracy: 0.7880
# Epoch 26/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4752 - accuracy: 0.7960 - val_loss: 0.4751 - val_accuracy: 0.8140
# Epoch 27/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4742 - accuracy: 0.8140 - val_loss: 0.4762 - val_accuracy: 0.7980
# Epoch 28/500
# 500/500 [==============================] - 0s 148us/sample - loss: 0.4730 - accuracy: 0.8120 - val_loss: 0.4738 - val_accuracy: 0.8220
# Epoch 29/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4734 - accuracy: 0.7880 - val_loss: 0.4743 - val_accuracy: 0.8080
# Epoch 30/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4732 - accuracy: 0.8020 - val_loss: 0.4773 - val_accuracy: 0.7960
# Epoch 31/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4733 - accuracy: 0.7880 - val_loss: 0.4730 - val_accuracy: 0.8220
# Epoch 32/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4716 - accuracy: 0.8000 - val_loss: 0.4747 - val_accuracy: 0.7980
# Epoch 33/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4734 - accuracy: 0.8180 - val_loss: 0.4729 - val_accuracy: 0.7960
# Epoch 34/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4739 - accuracy: 0.8080 - val_loss: 0.4760 - val_accuracy: 0.8040
# Epoch 35/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4727 - accuracy: 0.7900 - val_loss: 0.4720 - val_accuracy: 0.8200
# Epoch 36/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4716 - accuracy: 0.8040 - val_loss: 0.4720 - val_accuracy: 0.7980
# Epoch 37/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4709 - accuracy: 0.8020 - val_loss: 0.4727 - val_accuracy: 0.8060
# Epoch 38/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4727 - accuracy: 0.8140 - val_loss: 0.4715 - val_accuracy: 0.7960
# Epoch 39/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4731 - accuracy: 0.8020 - val_loss: 0.4747 - val_accuracy: 0.7940
# Epoch 40/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4707 - accuracy: 0.8020 - val_loss: 0.4706 - val_accuracy: 0.8220
# Epoch 41/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4711 - accuracy: 0.8020 - val_loss: 0.4705 - val_accuracy: 0.8020
# Epoch 42/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4712 - accuracy: 0.8080 - val_loss: 0.4706 - val_accuracy: 0.8180
# Epoch 43/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4693 - accuracy: 0.7960 - val_loss: 0.4697 - val_accuracy: 0.8200
# Epoch 44/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4693 - accuracy: 0.8020 - val_loss: 0.4707 - val_accuracy: 0.8100
# Epoch 45/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4689 - accuracy: 0.7980 - val_loss: 0.4703 - val_accuracy: 0.8100
# Epoch 46/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4691 - accuracy: 0.8080 - val_loss: 0.4686 - val_accuracy: 0.8140
# Epoch 47/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4667 - accuracy: 0.8160 - val_loss: 0.4691 - val_accuracy: 0.7960
# Epoch 48/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4690 - accuracy: 0.8120 - val_loss: 0.4697 - val_accuracy: 0.8040
# Epoch 49/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4707 - accuracy: 0.8160 - val_loss: 0.4704 - val_accuracy: 0.8080
# Epoch 50/500
# 500/500 [==============================] - 0s 143us/sample - loss: 0.4701 - accuracy: 0.7820 - val_loss: 0.4690 - val_accuracy: 0.8160
# Epoch 51/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4672 - accuracy: 0.8000 - val_loss: 0.4681 - val_accuracy: 0.8160
# Epoch 52/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4672 - accuracy: 0.8120 - val_loss: 0.4672 - val_accuracy: 0.8260
# Epoch 53/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4668 - accuracy: 0.7960 - val_loss: 0.4689 - val_accuracy: 0.8080
# Epoch 54/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4664 - accuracy: 0.7980 - val_loss: 0.4672 - val_accuracy: 0.8020
# Epoch 55/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4660 - accuracy: 0.8140 - val_loss: 0.4683 - val_accuracy: 0.8080
# Epoch 56/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4669 - accuracy: 0.7940 - val_loss: 0.4665 - val_accuracy: 0.8180
# Epoch 57/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4688 - accuracy: 0.8080 - val_loss: 0.4680 - val_accuracy: 0.8060
# Epoch 58/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4660 - accuracy: 0.8060 - val_loss: 0.4662 - val_accuracy: 0.8060
# Epoch 59/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4678 - accuracy: 0.7940 - val_loss: 0.4662 - val_accuracy: 0.7920
# Epoch 60/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4670 - accuracy: 0.8220 - val_loss: 0.4678 - val_accuracy: 0.8000
# Epoch 61/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4648 - accuracy: 0.7980 - val_loss: 0.4647 - val_accuracy: 0.8180
# Epoch 62/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4642 - accuracy: 0.8000 - val_loss: 0.4667 - val_accuracy: 0.8100
# Epoch 63/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4646 - accuracy: 0.8060 - val_loss: 0.4649 - val_accuracy: 0.8020
# Epoch 64/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4634 - accuracy: 0.7980 - val_loss: 0.4655 - val_accuracy: 0.8140
# Epoch 65/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4636 - accuracy: 0.7980 - val_loss: 0.4662 - val_accuracy: 0.7980
# Epoch 66/500
# 500/500 [==============================] - 0s 151us/sample - loss: 0.4636 - accuracy: 0.7980 - val_loss: 0.4634 - val_accuracy: 0.8180
# Epoch 67/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4641 - accuracy: 0.7980 - val_loss: 0.4650 - val_accuracy: 0.8060
# Epoch 68/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4627 - accuracy: 0.8040 - val_loss: 0.4640 - val_accuracy: 0.8160
# Epoch 69/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4618 - accuracy: 0.8040 - val_loss: 0.4628 - val_accuracy: 0.8220
# Epoch 70/500
# 500/500 [==============================] - 0s 144us/sample - loss: 0.4620 - accuracy: 0.8040 - val_loss: 0.4650 - val_accuracy: 0.8060
# Epoch 71/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4631 - accuracy: 0.8020 - val_loss: 0.4629 - val_accuracy: 0.8200
# Epoch 72/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4632 - accuracy: 0.8100 - val_loss: 0.4626 - val_accuracy: 0.8080
# Epoch 73/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4618 - accuracy: 0.8040 - val_loss: 0.4632 - val_accuracy: 0.8180
# Epoch 74/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4633 - accuracy: 0.7900 - val_loss: 0.4638 - val_accuracy: 0.8120
# Epoch 75/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4642 - accuracy: 0.8080 - val_loss: 0.4638 - val_accuracy: 0.7960
# Epoch 76/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4665 - accuracy: 0.7920 - val_loss: 0.4619 - val_accuracy: 0.8140
# Epoch 77/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4604 - accuracy: 0.8040 - val_loss: 0.4612 - val_accuracy: 0.7980
# Epoch 78/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4631 - accuracy: 0.8040 - val_loss: 0.4620 - val_accuracy: 0.8140
# Epoch 79/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4634 - accuracy: 0.8040 - val_loss: 0.4612 - val_accuracy: 0.8120
# Epoch 80/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4635 - accuracy: 0.7920 - val_loss: 0.4616 - val_accuracy: 0.8120
# Epoch 81/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4611 - accuracy: 0.8040 - val_loss: 0.4594 - val_accuracy: 0.8160
# Epoch 82/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4595 - accuracy: 0.8040 - val_loss: 0.4622 - val_accuracy: 0.8080
# Epoch 83/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4594 - accuracy: 0.7960 - val_loss: 0.4610 - val_accuracy: 0.8220
# Epoch 84/500
# 500/500 [==============================] - 0s 169us/sample - loss: 0.4588 - accuracy: 0.8000 - val_loss: 0.4594 - val_accuracy: 0.8120
# Epoch 85/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4588 - accuracy: 0.8100 - val_loss: 0.4604 - val_accuracy: 0.8040
# Epoch 86/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4586 - accuracy: 0.8040 - val_loss: 0.4614 - val_accuracy: 0.8180
# Epoch 87/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4580 - accuracy: 0.7920 - val_loss: 0.4606 - val_accuracy: 0.8140
# Epoch 88/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4581 - accuracy: 0.8140 - val_loss: 0.4580 - val_accuracy: 0.8140
# Epoch 89/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4579 - accuracy: 0.7980 - val_loss: 0.4596 - val_accuracy: 0.8120
# Epoch 90/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4571 - accuracy: 0.8040 - val_loss: 0.4577 - val_accuracy: 0.8140
# Epoch 91/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4583 - accuracy: 0.8060 - val_loss: 0.4595 - val_accuracy: 0.8100
# Epoch 92/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4612 - accuracy: 0.8100 - val_loss: 0.4589 - val_accuracy: 0.8120
# Epoch 93/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4600 - accuracy: 0.7900 - val_loss: 0.4575 - val_accuracy: 0.8140
# Epoch 94/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4610 - accuracy: 0.8160 - val_loss: 0.4625 - val_accuracy: 0.7920
# Epoch 95/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4554 - accuracy: 0.7920 - val_loss: 0.4564 - val_accuracy: 0.8240
# Epoch 96/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4600 - accuracy: 0.8160 - val_loss: 0.4568 - val_accuracy: 0.8060
# Epoch 97/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4562 - accuracy: 0.7960 - val_loss: 0.4589 - val_accuracy: 0.8200
# Epoch 98/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4557 - accuracy: 0.7900 - val_loss: 0.4581 - val_accuracy: 0.8160
# Epoch 99/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4568 - accuracy: 0.8080 - val_loss: 0.4566 - val_accuracy: 0.8080
# Epoch 100/500
# 500/500 [==============================] - 0s 164us/sample - loss: 0.4552 - accuracy: 0.8100 - val_loss: 0.4563 - val_accuracy: 0.8200
# Epoch 101/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4570 - accuracy: 0.8000 - val_loss: 0.4563 - val_accuracy: 0.8180
# Epoch 102/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4567 - accuracy: 0.8180 - val_loss: 0.4568 - val_accuracy: 0.8100
# Epoch 103/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4583 - accuracy: 0.7920 - val_loss: 0.4547 - val_accuracy: 0.8160
# Epoch 104/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4553 - accuracy: 0.8140 - val_loss: 0.4583 - val_accuracy: 0.8120
# Epoch 105/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4569 - accuracy: 0.7940 - val_loss: 0.4569 - val_accuracy: 0.8220
# Epoch 106/500
# 500/500 [==============================] - 0s 147us/sample - loss: 0.4534 - accuracy: 0.8080 - val_loss: 0.4578 - val_accuracy: 0.8080
# Epoch 107/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4538 - accuracy: 0.8000 - val_loss: 0.4556 - val_accuracy: 0.8220
# Epoch 108/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4544 - accuracy: 0.8100 - val_loss: 0.4551 - val_accuracy: 0.8080
# Epoch 109/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4543 - accuracy: 0.8100 - val_loss: 0.4556 - val_accuracy: 0.8220
# Epoch 110/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4535 - accuracy: 0.7980 - val_loss: 0.4545 - val_accuracy: 0.8120
# Epoch 111/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4551 - accuracy: 0.8180 - val_loss: 0.4556 - val_accuracy: 0.8240
# Epoch 112/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4571 - accuracy: 0.7880 - val_loss: 0.4532 - val_accuracy: 0.8200
# Epoch 113/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4569 - accuracy: 0.8080 - val_loss: 0.4553 - val_accuracy: 0.8020
# Epoch 114/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4583 - accuracy: 0.7960 - val_loss: 0.4543 - val_accuracy: 0.8120
# Epoch 115/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4552 - accuracy: 0.8100 - val_loss: 0.4536 - val_accuracy: 0.8080
# Epoch 116/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4541 - accuracy: 0.7960 - val_loss: 0.4547 - val_accuracy: 0.8220
# Epoch 117/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4528 - accuracy: 0.7900 - val_loss: 0.4529 - val_accuracy: 0.8120
# Epoch 118/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4531 - accuracy: 0.8100 - val_loss: 0.4532 - val_accuracy: 0.8220
# Epoch 119/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4523 - accuracy: 0.8080 - val_loss: 0.4548 - val_accuracy: 0.8160
# Epoch 120/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4520 - accuracy: 0.7880 - val_loss: 0.4537 - val_accuracy: 0.8220
# Epoch 121/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4520 - accuracy: 0.8000 - val_loss: 0.4512 - val_accuracy: 0.8080
# Epoch 122/500
# 500/500 [==============================] - 0s 110us/sample - loss: 0.4537 - accuracy: 0.8180 - val_loss: 0.4545 - val_accuracy: 0.8140
# Epoch 123/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4517 - accuracy: 0.8000 - val_loss: 0.4525 - val_accuracy: 0.8140
# Epoch 124/500
# 500/500 [==============================] - 0s 112us/sample - loss: 0.4546 - accuracy: 0.8040 - val_loss: 0.4504 - val_accuracy: 0.8080
# Epoch 125/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4582 - accuracy: 0.8180 - val_loss: 0.4545 - val_accuracy: 0.8200
# Epoch 126/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4586 - accuracy: 0.7900 - val_loss: 0.4534 - val_accuracy: 0.8160
# Epoch 127/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4532 - accuracy: 0.8000 - val_loss: 0.4536 - val_accuracy: 0.8020
# Epoch 128/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4495 - accuracy: 0.8000 - val_loss: 0.4530 - val_accuracy: 0.8220
# Epoch 129/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4504 - accuracy: 0.7940 - val_loss: 0.4502 - val_accuracy: 0.8180
# Epoch 130/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4559 - accuracy: 0.8080 - val_loss: 0.4498 - val_accuracy: 0.8080
# Epoch 131/500
# 500/500 [==============================] - 0s 155us/sample - loss: 0.4491 - accuracy: 0.8120 - val_loss: 0.4543 - val_accuracy: 0.8060
# Epoch 132/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4523 - accuracy: 0.8120 - val_loss: 0.4505 - val_accuracy: 0.8200
# Epoch 133/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4492 - accuracy: 0.8040 - val_loss: 0.4512 - val_accuracy: 0.8020
# Epoch 134/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4516 - accuracy: 0.8120 - val_loss: 0.4508 - val_accuracy: 0.8220
# Epoch 135/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4498 - accuracy: 0.7980 - val_loss: 0.4527 - val_accuracy: 0.8180
# Epoch 136/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4515 - accuracy: 0.8060 - val_loss: 0.4480 - val_accuracy: 0.8180
# Epoch 137/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4471 - accuracy: 0.8000 - val_loss: 0.4516 - val_accuracy: 0.8160
# Epoch 138/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4567 - accuracy: 0.8040 - val_loss: 0.4522 - val_accuracy: 0.8240
# Epoch 139/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4501 - accuracy: 0.8000 - val_loss: 0.4473 - val_accuracy: 0.8280
# Epoch 140/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4503 - accuracy: 0.8100 - val_loss: 0.4519 - val_accuracy: 0.8080
# Epoch 141/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4484 - accuracy: 0.7940 - val_loss: 0.4489 - val_accuracy: 0.8220
# Epoch 142/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4497 - accuracy: 0.8040 - val_loss: 0.4498 - val_accuracy: 0.8100
# Epoch 143/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4481 - accuracy: 0.8060 - val_loss: 0.4494 - val_accuracy: 0.8140
# Epoch 144/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4457 - accuracy: 0.8080 - val_loss: 0.4488 - val_accuracy: 0.8220
# Epoch 145/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4532 - accuracy: 0.8020 - val_loss: 0.4509 - val_accuracy: 0.8140
# Epoch 146/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4510 - accuracy: 0.8000 - val_loss: 0.4472 - val_accuracy: 0.8200
# Epoch 147/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4544 - accuracy: 0.8100 - val_loss: 0.4478 - val_accuracy: 0.8120
# Epoch 148/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4528 - accuracy: 0.7880 - val_loss: 0.4505 - val_accuracy: 0.8240
# Epoch 149/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4483 - accuracy: 0.7940 - val_loss: 0.4482 - val_accuracy: 0.8100
# Epoch 150/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4491 - accuracy: 0.8020 - val_loss: 0.4472 - val_accuracy: 0.8200
# Epoch 151/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4474 - accuracy: 0.8140 - val_loss: 0.4478 - val_accuracy: 0.8240
# Epoch 152/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4461 - accuracy: 0.8000 - val_loss: 0.4471 - val_accuracy: 0.8160
# Epoch 153/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4451 - accuracy: 0.8040 - val_loss: 0.4474 - val_accuracy: 0.8140
# Epoch 154/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4464 - accuracy: 0.8040 - val_loss: 0.4457 - val_accuracy: 0.8240
# Epoch 155/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4486 - accuracy: 0.7880 - val_loss: 0.4497 - val_accuracy: 0.8060
# Epoch 156/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4475 - accuracy: 0.8000 - val_loss: 0.4462 - val_accuracy: 0.8240
# Epoch 157/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4517 - accuracy: 0.8080 - val_loss: 0.4475 - val_accuracy: 0.8240
# Epoch 158/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4448 - accuracy: 0.7860 - val_loss: 0.4472 - val_accuracy: 0.8080
# Epoch 159/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4473 - accuracy: 0.8180 - val_loss: 0.4447 - val_accuracy: 0.8220
# Epoch 160/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4446 - accuracy: 0.7940 - val_loss: 0.4459 - val_accuracy: 0.8240
# Epoch 161/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4448 - accuracy: 0.8100 - val_loss: 0.4468 - val_accuracy: 0.8140
# Epoch 162/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4451 - accuracy: 0.8000 - val_loss: 0.4452 - val_accuracy: 0.8260
# Epoch 163/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4464 - accuracy: 0.7900 - val_loss: 0.4437 - val_accuracy: 0.8140
# Epoch 164/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4508 - accuracy: 0.8160 - val_loss: 0.4468 - val_accuracy: 0.8280
# Epoch 165/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4453 - accuracy: 0.8060 - val_loss: 0.4445 - val_accuracy: 0.8120
# Epoch 166/500
# 500/500 [==============================] - 0s 148us/sample - loss: 0.4434 - accuracy: 0.8040 - val_loss: 0.4471 - val_accuracy: 0.8200
# Epoch 167/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4426 - accuracy: 0.8000 - val_loss: 0.4462 - val_accuracy: 0.8140
# Epoch 168/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4445 - accuracy: 0.8040 - val_loss: 0.4429 - val_accuracy: 0.8160
# Epoch 169/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4434 - accuracy: 0.7960 - val_loss: 0.4465 - val_accuracy: 0.8120
# Epoch 170/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4456 - accuracy: 0.8080 - val_loss: 0.4478 - val_accuracy: 0.8180
# Epoch 171/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4499 - accuracy: 0.7960 - val_loss: 0.4443 - val_accuracy: 0.8040
# Epoch 172/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4432 - accuracy: 0.8140 - val_loss: 0.4460 - val_accuracy: 0.8100
# Epoch 173/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4432 - accuracy: 0.7960 - val_loss: 0.4447 - val_accuracy: 0.8240
# Epoch 174/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4434 - accuracy: 0.8080 - val_loss: 0.4423 - val_accuracy: 0.8160
# Epoch 175/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4458 - accuracy: 0.8100 - val_loss: 0.4463 - val_accuracy: 0.8220
# Epoch 176/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4462 - accuracy: 0.8120 - val_loss: 0.4417 - val_accuracy: 0.8180
# Epoch 177/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4420 - accuracy: 0.7960 - val_loss: 0.4471 - val_accuracy: 0.8160
# Epoch 178/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4428 - accuracy: 0.8140 - val_loss: 0.4428 - val_accuracy: 0.8260
# Epoch 179/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4422 - accuracy: 0.8020 - val_loss: 0.4435 - val_accuracy: 0.8260
# Epoch 180/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4428 - accuracy: 0.8060 - val_loss: 0.4423 - val_accuracy: 0.8080
# Epoch 181/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4441 - accuracy: 0.8000 - val_loss: 0.4434 - val_accuracy: 0.8240
# Epoch 182/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4408 - accuracy: 0.8060 - val_loss: 0.4421 - val_accuracy: 0.8140
# Epoch 183/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4403 - accuracy: 0.8060 - val_loss: 0.4433 - val_accuracy: 0.8240
# Epoch 184/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4432 - accuracy: 0.8080 - val_loss: 0.4425 - val_accuracy: 0.8120
# Epoch 185/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4455 - accuracy: 0.8080 - val_loss: 0.4433 - val_accuracy: 0.8220
# Epoch 186/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4479 - accuracy: 0.8120 - val_loss: 0.4426 - val_accuracy: 0.8060
# Epoch 187/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4476 - accuracy: 0.7900 - val_loss: 0.4415 - val_accuracy: 0.8200
# Epoch 188/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4419 - accuracy: 0.8140 - val_loss: 0.4440 - val_accuracy: 0.8160
# Epoch 189/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4400 - accuracy: 0.7960 - val_loss: 0.4423 - val_accuracy: 0.8260
# Epoch 190/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4396 - accuracy: 0.8020 - val_loss: 0.4413 - val_accuracy: 0.8160
# Epoch 191/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4420 - accuracy: 0.8200 - val_loss: 0.4398 - val_accuracy: 0.8200
# Epoch 192/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4448 - accuracy: 0.7920 - val_loss: 0.4435 - val_accuracy: 0.8280
# Epoch 193/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4428 - accuracy: 0.8080 - val_loss: 0.4405 - val_accuracy: 0.8120
# Epoch 194/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4405 - accuracy: 0.8120 - val_loss: 0.4426 - val_accuracy: 0.8260
# Epoch 195/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4396 - accuracy: 0.8140 - val_loss: 0.4404 - val_accuracy: 0.8160
# Epoch 196/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4389 - accuracy: 0.7980 - val_loss: 0.4397 - val_accuracy: 0.8260
# Epoch 197/500
# 500/500 [==============================] - 0s 147us/sample - loss: 0.4409 - accuracy: 0.7960 - val_loss: 0.4400 - val_accuracy: 0.8180
# Epoch 198/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4393 - accuracy: 0.7960 - val_loss: 0.4388 - val_accuracy: 0.8260
# Epoch 199/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4381 - accuracy: 0.8080 - val_loss: 0.4442 - val_accuracy: 0.8040
# Epoch 200/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4389 - accuracy: 0.8120 - val_loss: 0.4404 - val_accuracy: 0.8300
# Epoch 201/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4415 - accuracy: 0.7940 - val_loss: 0.4438 - val_accuracy: 0.8100
# Epoch 202/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4400 - accuracy: 0.8240 - val_loss: 0.4387 - val_accuracy: 0.8080
# Epoch 203/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4408 - accuracy: 0.8000 - val_loss: 0.4424 - val_accuracy: 0.8160
# Epoch 204/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4371 - accuracy: 0.8060 - val_loss: 0.4396 - val_accuracy: 0.8240
# Epoch 205/500
# 500/500 [==============================] - 0s 148us/sample - loss: 0.4392 - accuracy: 0.8020 - val_loss: 0.4399 - val_accuracy: 0.8120
# Epoch 206/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4370 - accuracy: 0.8060 - val_loss: 0.4374 - val_accuracy: 0.8200
# Epoch 207/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4390 - accuracy: 0.7940 - val_loss: 0.4392 - val_accuracy: 0.8160
# Epoch 208/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4367 - accuracy: 0.8120 - val_loss: 0.4385 - val_accuracy: 0.8200
# Epoch 209/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4421 - accuracy: 0.8020 - val_loss: 0.4399 - val_accuracy: 0.8060
# Epoch 210/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4378 - accuracy: 0.8000 - val_loss: 0.4404 - val_accuracy: 0.8240
# Epoch 211/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4378 - accuracy: 0.8040 - val_loss: 0.4379 - val_accuracy: 0.8200
# Epoch 212/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4385 - accuracy: 0.8020 - val_loss: 0.4380 - val_accuracy: 0.8220
# Epoch 213/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4389 - accuracy: 0.7960 - val_loss: 0.4419 - val_accuracy: 0.8180
# Epoch 214/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4350 - accuracy: 0.8080 - val_loss: 0.4363 - val_accuracy: 0.8260
# Epoch 215/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4381 - accuracy: 0.7980 - val_loss: 0.4368 - val_accuracy: 0.8260
# Epoch 216/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4389 - accuracy: 0.8220 - val_loss: 0.4376 - val_accuracy: 0.8200
# Epoch 217/500
# 500/500 [==============================] - 0s 154us/sample - loss: 0.4361 - accuracy: 0.7900 - val_loss: 0.4378 - val_accuracy: 0.8240
# Epoch 218/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4380 - accuracy: 0.8140 - val_loss: 0.4386 - val_accuracy: 0.8200
# Epoch 219/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4366 - accuracy: 0.7920 - val_loss: 0.4378 - val_accuracy: 0.8180
# Epoch 220/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4368 - accuracy: 0.8040 - val_loss: 0.4356 - val_accuracy: 0.8220
# Epoch 221/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4370 - accuracy: 0.8080 - val_loss: 0.4386 - val_accuracy: 0.8280
# Epoch 222/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4355 - accuracy: 0.8040 - val_loss: 0.4359 - val_accuracy: 0.8140
# Epoch 223/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4368 - accuracy: 0.7980 - val_loss: 0.4395 - val_accuracy: 0.8160
# Epoch 224/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4382 - accuracy: 0.8180 - val_loss: 0.4357 - val_accuracy: 0.8220
# Epoch 225/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4365 - accuracy: 0.8080 - val_loss: 0.4387 - val_accuracy: 0.8160
# Epoch 226/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4386 - accuracy: 0.8000 - val_loss: 0.4360 - val_accuracy: 0.8280
# Epoch 227/500
# 500/500 [==============================] - 0s 149us/sample - loss: 0.4354 - accuracy: 0.8100 - val_loss: 0.4381 - val_accuracy: 0.8120
# Epoch 228/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4350 - accuracy: 0.8160 - val_loss: 0.4358 - val_accuracy: 0.8260
# Epoch 229/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4416 - accuracy: 0.7880 - val_loss: 0.4384 - val_accuracy: 0.8100
# Epoch 230/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4423 - accuracy: 0.8220 - val_loss: 0.4374 - val_accuracy: 0.8220
# Epoch 231/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4408 - accuracy: 0.7840 - val_loss: 0.4341 - val_accuracy: 0.8280
# Epoch 232/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4412 - accuracy: 0.8100 - val_loss: 0.4374 - val_accuracy: 0.8180
# Epoch 233/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4365 - accuracy: 0.7920 - val_loss: 0.4360 - val_accuracy: 0.8280
# Epoch 234/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4397 - accuracy: 0.7960 - val_loss: 0.4380 - val_accuracy: 0.8220
# Epoch 235/500
# 500/500 [==============================] - 0s 150us/sample - loss: 0.4359 - accuracy: 0.8060 - val_loss: 0.4396 - val_accuracy: 0.7980
# Epoch 236/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4349 - accuracy: 0.8060 - val_loss: 0.4360 - val_accuracy: 0.8260
# Epoch 237/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4353 - accuracy: 0.8060 - val_loss: 0.4345 - val_accuracy: 0.8280
# Epoch 238/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4364 - accuracy: 0.7940 - val_loss: 0.4364 - val_accuracy: 0.8140
# Epoch 239/500
# 500/500 [==============================] - 0s 114us/sample - loss: 0.4351 - accuracy: 0.8100 - val_loss: 0.4357 - val_accuracy: 0.8220
# Epoch 240/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4336 - accuracy: 0.8100 - val_loss: 0.4332 - val_accuracy: 0.8140
# Epoch 241/500
# 500/500 [==============================] - 0s 169us/sample - loss: 0.4390 - accuracy: 0.7960 - val_loss: 0.4347 - val_accuracy: 0.8240
# Epoch 242/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4358 - accuracy: 0.8140 - val_loss: 0.4364 - val_accuracy: 0.8120
# Epoch 243/500
# 500/500 [==============================] - 0s 144us/sample - loss: 0.4322 - accuracy: 0.8000 - val_loss: 0.4339 - val_accuracy: 0.8260
# Epoch 244/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4351 - accuracy: 0.7980 - val_loss: 0.4362 - val_accuracy: 0.8080
# Epoch 245/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4354 - accuracy: 0.8260 - val_loss: 0.4356 - val_accuracy: 0.8260
# Epoch 246/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4357 - accuracy: 0.8040 - val_loss: 0.4356 - val_accuracy: 0.8140
# Epoch 247/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4328 - accuracy: 0.7940 - val_loss: 0.4336 - val_accuracy: 0.8220
# Epoch 248/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4321 - accuracy: 0.8040 - val_loss: 0.4358 - val_accuracy: 0.8180
# Epoch 249/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4352 - accuracy: 0.8100 - val_loss: 0.4320 - val_accuracy: 0.8260
# Epoch 250/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4330 - accuracy: 0.8060 - val_loss: 0.4362 - val_accuracy: 0.8240
# Epoch 251/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4323 - accuracy: 0.8020 - val_loss: 0.4338 - val_accuracy: 0.8220
# Epoch 252/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4346 - accuracy: 0.8100 - val_loss: 0.4337 - val_accuracy: 0.8260
# Epoch 253/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4339 - accuracy: 0.8040 - val_loss: 0.4350 - val_accuracy: 0.8180
# Epoch 254/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4346 - accuracy: 0.7980 - val_loss: 0.4352 - val_accuracy: 0.8180
# Epoch 255/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4327 - accuracy: 0.8140 - val_loss: 0.4311 - val_accuracy: 0.8180
# Epoch 256/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4355 - accuracy: 0.7940 - val_loss: 0.4357 - val_accuracy: 0.8180
# Epoch 257/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4332 - accuracy: 0.8100 - val_loss: 0.4337 - val_accuracy: 0.8240
# Epoch 258/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4316 - accuracy: 0.7920 - val_loss: 0.4319 - val_accuracy: 0.8200
# Epoch 259/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4320 - accuracy: 0.8020 - val_loss: 0.4346 - val_accuracy: 0.8160
# Epoch 260/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4322 - accuracy: 0.8240 - val_loss: 0.4326 - val_accuracy: 0.8260
# Epoch 261/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4321 - accuracy: 0.7920 - val_loss: 0.4317 - val_accuracy: 0.8260
# Epoch 262/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4330 - accuracy: 0.8140 - val_loss: 0.4336 - val_accuracy: 0.8220
# Epoch 263/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4310 - accuracy: 0.7960 - val_loss: 0.4322 - val_accuracy: 0.8240
# Epoch 264/500
# 500/500 [==============================] - 0s 148us/sample - loss: 0.4294 - accuracy: 0.8020 - val_loss: 0.4351 - val_accuracy: 0.8040
# Epoch 265/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4320 - accuracy: 0.7980 - val_loss: 0.4327 - val_accuracy: 0.8220
# Epoch 266/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4319 - accuracy: 0.7980 - val_loss: 0.4312 - val_accuracy: 0.8240
# Epoch 267/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4289 - accuracy: 0.8140 - val_loss: 0.4322 - val_accuracy: 0.8200
# Epoch 268/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4323 - accuracy: 0.8000 - val_loss: 0.4300 - val_accuracy: 0.8260
# Epoch 269/500
# 500/500 [==============================] - 0s 155us/sample - loss: 0.4312 - accuracy: 0.8060 - val_loss: 0.4320 - val_accuracy: 0.8240
# Epoch 270/500
# 500/500 [==============================] - 0s 143us/sample - loss: 0.4318 - accuracy: 0.7980 - val_loss: 0.4305 - val_accuracy: 0.8260
# Epoch 271/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4309 - accuracy: 0.8120 - val_loss: 0.4308 - val_accuracy: 0.8220
# Epoch 272/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4312 - accuracy: 0.8020 - val_loss: 0.4307 - val_accuracy: 0.8260
# Epoch 273/500
# 500/500 [==============================] - 0s 142us/sample - loss: 0.4319 - accuracy: 0.8040 - val_loss: 0.4328 - val_accuracy: 0.8240
# Epoch 274/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4321 - accuracy: 0.8140 - val_loss: 0.4304 - val_accuracy: 0.8240
# Epoch 275/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4324 - accuracy: 0.7980 - val_loss: 0.4306 - val_accuracy: 0.8160
# Epoch 276/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4288 - accuracy: 0.8080 - val_loss: 0.4339 - val_accuracy: 0.8280
# Epoch 277/500
# 500/500 [==============================] - 0s 143us/sample - loss: 0.4340 - accuracy: 0.8080 - val_loss: 0.4296 - val_accuracy: 0.8260
# Epoch 278/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4313 - accuracy: 0.8060 - val_loss: 0.4303 - val_accuracy: 0.8160
# Epoch 279/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4296 - accuracy: 0.8100 - val_loss: 0.4328 - val_accuracy: 0.8240
# Epoch 280/500
# 500/500 [==============================] - 0s 147us/sample - loss: 0.4316 - accuracy: 0.8040 - val_loss: 0.4358 - val_accuracy: 0.8080
# Epoch 281/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4362 - accuracy: 0.8180 - val_loss: 0.4303 - val_accuracy: 0.8200
# Epoch 282/500
# 500/500 [==============================] - 0s 156us/sample - loss: 0.4290 - accuracy: 0.8020 - val_loss: 0.4333 - val_accuracy: 0.8120
# Epoch 283/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4332 - accuracy: 0.7980 - val_loss: 0.4288 - val_accuracy: 0.8280
# Epoch 284/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4302 - accuracy: 0.8000 - val_loss: 0.4311 - val_accuracy: 0.8160
# Epoch 285/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4286 - accuracy: 0.8080 - val_loss: 0.4294 - val_accuracy: 0.8200
# Epoch 286/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4368 - accuracy: 0.8040 - val_loss: 0.4303 - val_accuracy: 0.8280
# Epoch 287/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4325 - accuracy: 0.8020 - val_loss: 0.4320 - val_accuracy: 0.8180
# Epoch 288/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4279 - accuracy: 0.8000 - val_loss: 0.4296 - val_accuracy: 0.8240
# Epoch 289/500
# 500/500 [==============================] - 0s 157us/sample - loss: 0.4381 - accuracy: 0.8020 - val_loss: 0.4325 - val_accuracy: 0.8160
# Epoch 290/500
# 500/500 [==============================] - 0s 154us/sample - loss: 0.4309 - accuracy: 0.8060 - val_loss: 0.4322 - val_accuracy: 0.8160
# Epoch 291/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4310 - accuracy: 0.8020 - val_loss: 0.4332 - val_accuracy: 0.8200
# Epoch 292/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4353 - accuracy: 0.8080 - val_loss: 0.4281 - val_accuracy: 0.8180
# Epoch 293/500
# 500/500 [==============================] - 0s 140us/sample - loss: 0.4377 - accuracy: 0.7980 - val_loss: 0.4350 - val_accuracy: 0.8180
# Epoch 294/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4318 - accuracy: 0.7980 - val_loss: 0.4263 - val_accuracy: 0.8180
# Epoch 295/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4304 - accuracy: 0.8180 - val_loss: 0.4305 - val_accuracy: 0.8240
# Epoch 296/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4336 - accuracy: 0.7960 - val_loss: 0.4275 - val_accuracy: 0.8180
# Epoch 297/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4335 - accuracy: 0.8020 - val_loss: 0.4315 - val_accuracy: 0.8240
# Epoch 298/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4315 - accuracy: 0.8040 - val_loss: 0.4284 - val_accuracy: 0.8220
# Epoch 299/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4311 - accuracy: 0.7920 - val_loss: 0.4310 - val_accuracy: 0.8200
# Epoch 300/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4320 - accuracy: 0.8280 - val_loss: 0.4284 - val_accuracy: 0.8240
# Epoch 301/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4301 - accuracy: 0.8020 - val_loss: 0.4273 - val_accuracy: 0.8220
# Epoch 302/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4259 - accuracy: 0.7920 - val_loss: 0.4269 - val_accuracy: 0.8260
# Epoch 303/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4263 - accuracy: 0.8080 - val_loss: 0.4296 - val_accuracy: 0.8200
# Epoch 304/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4292 - accuracy: 0.8140 - val_loss: 0.4283 - val_accuracy: 0.8280
# Epoch 305/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4306 - accuracy: 0.7960 - val_loss: 0.4277 - val_accuracy: 0.8220
# Epoch 306/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4302 - accuracy: 0.8000 - val_loss: 0.4324 - val_accuracy: 0.8120
# Epoch 307/500
# 500/500 [==============================] - 0s 149us/sample - loss: 0.4323 - accuracy: 0.8240 - val_loss: 0.4281 - val_accuracy: 0.8200
# Epoch 308/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4322 - accuracy: 0.7960 - val_loss: 0.4293 - val_accuracy: 0.8160
# Epoch 309/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4303 - accuracy: 0.8120 - val_loss: 0.4264 - val_accuracy: 0.8200
# Epoch 310/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4284 - accuracy: 0.8200 - val_loss: 0.4306 - val_accuracy: 0.8140
# Epoch 311/500
# 500/500 [==============================] - 0s 153us/sample - loss: 0.4283 - accuracy: 0.8080 - val_loss: 0.4283 - val_accuracy: 0.8220
# Epoch 312/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4281 - accuracy: 0.8020 - val_loss: 0.4269 - val_accuracy: 0.8240
# Epoch 313/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4328 - accuracy: 0.8120 - val_loss: 0.4259 - val_accuracy: 0.8240
# Epoch 314/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4288 - accuracy: 0.7920 - val_loss: 0.4284 - val_accuracy: 0.8140
# Epoch 315/500
# 500/500 [==============================] - 0s 146us/sample - loss: 0.4272 - accuracy: 0.8100 - val_loss: 0.4274 - val_accuracy: 0.8260
# Epoch 316/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4262 - accuracy: 0.8100 - val_loss: 0.4294 - val_accuracy: 0.8140
# Epoch 317/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4340 - accuracy: 0.8200 - val_loss: 0.4270 - val_accuracy: 0.8220
# Epoch 318/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4282 - accuracy: 0.7980 - val_loss: 0.4263 - val_accuracy: 0.8240
# Epoch 319/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4265 - accuracy: 0.7900 - val_loss: 0.4259 - val_accuracy: 0.8200
# Epoch 320/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4333 - accuracy: 0.8140 - val_loss: 0.4291 - val_accuracy: 0.8260
# Epoch 321/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4254 - accuracy: 0.7920 - val_loss: 0.4283 - val_accuracy: 0.8100
# Epoch 322/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4295 - accuracy: 0.8120 - val_loss: 0.4266 - val_accuracy: 0.8260
# Epoch 323/500
# ...
# Epoch 394/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4192 - accuracy: 0.8160 - val_loss: 0.4223 - val_accuracy: 0.8220
# Epoch 395/500
# 500/500 [==============================] - 0s 144us/sample - loss: 0.4234 - accuracy: 0.8000 - val_loss: 0.4216 - val_accuracy: 0.8220
# Epoch 396/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4216 - accuracy: 0.8080 - val_loss: 0.4191 - val_accuracy: 0.8240
# Epoch 397/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4193 - accuracy: 0.8040 - val_loss: 0.4242 - val_accuracy: 0.8240
# Epoch 398/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4206 - accuracy: 0.8100 - val_loss: 0.4197 - val_accuracy: 0.8200
# Epoch 399/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4192 - accuracy: 0.8120 - val_loss: 0.4242 - val_accuracy: 0.8340
# Epoch 400/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4182 - accuracy: 0.8140 - val_loss: 0.4240 - val_accuracy: 0.8180
# Epoch 401/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4189 - accuracy: 0.8100 - val_loss: 0.4225 - val_accuracy: 0.8280
# Epoch 402/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4200 - accuracy: 0.8020 - val_loss: 0.4237 - val_accuracy: 0.8180
# Epoch 403/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4229 - accuracy: 0.8220 - val_loss: 0.4220 - val_accuracy: 0.8240
# Epoch 404/500
# 500/500 [==============================] - 0s 114us/sample - loss: 0.4227 - accuracy: 0.8060 - val_loss: 0.4226 - val_accuracy: 0.8240
# Epoch 405/500
# 500/500 [==============================] - 0s 114us/sample - loss: 0.4202 - accuracy: 0.8040 - val_loss: 0.4210 - val_accuracy: 0.8220
# Epoch 406/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4193 - accuracy: 0.8260 - val_loss: 0.4195 - val_accuracy: 0.8280
# Epoch 407/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4193 - accuracy: 0.8000 - val_loss: 0.4229 - val_accuracy: 0.8260
# Epoch 408/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4207 - accuracy: 0.8260 - val_loss: 0.4242 - val_accuracy: 0.8280
# Epoch 409/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4304 - accuracy: 0.7940 - val_loss: 0.4191 - val_accuracy: 0.8240
# Epoch 410/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4254 - accuracy: 0.8060 - val_loss: 0.4172 - val_accuracy: 0.8220
# Epoch 411/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4229 - accuracy: 0.8040 - val_loss: 0.4223 - val_accuracy: 0.8240
# Epoch 412/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4199 - accuracy: 0.8220 - val_loss: 0.4185 - val_accuracy: 0.8200
# Epoch 413/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4187 - accuracy: 0.8120 - val_loss: 0.4217 - val_accuracy: 0.8240
# Epoch 414/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4232 - accuracy: 0.8040 - val_loss: 0.4206 - val_accuracy: 0.8220
# Epoch 415/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4170 - accuracy: 0.8180 - val_loss: 0.4209 - val_accuracy: 0.8280
# Epoch 416/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4275 - accuracy: 0.8160 - val_loss: 0.4249 - val_accuracy: 0.8160
# Epoch 417/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4211 - accuracy: 0.8020 - val_loss: 0.4198 - val_accuracy: 0.8260
# Epoch 418/500
# 500/500 [==============================] - 0s 138us/sample - loss: 0.4200 - accuracy: 0.8180 - val_loss: 0.4166 - val_accuracy: 0.8240
# Epoch 419/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4242 - accuracy: 0.8060 - val_loss: 0.4274 - val_accuracy: 0.8120
# Epoch 420/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4205 - accuracy: 0.8300 - val_loss: 0.4206 - val_accuracy: 0.8260
# Epoch 421/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4212 - accuracy: 0.8040 - val_loss: 0.4186 - val_accuracy: 0.8260
# Epoch 422/500
# 500/500 [==============================] - 0s 139us/sample - loss: 0.4170 - accuracy: 0.8180 - val_loss: 0.4190 - val_accuracy: 0.8280
# Epoch 423/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4219 - accuracy: 0.8020 - val_loss: 0.4198 - val_accuracy: 0.8220
# Epoch 424/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4275 - accuracy: 0.8040 - val_loss: 0.4201 - val_accuracy: 0.8280
# Epoch 425/500
# 500/500 [==============================] - 0s 152us/sample - loss: 0.4227 - accuracy: 0.8160 - val_loss: 0.4180 - val_accuracy: 0.8220
# Epoch 426/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4361 - accuracy: 0.7960 - val_loss: 0.4295 - val_accuracy: 0.8080
# Epoch 427/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4303 - accuracy: 0.7920 - val_loss: 0.4185 - val_accuracy: 0.8280
# Epoch 428/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4205 - accuracy: 0.8300 - val_loss: 0.4214 - val_accuracy: 0.8180
# Epoch 429/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4323 - accuracy: 0.7820 - val_loss: 0.4228 - val_accuracy: 0.8200
# Epoch 430/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4193 - accuracy: 0.8060 - val_loss: 0.4171 - val_accuracy: 0.8260
# Epoch 431/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4254 - accuracy: 0.8060 - val_loss: 0.4174 - val_accuracy: 0.8300
# Epoch 432/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4171 - accuracy: 0.8080 - val_loss: 0.4235 - val_accuracy: 0.8240
# Epoch 433/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4207 - accuracy: 0.8100 - val_loss: 0.4215 - val_accuracy: 0.8220
# Epoch 434/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4150 - accuracy: 0.8080 - val_loss: 0.4159 - val_accuracy: 0.8200
# Epoch 435/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4207 - accuracy: 0.8160 - val_loss: 0.4181 - val_accuracy: 0.8260
# Epoch 436/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4171 - accuracy: 0.8140 - val_loss: 0.4186 - val_accuracy: 0.8260
# Epoch 437/500
# 500/500 [==============================] - 0s 141us/sample - loss: 0.4181 - accuracy: 0.8060 - val_loss: 0.4166 - val_accuracy: 0.8260
# Epoch 438/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4204 - accuracy: 0.8140 - val_loss: 0.4173 - val_accuracy: 0.8220
# Epoch 439/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4181 - accuracy: 0.8220 - val_loss: 0.4189 - val_accuracy: 0.8300
# Epoch 440/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4193 - accuracy: 0.8060 - val_loss: 0.4210 - val_accuracy: 0.8200
# Epoch 441/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4189 - accuracy: 0.8060 - val_loss: 0.4162 - val_accuracy: 0.8240
# Epoch 442/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4198 - accuracy: 0.8100 - val_loss: 0.4174 - val_accuracy: 0.8260
# Epoch 443/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4180 - accuracy: 0.8040 - val_loss: 0.4180 - val_accuracy: 0.8280
# Epoch 444/500
# 500/500 [==============================] - 0s 112us/sample - loss: 0.4189 - accuracy: 0.8040 - val_loss: 0.4163 - val_accuracy: 0.8240
# Epoch 445/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4199 - accuracy: 0.8100 - val_loss: 0.4155 - val_accuracy: 0.8280
# Epoch 446/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4216 - accuracy: 0.8020 - val_loss: 0.4164 - val_accuracy: 0.8220
# Epoch 447/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4176 - accuracy: 0.8040 - val_loss: 0.4248 - val_accuracy: 0.8140
# Epoch 448/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4199 - accuracy: 0.8080 - val_loss: 0.4176 - val_accuracy: 0.8260
# Epoch 449/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4159 - accuracy: 0.7980 - val_loss: 0.4170 - val_accuracy: 0.8280
# Epoch 450/500
# 500/500 [==============================] - 0s 132us/sample - loss: 0.4182 - accuracy: 0.8140 - val_loss: 0.4174 - val_accuracy: 0.8220
# Epoch 451/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4157 - accuracy: 0.8080 - val_loss: 0.4174 - val_accuracy: 0.8240
# Epoch 452/500
# 500/500 [==============================] - 0s 118us/sample - loss: 0.4167 - accuracy: 0.8120 - val_loss: 0.4160 - val_accuracy: 0.8180
# Epoch 453/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4238 - accuracy: 0.8020 - val_loss: 0.4270 - val_accuracy: 0.8180
# Epoch 454/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4259 - accuracy: 0.8140 - val_loss: 0.4205 - val_accuracy: 0.8240
# Epoch 455/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4228 - accuracy: 0.8040 - val_loss: 0.4166 - val_accuracy: 0.8240
# Epoch 456/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4185 - accuracy: 0.8040 - val_loss: 0.4186 - val_accuracy: 0.8260
# Epoch 457/500
# 500/500 [==============================] - 0s 136us/sample - loss: 0.4182 - accuracy: 0.8020 - val_loss: 0.4160 - val_accuracy: 0.8280
# Epoch 458/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4190 - accuracy: 0.8040 - val_loss: 0.4136 - val_accuracy: 0.8240
# Epoch 459/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4205 - accuracy: 0.8120 - val_loss: 0.4249 - val_accuracy: 0.8280
# Epoch 460/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4182 - accuracy: 0.8080 - val_loss: 0.4238 - val_accuracy: 0.8200
# Epoch 461/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4161 - accuracy: 0.8080 - val_loss: 0.4187 - val_accuracy: 0.8260
# Epoch 462/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4213 - accuracy: 0.8020 - val_loss: 0.4215 - val_accuracy: 0.8240
# Epoch 463/500
# 500/500 [==============================] - 0s 133us/sample - loss: 0.4203 - accuracy: 0.8060 - val_loss: 0.4144 - val_accuracy: 0.8260
# Epoch 464/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4199 - accuracy: 0.8040 - val_loss: 0.4210 - val_accuracy: 0.8340
# Epoch 465/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4216 - accuracy: 0.8060 - val_loss: 0.4144 - val_accuracy: 0.8240
# Epoch 466/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4198 - accuracy: 0.8200 - val_loss: 0.4253 - val_accuracy: 0.8160
# Epoch 467/500
# 500/500 [==============================] - 0s 144us/sample - loss: 0.4248 - accuracy: 0.7980 - val_loss: 0.4245 - val_accuracy: 0.8120
# Epoch 468/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4250 - accuracy: 0.7880 - val_loss: 0.4166 - val_accuracy: 0.8260
# Epoch 469/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4262 - accuracy: 0.8100 - val_loss: 0.4157 - val_accuracy: 0.8280
# Epoch 470/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4171 - accuracy: 0.8100 - val_loss: 0.4131 - val_accuracy: 0.8260
# Epoch 471/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4175 - accuracy: 0.8000 - val_loss: 0.4155 - val_accuracy: 0.8280
# Epoch 472/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4151 - accuracy: 0.8040 - val_loss: 0.4211 - val_accuracy: 0.8180
# Epoch 473/500
# 500/500 [==============================] - 0s 125us/sample - loss: 0.4172 - accuracy: 0.8140 - val_loss: 0.4180 - val_accuracy: 0.8260
# Epoch 474/500
# 500/500 [==============================] - 0s 128us/sample - loss: 0.4132 - accuracy: 0.8060 - val_loss: 0.4148 - val_accuracy: 0.8280
# Epoch 475/500
# 500/500 [==============================] - 0s 131us/sample - loss: 0.4147 - accuracy: 0.8160 - val_loss: 0.4120 - val_accuracy: 0.8240
# Epoch 476/500
# 500/500 [==============================] - 0s 129us/sample - loss: 0.4165 - accuracy: 0.8040 - val_loss: 0.4171 - val_accuracy: 0.8240
# Epoch 477/500
# 500/500 [==============================] - 0s 124us/sample - loss: 0.4163 - accuracy: 0.7960 - val_loss: 0.4177 - val_accuracy: 0.8180
# Epoch 478/500
# 500/500 [==============================] - 0s 137us/sample - loss: 0.4173 - accuracy: 0.8220 - val_loss: 0.4138 - val_accuracy: 0.8240
# Epoch 479/500
# 500/500 [==============================] - 0s 134us/sample - loss: 0.4151 - accuracy: 0.8120 - val_loss: 0.4195 - val_accuracy: 0.8220
# Epoch 480/500
# 500/500 [==============================] - 0s 126us/sample - loss: 0.4183 - accuracy: 0.8040 - val_loss: 0.4181 - val_accuracy: 0.8300
# Epoch 481/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4183 - accuracy: 0.8100 - val_loss: 0.4183 - val_accuracy: 0.8220
# Epoch 482/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4152 - accuracy: 0.8080 - val_loss: 0.4176 - val_accuracy: 0.8280
# Epoch 483/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4171 - accuracy: 0.8060 - val_loss: 0.4221 - val_accuracy: 0.8180
# Epoch 484/500
# 500/500 [==============================] - 0s 135us/sample - loss: 0.4184 - accuracy: 0.8140 - val_loss: 0.4159 - val_accuracy: 0.8200
# Epoch 485/500
# 500/500 [==============================] - 0s 130us/sample - loss: 0.4130 - accuracy: 0.8020 - val_loss: 0.4174 - val_accuracy: 0.8200
# Epoch 486/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4190 - accuracy: 0.8060 - val_loss: 0.4133 - val_accuracy: 0.8240
# Epoch 487/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4143 - accuracy: 0.8160 - val_loss: 0.4158 - val_accuracy: 0.8180
# Epoch 488/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4168 - accuracy: 0.8160 - val_loss: 0.4158 - val_accuracy: 0.8320
# Epoch 489/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4184 - accuracy: 0.8020 - val_loss: 0.4136 - val_accuracy: 0.8260
# Epoch 490/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4281 - accuracy: 0.8240 - val_loss: 0.4209 - val_accuracy: 0.8220
# Epoch 491/500
# 500/500 [==============================] - 0s 121us/sample - loss: 0.4238 - accuracy: 0.8040 - val_loss: 0.4205 - val_accuracy: 0.8140
# Epoch 492/500
# 500/500 [==============================] - 0s 113us/sample - loss: 0.4149 - accuracy: 0.7960 - val_loss: 0.4133 - val_accuracy: 0.8280
# Epoch 493/500
# 500/500 [==============================] - 0s 116us/sample - loss: 0.4135 - accuracy: 0.8020 - val_loss: 0.4147 - val_accuracy: 0.8200
# Epoch 494/500
# 500/500 [==============================] - 0s 115us/sample - loss: 0.4146 - accuracy: 0.8260 - val_loss: 0.4184 - val_accuracy: 0.8280
# Epoch 495/500
# 500/500 [==============================] - 0s 122us/sample - loss: 0.4201 - accuracy: 0.7960 - val_loss: 0.4176 - val_accuracy: 0.8200
# Epoch 496/500
# 500/500 [==============================] - 0s 120us/sample - loss: 0.4194 - accuracy: 0.8160 - val_loss: 0.4164 - val_accuracy: 0.8300
# Epoch 497/500
# 500/500 [==============================] - 0s 123us/sample - loss: 0.4154 - accuracy: 0.8120 - val_loss: 0.4127 - val_accuracy: 0.8280
# Epoch 498/500
# 500/500 [==============================] - 0s 127us/sample - loss: 0.4218 - accuracy: 0.8120 - val_loss: 0.4195 - val_accuracy: 0.8200
# Epoch 499/500
# 500/500 [==============================] - 0s 119us/sample - loss: 0.4263 - accuracy: 0.7980 - val_loss: 0.4209 - val_accuracy: 0.8180
# Epoch 500/500
# 500/500 [==============================] - 0s 117us/sample - loss: 0.4115 - accuracy: 0.8100 - val_loss: 0.4165 - val_accuracy: 0.8260

# %%
# evaluate the model
_, train_acc = modelA.evaluate(train_X, train_y, verbose=0)
_, test_acc = modelA.evaluate(test_X, test_y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 0.802, Test: 0.826

# %%
y_pred=modelA.predict_classes(X)

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1], label=str(0)) # extacción puntos según clase (0)
plt.scatter(X[y == 1, 0], X[y == 1, 1], label=str(1)) # extacción puntos según clase (1)

plt.legend()
plt.show()

# %%
y_pred=y_pred.reshape((-1))
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], label=str(0)) # extacción puntos según clase (0)
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], label=str(1)) # extacción puntos según clase (1)

plt.legend()
plt.show()

# %% [markdown]
# ### Creación de un modelo más profundo con fución de activación tanh:
#
# Veamos ahora cómo un modelo de una red neuronal más profunda, genera un modelo menos predictivo devido al problema del desvanecimiento del gradiente. La red consta de una capa de entrada con un a función de activación `tanh`, y 4 capas ocultas, también definidas con una función de activación `tanh`, y una capa de salida con una función de activación `sigmoid`.

# %%
keras.backend.clear_session()

# define model
init = keras.initializers.RandomUniform(minval=0, maxval=1)
modelB = keras.models.Sequential()
modelB.add(keras.layers.Dense(5, input_dim=2, activation='tanh', kernel_initializer=init))
modelB.add(keras.layers.Dense(5, activation='tanh', kernel_initializer=init))
modelB.add(keras.layers.Dense(5, activation='tanh', kernel_initializer=init))
modelB.add(keras.layers.Dense(5, activation='tanh', kernel_initializer=init))
modelB.add(keras.layers.Dense(5, activation='tanh', kernel_initializer=init))
modelB.add(keras.layers.Dense(1, activation='sigmoid', kernel_initializer=init))
# compile model
opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
modelB.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# fit model
history = modelB.fit(train_X, train_y, validation_data=(test_X, test_y), epochs=500, verbose=0)
# evaluate the model
_, train_acc = modelB.evaluate(train_X, train_y, verbose=0)
_, test_acc = modelB.evaluate(test_X, test_y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 0.532, Test: 0.484

# %%
y_pred=modelB.predict_classes(X)

# %%
y_pred=y_pred.reshape((-1))
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], label=str(0)) # extacción puntos según clase (0)
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], label=str(1)) # extacción puntos según clase (1)

plt.legend()
plt.show()

# %% [markdown]
# ### Creación de un modelo más profundo con fución de activación ReLU:
#
# Ilustremos ahora cómo, con el simple hecho de cambiar las función de activación de la capa de entrada y las capas ocultas del anterior modelo por una función de activación `ReLU`, se mejora el problema del desvanecimiento del gradiente:

# %%
keras.backend.clear_session()

# define model
modelC = keras.models.Sequential()
modelC.add(keras.layers.Dense(5, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
modelC.add(keras.layers.Dense(5, activation='relu', kernel_initializer='he_uniform'))
modelC.add(keras.layers.Dense(5, activation='relu', kernel_initializer='he_uniform'))
modelC.add(keras.layers.Dense(5, activation='relu', kernel_initializer='he_uniform'))
modelC.add(keras.layers.Dense(5, activation='relu', kernel_initializer='he_uniform'))
modelC.add(keras.layers.Dense(1, activation='sigmoid'))
# compile model
opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
modelC.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# fit model
history = modelC.fit(train_X, train_y, validation_data=(test_X, test_y), epochs=500, verbose=0)
# evaluate the model
_, train_acc = modelC.evaluate(train_X, train_y, verbose=0)
_, test_acc = modelC.evaluate(test_X, test_y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 0.836, Test: 0.850

# %%
y_pred=modelC.predict_classes(X)
y_pred=y_pred.reshape((-1))
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], label=str(0)) # extacción puntos según clase (0)
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], label=str(1)) # extacción puntos según clase (1)

plt.legend()
plt.show()

# %% [markdown]
# Finalmente, veamos que las funciones de activación `SeLU`, también  ayudan a resolver el problema del desvanecimiento/explosión del gradiente:

# %%
keras.backend.clear_session()

# define model
modelE = keras.models.Sequential()
modelE.add(keras.layers.Dense(5, input_dim=2, activation='selu', kernel_initializer='lecun_normal'))
modelE.add(keras.layers.Dense(5, activation='selu', kernel_initializer='lecun_normal'))
modelE.add(keras.layers.Dense(5, activation='selu', kernel_initializer='lecun_normal'))
modelE.add(keras.layers.Dense(5, activation='selu', kernel_initializer='lecun_normal'))
modelE.add(keras.layers.Dense(5, activation='selu', kernel_initializer='lecun_normal'))
modelE.add(keras.layers.Dense(1, activation='sigmoid'))
# compile model
opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
modelE.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# fit model
history = modelE.fit(train_X, train_y, validation_data=(test_X, test_y), epochs=500, verbose=0)
# evaluate the model
_, train_acc = modelE.evaluate(train_X, train_y, verbose=0)
_, test_acc = modelE.evaluate(test_X, test_y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 0.828, Test: 0.844

# %% [markdown]
# # Recapitulación del problema del desvanecimiento/explosión del gradiente.
#
# Cuando se realiza la propagación hacia atrás, los gradientes a menudo se hacen cada vez más pequeños a medida que el algoritmo avanza hacia las capas inferiores. Como resultado, el algoritmo de Descenso de degradado deja los pesos de conexión de la capa inferior prácticamente sin cambios, y el entrenamiento nunca converge en una buena solución. Esto es lo que se conoce como Vanishing Gradients Problems. En algunos otros casos, puede suceder lo contrario: los gradientes pueden crecer más y más, por lo que muchas capas obtienen actualizaciones de peso increíblemente grandes y el algoritmo diverge. Esto es lo que se conoce como Exploding Gradients Problems.
#
#
# Aunque este comportamiento se ha observado empíricamente durante bastante tiempo (fue una de las razones por las que las redes neuronales profundas fueron abandonadas durante mucho tiempo), apenas alrededor de 2010 se logró un progreso significativo en su comprensión. Xavier Glorot y Yoshua Bengio descubrieron que el problema estaba en la combinación de la popular función de activación sigmoid (y tambien la hyperbolica aunque en menor medida) y la técnica de inicialización de pesos que era más popular en ese momento (la inicialización aleatoria usando una distribución normal con una media de 0 y un estándar desviación de 1).
#
# <p><img alt="Colaboratory logo" height="300px" src="https://i.imgur.com/Dbt0lIL.png" align="center" hspace="10px" vspace="0px"></p>

# %% [markdown]
# # Inicialización de Glorot and He
#
# Glorot y Bengio proponen una forma de aliviar significativamente este problema. Argumentan que necesitamos la varianza de la
# Las salidas de cada capa deben ser iguales a la varianza de sus entradas, y también necesitamos que los gradientes tengan la misma varianza antes y después de fluir a través de una capa en la dirección inversa. En realidad, no es posible garantizar ambos a menos que la capa tenga el mismo número de entradas y neuronas (que en general no es cierto), pero propusieron una buena solución que ha demostrado funcionar muy bien en la práctica: los pesos de cada capa (para el caso de la funcion de activacion sigmoid) deben inicializarse aleatoriamente como (Esta es la inicialización de Glorot):
#
# Distribución normal con media 0 y varianza
# \begin{equation}
# \sigma^2 = \frac{1}{fan_{avg}}
# \end{equation}
#
# O una distribución uniforme entre $−r$ and $+r$,
# \begin{equation}
# r = \sqrt{\frac{3}{fan_{avg}}} = \sqrt{3\sigma^2}
# \end{equation}
#
#
# donde
#
#
# * $fan_{avg} = \frac{1}{2} (fan_{in} + fan_{out})$
#
#
# * $fan_{in}$ es el numero de neuronas de entrada
#
# * $fan_{out}$ es el numero de neuronas de salida
#
#
# La estrategia de inicialización para la función de activación ReLUy sus variantes es (Esta es la inicialización de He) :
#
# Distribución normal con media 0 y varianza
# \begin{equation}
# \sigma^2 = \frac{2}{fan_{avg}}
# \end{equation}
#
# O una distribución uniforme entre $−r$ and $+r$,
# \begin{equation}
# r = \sqrt{\frac{6}{fan_{avg}}} = \sqrt{3\sigma^2}
# \end{equation}
#
# podemos resumir entonces la forma mas comun de inicialzar los pesos en la sigueinte tabla
#
# <p><img alt="Colaboratory logo" height="200px" src="https://i.imgur.com/hBQ26T3.png" align="center" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Por defecto, Keras usa la inicialización de Glorot con una distribución uniforme, pero esto puede ser cambiado. Veamos un ejemplo de como hacerlo

# %% [markdown]
# importemos algunas librerias que seran de utilidad

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()
from sklearn.datasets import make_circles

# %% [markdown]
# Resolveremos el problema de las dos espirales, para esto comencemos con crear las espirales

# %%
def twospirals(n_points, noise=0.5):
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(n_points),np.ones(n_points))))

# %%
X, y =  twospirals(1000, noise=0.8)
plt.figure(figsize=(7,7))
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter')

# %%
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import datetime, os
keras.backend.clear_session()

# %% [markdown]
# Dividamos los datos en un set de entrenamiento y otro de testeo

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %% [markdown]
# escalemos los datos

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
plt.figure(figsize=(7,7))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='winter')

# %%
X_train.shape
# Out:
# (1600, 2)

# %%
X_test.shape
# Out:
# (400, 2)

# %% [markdown]
# procedamos a construir nuestro modelo y a ilustrar como incializar los pesos de diferentes formas dependiendo la funcion de activacion

# %%
model = keras.models.Sequential([                                
                                keras.layers.Dense(40, activation='relu', kernel_initializer='he_normal',input_shape= (2,)),
                                keras.layers.Dense(12, activation='tanh',kernel_initializer='glorot_normal'),
                                keras.layers.Dense(40, activation='relu',kernel_initializer='he_uniform'),
                                keras.layers.Dense(12, activation='tanh',kernel_initializer='glorot_normal'),
                                keras.layers.Dense(1, activation='sigmoid', kernel_initializer='glorot_uniform')
                                ])
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train, epochs=200 ,verbose=0)

# %%
pd.DataFrame(history.history).plot(figsize=(7,7))

# %%
model.evaluate(X_test,y_test, verbose=0)
# Out:
# [0.38966559290885927, 0.9075]

# %%
y_fit =  model.predict_classes(X_test)

# %%
fig , ax = plt.subplots(1,2, figsize=(8,6))
ax[0].scatter(X_test[:,0], X_test[:,1], c=y_test, cmap='winter')
ax[0].set_title('true_model')
ax[1].scatter(X_test[:,0], X_test[:,1], c=y_fit[:,0], cmap='winter')
ax[1].set_title('predicted_model')
# Out:
# Text(0.5, 1.0, 'predicted_model')

# %% [markdown]
# Por defecto, Keras implementa la inicialización He con una distribución uniforme basada en $fan_{in}$. Si desea la inicialización de He con una distribución uniforme pero basada en $fan_{avg}$, puede usar el inicializador VarianceScaling de esta manera:

# %%
he_avg_init = keras.initializers.VarianceScaling(scale=2., mode='fan_avg', distribution='uniform')

# %% [markdown]
# mas informacion de la versatilidad a la hora de inicializar los pesos puede ser encontrado en https://keras.io/initializers/

# %% [markdown]
# # **Regularización**
#
# ### **Introducción**
# Muchas veces cuando entrenamos nuestro modelo y procedemos a validarlo, encontramos que este puede generalizar de una manera no totalmente correcta, es decir puede presentar overfitting. Como ya hemos visto existen multiples razones por las cuales esto se dé, poca cantidad de datos, una mala elección del modelo y su complejidad, entre otros.
#
# <p><img alt="Colaboratory logo" height="200px" src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/Screen-Shot-2018-04-03-at-7.52.01-PM-e1522832332857.png" align="center" hspace="10px" vspace="0px"></p>
#
#
# Una forma de evitar el overfitting es regularizando nuestro modelo, es decir poniendo ciertas restricciónes a nuestros parámetros de forma tal que se fuercen los parámetros a tomar valores pequeños, lo cual hará que la distribución de pesos sea más regular. Como se vió para regresiones, una de las formas de regularizar nuestro modelo era añadiendo un término a la función de costo, el cual de acuerdo a la forma de este, definía el tipo de regularización (**Ridge, lasso, Elasticnet**); o bien deteniendo el entrenamiento cuando el error de validación alcanzaba el mínimo, **Early stopping**.
#
#
#
# Veamos como se puede usar los diferentes tipos de regularización y como se puede realizar su implementación en redes neuronales profundas.
#
#
# ### **Regularización L1 y L2**
#
# Los métodos más simples de regularización son $l1$ y $l2$, los cuales consisten en añadir un término a nuestra función de costo, el cual dependerá de cual de los dos estemos usando, para así castigar los valores grandes de los parámetros en nuestra matriz de pesos y así restringirlos a pequeños valores. Esta tendra la siguiente forma aproximada:
#
# \begin{equation}
# J(W,b)=\frac{1}{m}\sum_{i}^{m}L(\hat{y}^{(i)},y^{(i)}) + regularización(W)
# \end{equation}
#
# Como vemos la regularización se realizará sobre los pesos de la red sin incluir el término de sesgo o inclinación "b" (bias term), esto se debe a que la mayoría de valores se encuentran en "W".
#
# Para el caso de **$l2$** tenemos la siguiente forma para la matriz de costo
#
# \begin{equation}
# J(W,b)=\frac{1}{m}\sum_{i}^{m}L(\hat{y}^{(i)},y^{(i)}) + \frac{\lambda}{2m}\sum_{l=1}^{L}||W^{[l]}||^{2}_{F}
# \end{equation}
#
# Donde el término de regularización es una suma sobre la norma de frobenius, que básicamente es elevar al cuadrado las componentes de la matriz de pesos, a esta forma de regularización también se le conoce como **weight decay**.
#
# De forma similar para **$l1$** tenemos
#
# \begin{equation}
# J(W,b)=\frac{1}{m}\sum_{i}^{m}L(\hat{y}^{(i)},y^{(i)}) + \frac{\lambda}{2m}\sum_{l=1}^{L}||W^{[l]}||
# \end{equation}
#
# Donde en este caso en la suma tendremos los valores absolutos de las componentes de la matriz de pesos. Como hemos mencionado la regularización busca disminuir y evitar el overfitting, el cual puede presentarse en parte debido a la complejidad de nuestro modelo.
#
# <p><img alt="Colaboratory logo" height="250px" src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/Screen-Shot-2018-04-04-at-1.53.35-AM.png" align="center" hspace="10px" vspace="0px"></p>
#
# Como vemos $l1$ y $l2$ consisten en añadir terminos proporcionales a $\lambda$ (un hiperparámetro), que de acuerdo a su valor va a restringir nuestros pesos a ciertos pequeños valores. Recordemos que
#
# \begin{equation}
# Z=W^{T}X + b
# \end{equation}
#
# Si tenemos pesos pequeños, esto implicará un $Z$ pequeño, debido a su proporcionalidad, y por lo tanto el efecto de la función de activación estará restringido a valores pequeños, lo cual podemos traducir como una disminución en la complejidad del modelo,que es lo buscado.
#
# <p><img alt="Colaboratory logo" height="250px" src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/Screen-Shot-2018-04-04-at-1.53.40-AM.png" align="center" hspace="10px" vspace="0px"></p>
#
# De nuevo, esta calibración será guiada por el hiperparámetro $\lambda$, pues de no tener un valor correcto para este podemos caer incluso en el underfitting, cuando lo que se busca es el mejor modelo posible.
#
# <p><img alt="Colaboratory logo" height="250px" src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/Screen-Shot-2018-04-03-at-10.37.28-PM.png" align="center" hspace="200px" vspace="0px"></p>
#
# Cuando usamos keras, una forma de llamar el regularizador es la siguiente

# %%
from tensorflow import keras

# %%
layer = keras.layers.Dense(100, activation="elu",kernel_initializer="he_normal",
                            kernel_regularizer=keras.regularizers.l2(0.01),bias_regularizer='l2')

# %% [markdown]
# Donde si necesitamos aplicar l1 usamos **keras.regularizers.l1()** o si deseamos usar ambos **keras.regularizers.l1_l2()**, donde el argumento sería el valor para $\lambda$.

# %% [markdown]
# ## **Dropout**
#
# Es uno de lo métodos mas usados como regularizador en redes neuronales. Fue propuesto por Geoffrey Hinton en el  2012. Dropout consiste en que en cada paso de entrenamiento se quitarán ciertas neuronas de nuestra red, es decir se tendrá cierta probabilidad "**P**" de que una neurona sea quitada o apagada (hacerla cero) durante ese paso del entrenamiento, para esto se tendrá en cuenta la capa de entrada y se excluíra la capa de salida.
#
# <p><img alt="Colaboratory logo" height="150px" src="https://miro.medium.com/max/1354/1*skMXofkjeXtKzSr5lqIEmg.png" align="center" hspace="10px" vspace="0px"></p>
#
# El hiperparámetro "**P**" es llamado **dropout rate**, normalmente tiene un valor entre $0.2$ y $0.5$, es decir, si tomamos 0.2, $1$ de $5$ unidades serán quitadas. Si ciertas neuronas en un paso son desactivadas, al siguiente no necesariamente lo estarán, pues de nuevo se tendrán en cuenta a la hora de hacer la desactivación en el nuevo paso del entrenamiento. Es importante aclarar que el **dropout** solo se realizará durante la etapa de entrenamiento, no en la de validación.
#
# Este método de regularización es altamente usado pues se comporta como un **ensemble**, es decir, como la unión de varios modelos, esto puede ser interpretado de esta manera, pues en cada paso del entrenamiento al tener diferentes neuronas desactivadas, esto "equivale" a tener diferentes redes neuronales. Su implementación en keras es la siguiente

# %%
model = keras.models.Sequential([
                  keras.layers.Flatten(input_shape=[28, 28]),
                  keras.layers.Dropout(rate=0.2),
                  keras.layers.Dense(300, activation="elu", kernel_initializer="he_normal"),
                  keras.layers.Dropout(rate=0.2),
                  keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
                  keras.layers.Dropout(rate=0.2),
                  keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# Donde en esta implementación vemos que se usó **keras.layers.Dropout**, donde durante el entrenamiento keras quita algunas de las entradas(haciendolas cero).
#
#
# ### **Regularización de norma máxima (Max-norm)**
#
# Es una forma de regularización muy usada en redes neuronales la cual consiste en restringir los valores de los pesos a cierto valor máximo, **r**, el cual es su hiperparámetro. En este caso no se le añade ningún término a la función de costo, en vez de eso se cálcula $|\textbf{w}|_{2}$ en cada paso y si se supera el valor límite se reescalan los valores de la siguiente forma:
# \begin{equation}
# \textbf{w} \leftarrow \textbf{w}\frac{r}{|\textbf{w}|_{2}}
# \end{equation}
#
# Reucir el **r** implica incrementar la cantidad de regularización, lo cual puede ayudar con el overfitting. Su implementación en Keras es en la siguiente manera

# %%
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal",
                    kernel_constraint=keras.constraints.max_norm(1.))

# %% [markdown]
# ### **Early Stopping**
#
# Este  es un tipo de método de validación cruzada, el cual conciste en analizar el conjunto de validación y en el momento en que su error empiece a aumentar detener el entrenamiento. [callbacks](https://keras.io/callbacks/)
#
# <p><img alt="Colaboratory logo" height="250px" src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/Screen-Shot-2018-04-04-at-12.31.56-AM.png" align="center" hspace="10px" vspace="0px"></p>
#
#
# En keras se puede aplicar este método, haciendo uso de los *callbacks*, los cuales me permiten monitorear él codigo e interactuar con el proceso de entrenamiento de forma automática.

# %%
from keras.callbacks import EarlyStopping

EarlyStopping(monitor='val_err', patience=5)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## **Ejemplo**: Con regularización l1
# Veamos un ejemplo guiado donde apliquemos regularización, a un dataset(**poker hand dataset**) que contiene manos de poker (5 cartas), donde cada carta se describe usando dos atributos (suit and rank), por lo tanto por cada mano tenemos 10 atributos, los cuales se definen de la siguiente manera.
#
#
# 1) S1 "Suit of card #1"
# Ordinal (1-4) representing {Hearts, Spades, Diamonds, Clubs}
#
# 2) C1 "Rank of card #1"
# Numerical (1-13) representing (Ace, 2, 3, ... , Queen, King)
#
# 3) S2 "Suit of card #2"
# Ordinal (1-4) representing {Hearts, Spades, Diamonds, Clubs}
#
# 4) C2 "Rank of card #2"
# Numerical (1-13) representing (Ace, 2, 3, ... , Queen, King)
#
# 5) S3 "Suit of card #3"
# Ordinal (1-4) representing {Hearts, Spades, Diamonds, Clubs}
#
# 6) C3 "Rank of card #3"
# Numerical (1-13) representing (Ace, 2, 3, ... , Queen, King)
#
# 7) S4 "Suit of card #4"
# Ordinal (1-4) representing {Hearts, Spades, Diamonds, Clubs}
#
# 8) C4 "Rank of card #4"
# Numerical (1-13) representing (Ace, 2, 3, ... , Queen, King)
#
# 9) S5 "Suit of card #5"
# Ordinal (1-4) representing {Hearts, Spades, Diamonds, Clubs}
#
# 10) C5 "Rank of card 5"
# Numerical (1-13) representing (Ace, 2, 3, ... , Queen, King)
#
# 11) CLASS "Poker Hand"
# Ordinal (0-9)
#
#   * 0: Nothing in hand; not a recognized poker hand
#   * 1: One pair; one pair of equal ranks within five cards
#   * 2: Two pairs; two pairs of equal ranks within five cards
#   * 3: Three of a kind; three equal ranks within five cards
#   * 4: Straight; five cards, sequentially ranked with no gaps
#   * 5: Flush; five cards with the same suit
#   * 6: Full house; pair + different rank three of a kind
#   * 7: Four of a kind; four equal ranks within five cards
#   * 8: Straight flush; straight + flush
#   * 9: Royal flush; {Ace, King, Queen, Jack, Ten} + flush
#
#  Carguemos las librerías que usaremos y llamemos los datos.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)

# %%
data_train=pd.read_csv('https://raw.githubusercontent.com/diplomado-bigdata-machinelearning-udea/Curso2/master/Datasets/poker-hand-training-true.data',
                       names=['S1','C1','S2','C2','S3','C3','S4','C4','S5','C5','hand'])
data_test=pd.read_csv('https://raw.githubusercontent.com/diplomado-bigdata-machinelearning-udea/Curso2/master/Datasets/poker-hand-testing.data',
                      names=['S1','C1','S2','C2','S3','C3','S4','C4','S5','C5','hand'])

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %% [markdown]
# Ahora, vamos a definir quien será nuestra matriz de atributos y cual será nuestro vector de etiquetas, tanto en el conjunto de entrenamiento como de prueba.

# %%
X=data_train.iloc[:,:-1].values
Y=data_train['hand'].values
X2=data_test.iloc[:,:-1].values
Y2=data_test['hand'].values

# %%
X_train_s= scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X2)

# %% [markdown]
# #### Intenta construir una red neuronal profunda con 120 neuronas de entrada y dos capas ocultas, con 100 y 80 neuronas, cuya función de activación sea  'relu' y en su capa de salida una softmax, compilala usando el optimizador adam

# %%
model=keras.models.Sequential()
model.add(keras.layers.Dense(120,input_dim=10))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(80,activation='relu'))
model.add(keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# #### Ahora entrena la red (fit) con nuestros datos de entrenamiento, en los cuales uses un 30% para validación, con 50 épocas y gráfica las curvas de validación

# %%
history1=model.fit(X_train_s,Y,epochs=50,validation_split=0.3,shuffle=False)
# Out:
# Train on 17507 samples, validate on 7503 samples
# Epoch 1/50
# 17507/17507 [==============================] - 3s 161us/sample - loss: 1.0248 - accuracy: 0.5190 - val_loss: 0.9631 - val_accuracy: 0.5345
# Epoch 2/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.9577 - accuracy: 0.5445 - val_loss: 0.9562 - val_accuracy: 0.5385
# Epoch 3/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.9473 - accuracy: 0.5509 - val_loss: 0.9521 - val_accuracy: 0.5427
# Epoch 4/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.9393 - accuracy: 0.5544 - val_loss: 0.9479 - val_accuracy: 0.5468
# Epoch 5/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.9318 - accuracy: 0.5590 - val_loss: 0.9434 - val_accuracy: 0.5490
# Epoch 6/50
# 17507/17507 [==============================] - 2s 90us/sample - loss: 0.9237 - accuracy: 0.5651 - val_loss: 0.9389 - val_accuracy: 0.5575
# Epoch 7/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.9135 - accuracy: 0.5709 - val_loss: 0.9343 - val_accuracy: 0.5556
# Epoch 8/50
# 17507/17507 [==============================] - 2s 89us/sample - loss: 0.9007 - accuracy: 0.5807 - val_loss: 0.9297 - val_accuracy: 0.5604
# Epoch 9/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8870 - accuracy: 0.5877 - val_loss: 0.9250 - val_accuracy: 0.5631
# Epoch 10/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.8721 - accuracy: 0.5975 - val_loss: 0.9170 - val_accuracy: 0.5724
# Epoch 11/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.8575 - accuracy: 0.6084 - val_loss: 0.9089 - val_accuracy: 0.5775
# Epoch 12/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.8409 - accuracy: 0.6199 - val_loss: 0.8978 - val_accuracy: 0.5890
# Epoch 13/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.8239 - accuracy: 0.6282 - val_loss: 0.8915 - val_accuracy: 0.5946
# Epoch 14/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8075 - accuracy: 0.6376 - val_loss: 0.8814 - val_accuracy: 0.5980
# Epoch 15/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.7901 - accuracy: 0.6483 - val_loss: 0.8753 - val_accuracy: 0.6083
# Epoch 16/50
# 17507/17507 [==============================] - 2s 100us/sample - loss: 0.7736 - accuracy: 0.6577 - val_loss: 0.8632 - val_accuracy: 0.6172
# Epoch 17/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.7546 - accuracy: 0.6661 - val_loss: 0.8459 - val_accuracy: 0.6253
# Epoch 18/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.7364 - accuracy: 0.6768 - val_loss: 0.8321 - val_accuracy: 0.6328
# Epoch 19/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.7153 - accuracy: 0.6892 - val_loss: 0.8172 - val_accuracy: 0.6401
# Epoch 20/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.6938 - accuracy: 0.6991 - val_loss: 0.8028 - val_accuracy: 0.6501
# Epoch 21/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.6731 - accuracy: 0.7079 - val_loss: 0.7903 - val_accuracy: 0.6568
# Epoch 22/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.6530 - accuracy: 0.7192 - val_loss: 0.7719 - val_accuracy: 0.6699
# Epoch 23/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.6357 - accuracy: 0.7287 - val_loss: 0.7648 - val_accuracy: 0.6721
# Epoch 24/50
# 17507/17507 [==============================] - 2s 90us/sample - loss: 0.6173 - accuracy: 0.7370 - val_loss: 0.7488 - val_accuracy: 0.6811
# Epoch 25/50
# 17507/17507 [==============================] - 2s 89us/sample - loss: 0.6009 - accuracy: 0.7438 - val_loss: 0.7270 - val_accuracy: 0.6975
# Epoch 26/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.5832 - accuracy: 0.7517 - val_loss: 0.7280 - val_accuracy: 0.6937
# Epoch 27/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.5629 - accuracy: 0.7612 - val_loss: 0.7095 - val_accuracy: 0.7109
# Epoch 28/50
# 17507/17507 [==============================] - 2s 90us/sample - loss: 0.5418 - accuracy: 0.7733 - val_loss: 0.7060 - val_accuracy: 0.7124
# Epoch 29/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.5219 - accuracy: 0.7803 - val_loss: 0.6715 - val_accuracy: 0.7317
# Epoch 30/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.4976 - accuracy: 0.7903 - val_loss: 0.6487 - val_accuracy: 0.7441
# Epoch 31/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.4788 - accuracy: 0.8001 - val_loss: 0.6211 - val_accuracy: 0.7525
# Epoch 32/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.4616 - accuracy: 0.8086 - val_loss: 0.6236 - val_accuracy: 0.7548
# Epoch 33/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.4416 - accuracy: 0.8181 - val_loss: 0.6034 - val_accuracy: 0.7670
# Epoch 34/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.4256 - accuracy: 0.8252 - val_loss: 0.5945 - val_accuracy: 0.7697
# Epoch 35/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.4070 - accuracy: 0.8331 - val_loss: 0.5643 - val_accuracy: 0.7824
# Epoch 36/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.3908 - accuracy: 0.8410 - val_loss: 0.5564 - val_accuracy: 0.7888
# Epoch 37/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.3761 - accuracy: 0.8485 - val_loss: 0.5442 - val_accuracy: 0.7945
# Epoch 38/50
# 17507/17507 [==============================] - 2s 90us/sample - loss: 0.3594 - accuracy: 0.8565 - val_loss: 0.5268 - val_accuracy: 0.8037
# Epoch 39/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.3406 - accuracy: 0.8643 - val_loss: 0.5264 - val_accuracy: 0.8043
# Epoch 40/50
# 17507/17507 [==============================] - 2s 91us/sample - loss: 0.3210 - accuracy: 0.8707 - val_loss: 0.5098 - val_accuracy: 0.8169
# Epoch 41/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.3104 - accuracy: 0.8775 - val_loss: 0.4735 - val_accuracy: 0.8275
# Epoch 42/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.2925 - accuracy: 0.8843 - val_loss: 0.4630 - val_accuracy: 0.8339
# Epoch 43/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.2769 - accuracy: 0.8912 - val_loss: 0.4495 - val_accuracy: 0.8389
# Epoch 44/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.2642 - accuracy: 0.8976 - val_loss: 0.4278 - val_accuracy: 0.8517
# Epoch 45/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.2464 - accuracy: 0.9057 - val_loss: 0.4085 - val_accuracy: 0.8587
# Epoch 46/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.2341 - accuracy: 0.9099 - val_loss: 0.4260 - val_accuracy: 0.8538
# Epoch 47/50
# 17507/17507 [==============================] - 2s 90us/sample - loss: 0.2143 - accuracy: 0.9187 - val_loss: 0.4078 - val_accuracy: 0.8639
# Epoch 48/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.2073 - accuracy: 0.9219 - val_loss: 0.3542 - val_accuracy: 0.8851
# Epoch 49/50
# 17507/17507 [==============================] - 2s 92us/sample - loss: 0.1869 - accuracy: 0.9295 - val_loss: 0.3425 - val_accuracy: 0.8872
# Epoch 50/50
# 17507/17507 [==============================] - 2s 93us/sample - loss: 0.1718 - accuracy: 0.9374 - val_loss: 0.3280 - val_accuracy: 0.8963

# %%
pd.DataFrame(history1.history).plot(figsize=(10,10))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %% [markdown]
# #### Crea un segunda red neuronal profunda en la cual utilizes el método de regularización L2, con su hiperparámetro igual a $0.002$. Compilalo con las mismas carácterisitcas de la red anterior y gráfica las curvas de validación.

# %%
model_2= keras.models.Sequential([
                  keras.layers.Dense(120,input_dim=10,kernel_regularizer=keras.regularizers.l2(0.002)),
                  keras.layers.Dense(100,activation='relu',kernel_regularizer=keras.regularizers.l2(0.002)),
                  keras.layers.Dense(80,activation='relu',kernel_regularizer=keras.regularizers.l2(0.002)),
                  keras.layers.Dense(10, activation="softmax")
])

# %%
model_2.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history2=model_2.fit(X_train_s,Y,epochs=50,validation_split=0.3,shuffle=False)
# Out:
# Train on 17507 samples, validate on 7503 samples
# Epoch 1/50
# 17507/17507 [==============================] - 2s 131us/sample - loss: 1.2907 - accuracy: 0.5244 - val_loss: 1.1321 - val_accuracy: 0.5287
# Epoch 2/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 1.0751 - accuracy: 0.5434 - val_loss: 1.0358 - val_accuracy: 0.5325
# Epoch 3/50
# 17507/17507 [==============================] - 2s 98us/sample - loss: 1.0153 - accuracy: 0.5485 - val_loss: 1.0010 - val_accuracy: 0.5338
# Epoch 4/50
# 17507/17507 [==============================] - 2s 99us/sample - loss: 0.9920 - accuracy: 0.5486 - val_loss: 0.9846 - val_accuracy: 0.5393
# Epoch 5/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.9811 - accuracy: 0.5493 - val_loss: 0.9760 - val_accuracy: 0.5440
# Epoch 6/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9748 - accuracy: 0.5499 - val_loss: 0.9710 - val_accuracy: 0.5452
# Epoch 7/50
# 17507/17507 [==============================] - 2s 98us/sample - loss: 0.9709 - accuracy: 0.5513 - val_loss: 0.9680 - val_accuracy: 0.5478
# Epoch 8/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9682 - accuracy: 0.5526 - val_loss: 0.9657 - val_accuracy: 0.5486
# Epoch 9/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9661 - accuracy: 0.5541 - val_loss: 0.9638 - val_accuracy: 0.5482
# Epoch 10/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9644 - accuracy: 0.5546 - val_loss: 0.9623 - val_accuracy: 0.5503
# Epoch 11/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9628 - accuracy: 0.5557 - val_loss: 0.9608 - val_accuracy: 0.5523
# Epoch 12/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9614 - accuracy: 0.5566 - val_loss: 0.9598 - val_accuracy: 0.5520
# Epoch 13/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9598 - accuracy: 0.5593 - val_loss: 0.9587 - val_accuracy: 0.5524
# Epoch 14/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9581 - accuracy: 0.5609 - val_loss: 0.9572 - val_accuracy: 0.5516
# Epoch 15/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.9562 - accuracy: 0.5654 - val_loss: 0.9556 - val_accuracy: 0.5556
# Epoch 16/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9541 - accuracy: 0.5666 - val_loss: 0.9545 - val_accuracy: 0.5571
# Epoch 17/50
# 17507/17507 [==============================] - 2s 99us/sample - loss: 0.9519 - accuracy: 0.5694 - val_loss: 0.9547 - val_accuracy: 0.5555
# Epoch 18/50
# 17507/17507 [==============================] - 2s 98us/sample - loss: 0.9498 - accuracy: 0.5717 - val_loss: 0.9544 - val_accuracy: 0.5512
# Epoch 19/50
# 17507/17507 [==============================] - 2s 99us/sample - loss: 0.9478 - accuracy: 0.5751 - val_loss: 0.9547 - val_accuracy: 0.5528
# Epoch 20/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9460 - accuracy: 0.5767 - val_loss: 0.9520 - val_accuracy: 0.5538
# Epoch 21/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9439 - accuracy: 0.5787 - val_loss: 0.9533 - val_accuracy: 0.5544
# Epoch 22/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9424 - accuracy: 0.5796 - val_loss: 0.9517 - val_accuracy: 0.5548
# Epoch 23/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9410 - accuracy: 0.5809 - val_loss: 0.9500 - val_accuracy: 0.5560
# Epoch 24/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9393 - accuracy: 0.5829 - val_loss: 0.9495 - val_accuracy: 0.5576
# Epoch 25/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9382 - accuracy: 0.5827 - val_loss: 0.9487 - val_accuracy: 0.5570
# Epoch 26/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9365 - accuracy: 0.5854 - val_loss: 0.9477 - val_accuracy: 0.5594
# Epoch 27/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9349 - accuracy: 0.5854 - val_loss: 0.9461 - val_accuracy: 0.5611
# Epoch 28/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9334 - accuracy: 0.5863 - val_loss: 0.9442 - val_accuracy: 0.5638
# Epoch 29/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9315 - accuracy: 0.5862 - val_loss: 0.9423 - val_accuracy: 0.5648
# Epoch 30/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.9298 - accuracy: 0.5885 - val_loss: 0.9412 - val_accuracy: 0.5679
# Epoch 31/50
# 17507/17507 [==============================] - 2s 98us/sample - loss: 0.9277 - accuracy: 0.5923 - val_loss: 0.9382 - val_accuracy: 0.5678
# Epoch 32/50
# 17507/17507 [==============================] - 2s 98us/sample - loss: 0.9254 - accuracy: 0.5938 - val_loss: 0.9345 - val_accuracy: 0.5759
# Epoch 33/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9229 - accuracy: 0.5984 - val_loss: 0.9308 - val_accuracy: 0.5816
# Epoch 34/50
# 17507/17507 [==============================] - 2s 101us/sample - loss: 0.9205 - accuracy: 0.6009 - val_loss: 0.9281 - val_accuracy: 0.5854
# Epoch 35/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9183 - accuracy: 0.6034 - val_loss: 0.9258 - val_accuracy: 0.5886
# Epoch 36/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9155 - accuracy: 0.6067 - val_loss: 0.9207 - val_accuracy: 0.5911
# Epoch 37/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.9125 - accuracy: 0.6106 - val_loss: 0.9189 - val_accuracy: 0.5908
# Epoch 38/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9102 - accuracy: 0.6116 - val_loss: 0.9164 - val_accuracy: 0.5920
# Epoch 39/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.9077 - accuracy: 0.6135 - val_loss: 0.9139 - val_accuracy: 0.5958
# Epoch 40/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.9052 - accuracy: 0.6156 - val_loss: 0.9118 - val_accuracy: 0.5970
# Epoch 41/50
# 17507/17507 [==============================] - 2s 99us/sample - loss: 0.9026 - accuracy: 0.6175 - val_loss: 0.9065 - val_accuracy: 0.6015
# Epoch 42/50
# 17507/17507 [==============================] - 2s 95us/sample - loss: 0.9001 - accuracy: 0.6174 - val_loss: 0.9066 - val_accuracy: 0.6028
# Epoch 43/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8976 - accuracy: 0.6196 - val_loss: 0.9035 - val_accuracy: 0.6030
# Epoch 44/50
# 17507/17507 [==============================] - 2s 101us/sample - loss: 0.8954 - accuracy: 0.6220 - val_loss: 0.8994 - val_accuracy: 0.6087
# Epoch 45/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8923 - accuracy: 0.6215 - val_loss: 0.8980 - val_accuracy: 0.6098
# Epoch 46/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.8896 - accuracy: 0.6233 - val_loss: 0.8943 - val_accuracy: 0.6124
# Epoch 47/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8873 - accuracy: 0.6249 - val_loss: 0.8931 - val_accuracy: 0.6111
# Epoch 48/50
# 17507/17507 [==============================] - 2s 96us/sample - loss: 0.8846 - accuracy: 0.6284 - val_loss: 0.8895 - val_accuracy: 0.6134
# Epoch 49/50
# 17507/17507 [==============================] - 2s 97us/sample - loss: 0.8828 - accuracy: 0.6287 - val_loss: 0.8874 - val_accuracy: 0.6167
# Epoch 50/50
# 17507/17507 [==============================] - 2s 94us/sample - loss: 0.8809 - accuracy: 0.6285 - val_loss: 0.8866 - val_accuracy: 0.6168

# %%
pd.DataFrame(history2.history).plot(figsize=(10,10))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %% [markdown]
# ## Gradient Clipping

# %% [markdown]
# **Ejercicio**: Entrene una red neuronal en keras para el dataset de Iris con 3 capas ocultas de 4 neuronas cada una con funciones de activación sigmoide. Use gradiente estocástico con **gradient clipping**

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.optimizers import SGD #Importar el optimizador
# from keras.utils import to_categorical
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# modelo=Sequential()
# modelo.add(Dense(4,activation='sigmoid',input_shape=(4,)))
# modelo.add(Dense(4,activation='sigmoid'))
# modelo.add(Dense(4,activation='sigmoid'))
# modelo.add(Dense(3,activation='softmax'))
# optim=SGD(clipnorm=1)
# modelo.compile(optim,loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# ----->

# %%
# %tensorflow_version 1.x
from sklearn.datasets import load_iris
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD #Importar el optimizador
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
data=load_iris()
X,y=data.data,data.target
X-=X.mean(axis=0)
X/=X.std(axis=0)
y=to_categorical(y)

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150, 3)

# %%
modelo=Sequential()
modelo.add(Dense(4,activation='sigmoid',input_shape=(4,)))
modelo.add(Dense(4,activation='sigmoid'))
modelo.add(Dense(4,activation='sigmoid'))
modelo.add(Dense(3,activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
optim=SGD(clipnorm=1)
modelo.compile(optim,loss='categorical_crossentropy',metrics=['accuracy'])
modelo.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelo.fit(x=X,y=y, batch_size=10,epochs=200)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/200
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2587 - acc: 0.3333
# Epoch 2/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.2279 - acc: 0.3333
# Epoch 3/200
# 150/150 [==============================] - 0s 148us/step - loss: 1.2033 - acc: 0.3333
# Epoch 4/200
# 150/150 [==============================] - 0s 138us/step - loss: 1.1835 - acc: 0.3333
# Epoch 5/200
# 150/150 [==============================] - 0s 130us/step - loss: 1.1673 - acc: 0.3333
# Epoch 6/200
# 150/150 [==============================] - 0s 128us/step - loss: 1.1540 - acc: 0.3333
# Epoch 7/200
# 150/150 [==============================] - 0s 153us/step - loss: 1.1439 - acc: 0.3333
# Epoch 8/200
# 150/150 [==============================] - 0s 144us/step - loss: 1.1352 - acc: 0.3333
# Epoch 9/200
# 150/150 [==============================] - 0s 133us/step - loss: 1.1279 - acc: 0.3333
# Epoch 10/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.1225 - acc: 0.3333
# Epoch 11/200
# 150/150 [==============================] - 0s 140us/step - loss: 1.1174 - acc: 0.3333
# Epoch 12/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.1139 - acc: 0.3333
# Epoch 13/200
# 150/150 [==============================] - 0s 170us/step - loss: 1.1106 - acc: 0.3333
# Epoch 14/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.1078 - acc: 0.3333
# Epoch 15/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.1057 - acc: 0.3333
# Epoch 16/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.1036 - acc: 0.3333
# Epoch 17/200
# 150/150 [==============================] - 0s 133us/step - loss: 1.1022 - acc: 0.3333
# Epoch 18/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.1011 - acc: 0.3333
# Epoch 19/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.1002 - acc: 0.3333
# Epoch 20/200
# 150/150 [==============================] - 0s 125us/step - loss: 1.0992 - acc: 0.3333
# Epoch 21/200
# 150/150 [==============================] - 0s 126us/step - loss: 1.0984 - acc: 0.3333
# Epoch 22/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0981 - acc: 0.3333
# Epoch 23/200
# 150/150 [==============================] - 0s 154us/step - loss: 1.0977 - acc: 0.3333
# Epoch 24/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0972 - acc: 0.3333
# Epoch 25/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0967 - acc: 0.3333
# Epoch 26/200
# 150/150 [==============================] - 0s 161us/step - loss: 1.0963 - acc: 0.3333
# Epoch 27/200
# 150/150 [==============================] - 0s 149us/step - loss: 1.0963 - acc: 0.3333
# Epoch 28/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0962 - acc: 0.3333
# Epoch 29/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0961 - acc: 0.3333
# Epoch 30/200
# 150/150 [==============================] - 0s 129us/step - loss: 1.0955 - acc: 0.3333
# Epoch 31/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0956 - acc: 0.3333
# Epoch 32/200
# 150/150 [==============================] - 0s 145us/step - loss: 1.0956 - acc: 0.3333
# Epoch 33/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0955 - acc: 0.3333
# Epoch 34/200
# 150/150 [==============================] - 0s 145us/step - loss: 1.0955 - acc: 0.4267
# Epoch 35/200
# 150/150 [==============================] - 0s 133us/step - loss: 1.0952 - acc: 0.3333
# Epoch 36/200
# 150/150 [==============================] - 0s 130us/step - loss: 1.0952 - acc: 0.3400
# Epoch 37/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0948 - acc: 0.3333
# Epoch 38/200
# 150/150 [==============================] - 0s 142us/step - loss: 1.0947 - acc: 0.3400
# Epoch 39/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0947 - acc: 0.3600
# Epoch 40/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0950 - acc: 0.3467
# Epoch 41/200
# 150/150 [==============================] - 0s 124us/step - loss: 1.0947 - acc: 0.3333
# Epoch 42/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0947 - acc: 0.5267
# Epoch 43/200
# 150/150 [==============================] - 0s 168us/step - loss: 1.0946 - acc: 0.3600
# Epoch 44/200
# 150/150 [==============================] - 0s 146us/step - loss: 1.0948 - acc: 0.3667
# Epoch 45/200
# 150/150 [==============================] - 0s 146us/step - loss: 1.0943 - acc: 0.3467
# Epoch 46/200
# 150/150 [==============================] - 0s 127us/step - loss: 1.0946 - acc: 0.4600
# Epoch 47/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0947 - acc: 0.4000
# Epoch 48/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0944 - acc: 0.3333
# Epoch 49/200
# 150/150 [==============================] - 0s 148us/step - loss: 1.0943 - acc: 0.4600
# Epoch 50/200
# 150/150 [==============================] - 0s 144us/step - loss: 1.0943 - acc: 0.3667
# Epoch 51/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0943 - acc: 0.3933
# Epoch 52/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.0940 - acc: 0.3600
# Epoch 53/200
# 150/150 [==============================] - 0s 129us/step - loss: 1.0945 - acc: 0.4067
# Epoch 54/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0941 - acc: 0.3600
# Epoch 55/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0940 - acc: 0.3467
# Epoch 56/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0939 - acc: 0.4467
# Epoch 57/200
# 150/150 [==============================] - 0s 173us/step - loss: 1.0939 - acc: 0.3800
# Epoch 58/200
# 150/150 [==============================] - 0s 150us/step - loss: 1.0940 - acc: 0.3933
# Epoch 59/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0939 - acc: 0.5467
# Epoch 60/200
# 150/150 [==============================] - 0s 138us/step - loss: 1.0940 - acc: 0.4067
# Epoch 61/200
# 150/150 [==============================] - 0s 148us/step - loss: 1.0934 - acc: 0.4267
# Epoch 62/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0938 - acc: 0.4933
# Epoch 63/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0938 - acc: 0.4533
# Epoch 64/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0935 - acc: 0.3733
# Epoch 65/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0937 - acc: 0.3667
# Epoch 66/200
# 150/150 [==============================] - 0s 140us/step - loss: 1.0935 - acc: 0.4400
# Epoch 67/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0934 - acc: 0.3867
# Epoch 68/200
# 150/150 [==============================] - 0s 160us/step - loss: 1.0937 - acc: 0.5267
# Epoch 69/200
# 150/150 [==============================] - 0s 160us/step - loss: 1.0932 - acc: 0.4133
# Epoch 70/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0933 - acc: 0.4933
# Epoch 71/200
# 150/150 [==============================] - 0s 159us/step - loss: 1.0931 - acc: 0.4800
# Epoch 72/200
# 150/150 [==============================] - 0s 163us/step - loss: 1.0933 - acc: 0.4333
# Epoch 73/200
# 150/150 [==============================] - 0s 150us/step - loss: 1.0930 - acc: 0.4467
# Epoch 74/200
# 150/150 [==============================] - 0s 179us/step - loss: 1.0930 - acc: 0.4133
# Epoch 75/200
# 150/150 [==============================] - 0s 166us/step - loss: 1.0931 - acc: 0.4733
# Epoch 76/200
# 150/150 [==============================] - 0s 119us/step - loss: 1.0932 - acc: 0.5267
# Epoch 77/200
# 150/150 [==============================] - 0s 207us/step - loss: 1.0933 - acc: 0.4333
# Epoch 78/200
# 150/150 [==============================] - 0s 148us/step - loss: 1.0928 - acc: 0.4067
# Epoch 79/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.0930 - acc: 0.4533
# Epoch 80/200
# 150/150 [==============================] - 0s 159us/step - loss: 1.0928 - acc: 0.4333
# Epoch 81/200
# 150/150 [==============================] - 0s 126us/step - loss: 1.0928 - acc: 0.5000
# Epoch 82/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.0929 - acc: 0.3867
# Epoch 83/200
# 150/150 [==============================] - 0s 164us/step - loss: 1.0927 - acc: 0.4267
# Epoch 84/200
# 150/150 [==============================] - 0s 126us/step - loss: 1.0926 - acc: 0.3867
# Epoch 85/200
# 150/150 [==============================] - 0s 149us/step - loss: 1.0924 - acc: 0.4133
# Epoch 86/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0924 - acc: 0.3800
# Epoch 87/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.0922 - acc: 0.5267
# Epoch 88/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0925 - acc: 0.5000
# Epoch 89/200
# 150/150 [==============================] - 0s 155us/step - loss: 1.0921 - acc: 0.4533
# Epoch 90/200
# 150/150 [==============================] - 0s 132us/step - loss: 1.0922 - acc: 0.5600
# Epoch 91/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0923 - acc: 0.4600
# Epoch 92/200
# 150/150 [==============================] - 0s 145us/step - loss: 1.0922 - acc: 0.3600
# Epoch 93/200
# 150/150 [==============================] - 0s 169us/step - loss: 1.0920 - acc: 0.3533
# Epoch 94/200
# 150/150 [==============================] - 0s 154us/step - loss: 1.0917 - acc: 0.4067
# Epoch 95/200
# 150/150 [==============================] - 0s 154us/step - loss: 1.0920 - acc: 0.4733
# Epoch 96/200
# 150/150 [==============================] - 0s 149us/step - loss: 1.0917 - acc: 0.4667
# Epoch 97/200
# 150/150 [==============================] - 0s 201us/step - loss: 1.0918 - acc: 0.4933
# Epoch 98/200
# 150/150 [==============================] - 0s 179us/step - loss: 1.0919 - acc: 0.5200
# Epoch 99/200
# 150/150 [==============================] - 0s 243us/step - loss: 1.0916 - acc: 0.5000
# Epoch 100/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0917 - acc: 0.3867
# Epoch 101/200
# 150/150 [==============================] - 0s 179us/step - loss: 1.0915 - acc: 0.5133
# Epoch 102/200
# 150/150 [==============================] - 0s 181us/step - loss: 1.0920 - acc: 0.5200
# Epoch 103/200
# 150/150 [==============================] - 0s 191us/step - loss: 1.0913 - acc: 0.4133
# Epoch 104/200
# 150/150 [==============================] - 0s 155us/step - loss: 1.0912 - acc: 0.4933
# Epoch 105/200
# 150/150 [==============================] - 0s 146us/step - loss: 1.0915 - acc: 0.5333
# Epoch 106/200
# 150/150 [==============================] - 0s 173us/step - loss: 1.0914 - acc: 0.4933
# Epoch 107/200
# 150/150 [==============================] - 0s 161us/step - loss: 1.0913 - acc: 0.4200
# Epoch 108/200
# 150/150 [==============================] - 0s 190us/step - loss: 1.0912 - acc: 0.3867
# Epoch 109/200
# 150/150 [==============================] - 0s 164us/step - loss: 1.0910 - acc: 0.5000
# Epoch 110/200
# 150/150 [==============================] - 0s 152us/step - loss: 1.0911 - acc: 0.4733
# Epoch 111/200
# 150/150 [==============================] - 0s 153us/step - loss: 1.0911 - acc: 0.5067
# Epoch 112/200
# 150/150 [==============================] - 0s 130us/step - loss: 1.0907 - acc: 0.3933
# Epoch 113/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0910 - acc: 0.4267
# Epoch 114/200
# 150/150 [==============================] - 0s 159us/step - loss: 1.0907 - acc: 0.5467
# Epoch 115/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0905 - acc: 0.5067
# Epoch 116/200
# 150/150 [==============================] - 0s 172us/step - loss: 1.0905 - acc: 0.4933
# Epoch 117/200
# 150/150 [==============================] - 0s 154us/step - loss: 1.0906 - acc: 0.3800
# Epoch 118/200
# 150/150 [==============================] - 0s 127us/step - loss: 1.0903 - acc: 0.5267
# Epoch 119/200
# 150/150 [==============================] - 0s 129us/step - loss: 1.0905 - acc: 0.5400
# Epoch 120/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0906 - acc: 0.3933
# Epoch 121/200
# 150/150 [==============================] - 0s 128us/step - loss: 1.0903 - acc: 0.4800
# Epoch 122/200
# 150/150 [==============================] - 0s 125us/step - loss: 1.0903 - acc: 0.4000
# Epoch 123/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.0901 - acc: 0.5467
# Epoch 124/200
# 150/150 [==============================] - 0s 128us/step - loss: 1.0905 - acc: 0.4600
# Epoch 125/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0900 - acc: 0.3733
# Epoch 126/200
# 150/150 [==============================] - 0s 132us/step - loss: 1.0901 - acc: 0.4733
# Epoch 127/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0900 - acc: 0.4333
# Epoch 128/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0899 - acc: 0.4867
# Epoch 129/200
# 150/150 [==============================] - 0s 123us/step - loss: 1.0895 - acc: 0.4533
# Epoch 130/200
# 150/150 [==============================] - 0s 123us/step - loss: 1.0898 - acc: 0.4600
# Epoch 131/200
# 150/150 [==============================] - 0s 169us/step - loss: 1.0896 - acc: 0.4133
# Epoch 132/200
# 150/150 [==============================] - 0s 152us/step - loss: 1.0895 - acc: 0.4067
# Epoch 133/200
# 150/150 [==============================] - 0s 169us/step - loss: 1.0892 - acc: 0.4333
# Epoch 134/200
# 150/150 [==============================] - 0s 189us/step - loss: 1.0894 - acc: 0.4800
# Epoch 135/200
# 150/150 [==============================] - 0s 154us/step - loss: 1.0892 - acc: 0.4800
# Epoch 136/200
# 150/150 [==============================] - 0s 159us/step - loss: 1.0893 - acc: 0.4600
# Epoch 137/200
# 150/150 [==============================] - 0s 170us/step - loss: 1.0891 - acc: 0.4733
# Epoch 138/200
# 150/150 [==============================] - 0s 191us/step - loss: 1.0890 - acc: 0.5467
# Epoch 139/200
# 150/150 [==============================] - 0s 180us/step - loss: 1.0888 - acc: 0.4667
# Epoch 140/200
# 150/150 [==============================] - 0s 173us/step - loss: 1.0891 - acc: 0.5667
# Epoch 141/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.0888 - acc: 0.5533
# Epoch 142/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.0885 - acc: 0.4267
# Epoch 143/200
# 150/150 [==============================] - 0s 144us/step - loss: 1.0884 - acc: 0.5000
# Epoch 144/200
# 150/150 [==============================] - 0s 140us/step - loss: 1.0886 - acc: 0.5067
# Epoch 145/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.0884 - acc: 0.4733
# Epoch 146/200
# 150/150 [==============================] - 0s 148us/step - loss: 1.0885 - acc: 0.4800
# Epoch 147/200
# 150/150 [==============================] - 0s 138us/step - loss: 1.0881 - acc: 0.4400
# Epoch 148/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0883 - acc: 0.4133
# Epoch 149/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0881 - acc: 0.5000
# Epoch 150/200
# 150/150 [==============================] - 0s 162us/step - loss: 1.0883 - acc: 0.5867
# Epoch 151/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0879 - acc: 0.4200
# Epoch 152/200
# 150/150 [==============================] - 0s 149us/step - loss: 1.0881 - acc: 0.4333
# Epoch 153/200
# 150/150 [==============================] - 0s 133us/step - loss: 1.0877 - acc: 0.4133
# Epoch 154/200
# 150/150 [==============================] - 0s 146us/step - loss: 1.0875 - acc: 0.4333
# Epoch 155/200
# 150/150 [==============================] - 0s 161us/step - loss: 1.0875 - acc: 0.3800
# Epoch 156/200
# 150/150 [==============================] - 0s 155us/step - loss: 1.0875 - acc: 0.4933
# Epoch 157/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0874 - acc: 0.4133
# Epoch 158/200
# 150/150 [==============================] - 0s 138us/step - loss: 1.0873 - acc: 0.4267
# Epoch 159/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0870 - acc: 0.3933
# Epoch 160/200
# 150/150 [==============================] - 0s 132us/step - loss: 1.0870 - acc: 0.3867
# Epoch 161/200
# 150/150 [==============================] - 0s 145us/step - loss: 1.0872 - acc: 0.5000
# Epoch 162/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0868 - acc: 0.4200
# Epoch 163/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.0867 - acc: 0.4800
# Epoch 164/200
# 150/150 [==============================] - 0s 134us/step - loss: 1.0868 - acc: 0.4667
# Epoch 165/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0866 - acc: 0.4133
# Epoch 166/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.0866 - acc: 0.4733
# Epoch 167/200
# 150/150 [==============================] - 0s 127us/step - loss: 1.0863 - acc: 0.4867
# Epoch 168/200
# 150/150 [==============================] - 0s 164us/step - loss: 1.0861 - acc: 0.5133
# Epoch 169/200
# 150/150 [==============================] - 0s 128us/step - loss: 1.0863 - acc: 0.4200
# Epoch 170/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0862 - acc: 0.3667
# Epoch 171/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0860 - acc: 0.6333
# Epoch 172/200
# 150/150 [==============================] - 0s 140us/step - loss: 1.0857 - acc: 0.5000
# Epoch 173/200
# 150/150 [==============================] - 0s 137us/step - loss: 1.0858 - acc: 0.4933
# Epoch 174/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0859 - acc: 0.3933
# Epoch 175/200
# 150/150 [==============================] - 0s 149us/step - loss: 1.0857 - acc: 0.5667
# Epoch 176/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.0855 - acc: 0.5267
# Epoch 177/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0855 - acc: 0.5267
# Epoch 178/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0853 - acc: 0.5733
# Epoch 179/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0852 - acc: 0.4000
# Epoch 180/200
# 150/150 [==============================] - 0s 142us/step - loss: 1.0851 - acc: 0.6000
# Epoch 181/200
# 150/150 [==============================] - 0s 170us/step - loss: 1.0850 - acc: 0.5200
# Epoch 182/200
# 150/150 [==============================] - 0s 131us/step - loss: 1.0848 - acc: 0.5533
# Epoch 183/200
# 150/150 [==============================] - 0s 145us/step - loss: 1.0849 - acc: 0.4133
# Epoch 184/200
# 150/150 [==============================] - 0s 157us/step - loss: 1.0847 - acc: 0.4467
# Epoch 185/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0845 - acc: 0.3867
# Epoch 186/200
# 150/150 [==============================] - 0s 132us/step - loss: 1.0842 - acc: 0.5867
# Epoch 187/200
# 150/150 [==============================] - 0s 138us/step - loss: 1.0843 - acc: 0.4333
# Epoch 188/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0843 - acc: 0.5467
# Epoch 189/200
# 150/150 [==============================] - 0s 135us/step - loss: 1.0843 - acc: 0.5467
# Epoch 190/200
# 150/150 [==============================] - 0s 136us/step - loss: 1.0837 - acc: 0.4133
# Epoch 191/200
# 150/150 [==============================] - 0s 127us/step - loss: 1.0837 - acc: 0.4400
# Epoch 192/200
# 150/150 [==============================] - 0s 176us/step - loss: 1.0837 - acc: 0.4467
# Epoch 193/200
# 150/150 [==============================] - 0s 144us/step - loss: 1.0838 - acc: 0.6200
# Epoch 194/200
# 150/150 [==============================] - 0s 181us/step - loss: 1.0836 - acc: 0.5733
# Epoch 195/200
# 150/150 [==============================] - 0s 141us/step - loss: 1.0833 - acc: 0.4067
# Epoch 196/200
# 150/150 [==============================] - 0s 151us/step - loss: 1.0831 - acc: 0.4667
# Epoch 197/200
# 150/150 [==============================] - 0s 143us/step - loss: 1.0830 - acc: 0.5600
# Epoch 198/200
# 150/150 [==============================] - 0s 146us/step - loss: 1.0828 - acc: 0.5133
# Epoch 199/200
# 150/150 [==============================] - 0s 147us/step - loss: 1.0830 - acc: 0.6000
# Epoch 200/200
# 150/150 [==============================] - 0s 139us/step - loss: 1.0827 - acc: 0.4933

# %% [markdown]
# ## Funciones de Activación

# %% [markdown]
# **Ejercicio**: Entrene una red neuronal en keras para el dataset de Iris con 3 capas ocultas de 4 neuronas cada una con funciones de activación **ReLu**, **PReLU** y **SELU** respectivamente. Cuantos parámetros tendrá cada capa?

# %%
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(modelo,show_shapes=True,show_layer_names=False)

# %%
from sklearn.datasets import load_iris
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,PReLU,ReLU #Puedo importar las funciones
from tensorflow.keras.utils import to_categorical
data=load_iris()
X,y=data.data,data.target
X-=X.mean(axis=0)
X/=X.std(axis=0)
y=to_categorical(y)
modelo=Sequential()
modelo.add(Dense(4,activation='relu',input_shape=(4,)))
modelo.add(Dense(4))
modelo.add(PReLU())
modelo.add(Dense(4,activation='selu'))
modelo.add(Dense(3,activation='softmax'))
modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
modelo.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# p_re_lu (PReLU)              (None, 4)                 4
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense,PReLU #Puedo importar las funciones
# from keras.utils import to_categorical
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# modelo=Sequential()
# modelo.add(Dense(4,activation='relu',input_shape=(4,)))
# modelo.add(Dense(4))
# modelo.add(PReLU())
# modelo.add(Dense(4,activation='selu'))
# modelo.add(Dense(3,activation='softmax'))
# modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# ----->

# %% [markdown]
# ## Inicialización de Parámetros

# %% [markdown]
# **Ejercicio:** Entrene una red neuronal para el dataset iris con 3 capas ocultas de 4 neuronas cada una con función de activación ReLU e inicialización **Glorot Normal**.

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.utils import to_categorical
# from keras.initializers import glorot_normal #Importar el inicializador
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# glorotinit=glorot_normal()
# modelo=Sequential()
# modelo.add(Dense(4,activation='relu',kernel_initializer=glorotinit,input_shape=(4,)))
# modelo.add(Dense(4,activation='relu',kernel_initializer='glorot_normal')) #puedo escribir simiplemente "glorot_normal"
# modelo.add(Dense(4,activation='relu',kernel_initializer='glorot_normal'))
# modelo.add(Dense(3,activation='softmax',kernel_initializer='glorot_normal'))
# modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# ----->

# %% [markdown]
# ## Batch Normalization

# %% [markdown]
# **Ejercicio:** Entrene una red neuronal para el dataset iris con 3 capas ocultas de 4 neuronas cada una con función de activación ReLU y **Batch Normalization** en la segunda capa oculta.

# %%
from sklearn.datasets import load_iris
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,BatchNormalization #Importar BatchNorm
from tensorflow.keras.utils import to_categorical

# %%
data=load_iris()
X,y=data.data,data.target
X-=X.mean(axis=0)
X/=X.std(axis=0)
y=to_categorical(y)

# %%
modelo=Sequential()
modelo.add(Dense(4,activation='relu',input_shape=(4,)))
modelo.add(Dense(4,activation='relu'))
modelo.add(BatchNormalization())
modelo.add(Dense(4,activation='relu'))
modelo.add(Dense(3,activation='softmax'))
modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 20
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4)                 16
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 91
# Trainable params: 83
# Non-trainable params: 8
# _________________________________________________________________

# %%
modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# Out:
# Train on 150 samples
# Epoch 1/500
# 150/150 [==============================] - 0s 875us/sample - loss: 1.1503 - acc: 0.4600
# Epoch 2/500
# 150/150 [==============================] - 0s 139us/sample - loss: 1.0988 - acc: 0.4333
# Epoch 3/500
# 150/150 [==============================] - 0s 140us/sample - loss: 1.0826 - acc: 0.5133
# Epoch 4/500
# 150/150 [==============================] - 0s 125us/sample - loss: 1.0655 - acc: 0.5200
# Epoch 5/500
# 150/150 [==============================] - 0s 151us/sample - loss: 1.0275 - acc: 0.6133
# Epoch 6/500
# 150/150 [==============================] - 0s 122us/sample - loss: 1.0113 - acc: 0.5867
# Epoch 7/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.9761 - acc: 0.5933
# Epoch 8/500
# 150/150 [==============================] - 0s 125us/sample - loss: 0.9270 - acc: 0.6133
# Epoch 9/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.9333 - acc: 0.6400
# Epoch 10/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.9182 - acc: 0.6200
# Epoch 11/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.8536 - acc: 0.6400
# Epoch 12/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.8306 - acc: 0.7000
# Epoch 13/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.8285 - acc: 0.6933
# Epoch 14/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.7931 - acc: 0.7067
# Epoch 15/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.7782 - acc: 0.6800
# Epoch 16/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.7950 - acc: 0.6467
# Epoch 17/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.7663 - acc: 0.6733
# Epoch 18/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.7171 - acc: 0.7000
# Epoch 19/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.7373 - acc: 0.6400
# Epoch 20/500
# 150/150 [==============================] - 0s 128us/sample - loss: 0.7292 - acc: 0.6733
# Epoch 21/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.6791 - acc: 0.7200
# Epoch 22/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.6618 - acc: 0.6800
# Epoch 23/500
# 150/150 [==============================] - 0s 122us/sample - loss: 0.6455 - acc: 0.6867
# Epoch 24/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.6581 - acc: 0.7133
# Epoch 25/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.6581 - acc: 0.6933
# Epoch 26/500
# 150/150 [==============================] - 0s 125us/sample - loss: 0.6367 - acc: 0.6933
# Epoch 27/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.6214 - acc: 0.7200
# Epoch 28/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.6658 - acc: 0.7000
# Epoch 29/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.6212 - acc: 0.7067
# Epoch 30/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.6316 - acc: 0.6200
# Epoch 31/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.6072 - acc: 0.7867
# Epoch 32/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.5627 - acc: 0.7667
# Epoch 33/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.5551 - acc: 0.7800
# Epoch 34/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.5376 - acc: 0.8067
# Epoch 35/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.5561 - acc: 0.7800
# Epoch 36/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.5129 - acc: 0.7867
# Epoch 37/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.5293 - acc: 0.8067
# Epoch 38/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.4968 - acc: 0.8200
# Epoch 39/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.5518 - acc: 0.8000
# Epoch 40/500
# 150/150 [==============================] - 0s 169us/sample - loss: 0.4771 - acc: 0.8267
# Epoch 41/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.4873 - acc: 0.8200
# Epoch 42/500
# 150/150 [==============================] - 0s 171us/sample - loss: 0.4856 - acc: 0.8333
# Epoch 43/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.4675 - acc: 0.8400
# Epoch 44/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.4901 - acc: 0.8267
# Epoch 45/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.5039 - acc: 0.7867
# Epoch 46/500
# 150/150 [==============================] - 0s 126us/sample - loss: 0.4538 - acc: 0.8333
# Epoch 47/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.4481 - acc: 0.8333
# Epoch 48/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.4744 - acc: 0.8133
# Epoch 49/500
# 150/150 [==============================] - 0s 178us/sample - loss: 0.4441 - acc: 0.8400
# Epoch 50/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.4454 - acc: 0.8333
# Epoch 51/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.4185 - acc: 0.8733
# Epoch 52/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.3978 - acc: 0.8467
# Epoch 53/500
# 150/150 [==============================] - 0s 176us/sample - loss: 0.3986 - acc: 0.8667
# Epoch 54/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.3847 - acc: 0.8800
# Epoch 55/500
# 150/150 [==============================] - 0s 177us/sample - loss: 0.3634 - acc: 0.8733
# Epoch 56/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.3739 - acc: 0.8800
# Epoch 57/500
# 150/150 [==============================] - 0s 176us/sample - loss: 0.3556 - acc: 0.8600
# Epoch 58/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.3660 - acc: 0.8733
# Epoch 59/500
# 150/150 [==============================] - 0s 190us/sample - loss: 0.4177 - acc: 0.8600
# Epoch 60/500
# 150/150 [==============================] - 0s 159us/sample - loss: 0.3525 - acc: 0.9000
# Epoch 61/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.3707 - acc: 0.8467
# Epoch 62/500
# 150/150 [==============================] - 0s 186us/sample - loss: 0.3470 - acc: 0.8867
# Epoch 63/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.3419 - acc: 0.8867
# Epoch 64/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.3082 - acc: 0.9133
# Epoch 65/500
# 150/150 [==============================] - 0s 154us/sample - loss: 0.3412 - acc: 0.8933
# Epoch 66/500
# 150/150 [==============================] - 0s 168us/sample - loss: 0.3169 - acc: 0.9200
# Epoch 67/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.3449 - acc: 0.8867
# Epoch 68/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.2926 - acc: 0.9067
# Epoch 69/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.2905 - acc: 0.9067
# Epoch 70/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.3399 - acc: 0.9067
# Epoch 71/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.2821 - acc: 0.9333
# Epoch 72/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.2755 - acc: 0.9200
# Epoch 73/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.2654 - acc: 0.9333
# Epoch 74/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.2881 - acc: 0.9133
# Epoch 75/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.3352 - acc: 0.8867
# Epoch 76/500
# 150/150 [==============================] - 0s 154us/sample - loss: 0.2601 - acc: 0.9400
# Epoch 77/500
# 150/150 [==============================] - 0s 173us/sample - loss: 0.2426 - acc: 0.9600
# Epoch 78/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.2295 - acc: 0.9400
# Epoch 79/500
# 150/150 [==============================] - 0s 174us/sample - loss: 0.2546 - acc: 0.9333
# Epoch 80/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.2203 - acc: 0.9467
# Epoch 81/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.2126 - acc: 0.9600
# Epoch 82/500
# 150/150 [==============================] - 0s 128us/sample - loss: 0.2158 - acc: 0.9200
# Epoch 83/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.2249 - acc: 0.9600
# Epoch 84/500
# 150/150 [==============================] - 0s 125us/sample - loss: 0.2102 - acc: 0.9333
# Epoch 85/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.2400 - acc: 0.9400
# Epoch 86/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1972 - acc: 0.9533
# Epoch 87/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1989 - acc: 0.9600
# Epoch 88/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.2025 - acc: 0.9400
# Epoch 89/500
# 150/150 [==============================] - 0s 126us/sample - loss: 0.2315 - acc: 0.9067
# Epoch 90/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.2227 - acc: 0.9333
# Epoch 91/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.2140 - acc: 0.9467
# Epoch 92/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1933 - acc: 0.9533
# Epoch 93/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.2083 - acc: 0.9333
# Epoch 94/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.2630 - acc: 0.9067
# Epoch 95/500
# 150/150 [==============================] - 0s 170us/sample - loss: 0.2154 - acc: 0.9333
# Epoch 96/500
# 150/150 [==============================] - 0s 176us/sample - loss: 0.2007 - acc: 0.9333
# Epoch 97/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.1781 - acc: 0.9467
# Epoch 98/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.2340 - acc: 0.9333
# Epoch 99/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.1663 - acc: 0.9467
# Epoch 100/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.2032 - acc: 0.9600
# Epoch 101/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.1438 - acc: 0.9733
# Epoch 102/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.2185 - acc: 0.9467
# Epoch 103/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.2220 - acc: 0.9467
# Epoch 104/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.2286 - acc: 0.9333
# Epoch 105/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1664 - acc: 0.9533
# Epoch 106/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1836 - acc: 0.9400
# Epoch 107/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1939 - acc: 0.9533
# Epoch 108/500
# 150/150 [==============================] - 0s 126us/sample - loss: 0.1540 - acc: 0.9600
# Epoch 109/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1445 - acc: 0.9800
# Epoch 110/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1640 - acc: 0.9667
# Epoch 111/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.2248 - acc: 0.9400
# Epoch 112/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.1988 - acc: 0.9333
# Epoch 113/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1511 - acc: 0.9600
# Epoch 114/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.1733 - acc: 0.9533
# Epoch 115/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1615 - acc: 0.9533
# Epoch 116/500
# 150/150 [==============================] - 0s 154us/sample - loss: 0.1824 - acc: 0.9400
# Epoch 117/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1697 - acc: 0.9333
# Epoch 118/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.1384 - acc: 0.9533
# Epoch 119/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.2283 - acc: 0.9400
# Epoch 120/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.1526 - acc: 0.9600
# Epoch 121/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.1929 - acc: 0.9400
# Epoch 122/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.1456 - acc: 0.9600
# Epoch 123/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.1319 - acc: 0.9600
# Epoch 124/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.2447 - acc: 0.9200
# Epoch 125/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.2189 - acc: 0.9467
# Epoch 126/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.2232 - acc: 0.9467
# Epoch 127/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.1804 - acc: 0.9400
# Epoch 128/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1291 - acc: 0.9667
# Epoch 129/500
# 150/150 [==============================] - 0s 163us/sample - loss: 0.1578 - acc: 0.9667
# Epoch 130/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.1615 - acc: 0.9667
# Epoch 131/500
# 150/150 [==============================] - 0s 169us/sample - loss: 0.1302 - acc: 0.9600
# Epoch 132/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1315 - acc: 0.9733
# Epoch 133/500
# 150/150 [==============================] - 0s 168us/sample - loss: 0.1378 - acc: 0.9600
# Epoch 134/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.1096 - acc: 0.9800
# Epoch 135/500
# 150/150 [==============================] - 0s 185us/sample - loss: 0.1343 - acc: 0.9733
# Epoch 136/500
# 150/150 [==============================] - 0s 179us/sample - loss: 0.1449 - acc: 0.9600
# Epoch 137/500
# 150/150 [==============================] - 0s 163us/sample - loss: 0.1365 - acc: 0.9533
# Epoch 138/500
# 150/150 [==============================] - 0s 184us/sample - loss: 0.1805 - acc: 0.9333
# Epoch 139/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.1343 - acc: 0.9667
# Epoch 140/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.2593 - acc: 0.8933
# Epoch 141/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.1243 - acc: 0.9600
# Epoch 142/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.2030 - acc: 0.9400
# Epoch 143/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.2419 - acc: 0.9600
# Epoch 144/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.1186 - acc: 0.9533
# Epoch 145/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.2255 - acc: 0.9333
# Epoch 146/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.1315 - acc: 0.9667
# Epoch 147/500
# 150/150 [==============================] - 0s 122us/sample - loss: 0.1732 - acc: 0.9467
# Epoch 148/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1429 - acc: 0.9533
# Epoch 149/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.2424 - acc: 0.9467
# Epoch 150/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1092 - acc: 0.9667
# Epoch 151/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.1560 - acc: 0.9467
# Epoch 152/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1470 - acc: 0.9600
# Epoch 153/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.1831 - acc: 0.9400
# Epoch 154/500
# 150/150 [==============================] - 0s 168us/sample - loss: 0.1245 - acc: 0.9533
# Epoch 155/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.1747 - acc: 0.9533
# Epoch 156/500
# 150/150 [==============================] - 0s 158us/sample - loss: 0.1290 - acc: 0.9733
# Epoch 157/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.1773 - acc: 0.9333
# Epoch 158/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.1419 - acc: 0.9600
# Epoch 159/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1336 - acc: 0.9667
# Epoch 160/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.1095 - acc: 0.9667
# Epoch 161/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.1610 - acc: 0.9533
# Epoch 162/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.1618 - acc: 0.9533
# Epoch 163/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.1265 - acc: 0.9667
# Epoch 164/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1520 - acc: 0.9267
# Epoch 165/500
# 150/150 [==============================] - 0s 191us/sample - loss: 0.1100 - acc: 0.9733
# Epoch 166/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1374 - acc: 0.9667
# Epoch 167/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.1129 - acc: 0.9600
# Epoch 168/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.1261 - acc: 0.9600
# Epoch 169/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.1342 - acc: 0.9733
# Epoch 170/500
# 150/150 [==============================] - 0s 168us/sample - loss: 0.0781 - acc: 0.9733
# Epoch 171/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.1732 - acc: 0.9533
# Epoch 172/500
# 150/150 [==============================] - 0s 163us/sample - loss: 0.1053 - acc: 0.9733
# Epoch 173/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.1070 - acc: 0.9733
# Epoch 174/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.2870 - acc: 0.9267
# Epoch 175/500
# 150/150 [==============================] - 0s 192us/sample - loss: 0.1059 - acc: 0.9733
# Epoch 176/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.1123 - acc: 0.9733
# Epoch 177/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0769 - acc: 0.9667
# Epoch 178/500
# 150/150 [==============================] - 0s 184us/sample - loss: 0.0838 - acc: 0.9733
# Epoch 179/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0804 - acc: 0.9733
# Epoch 180/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0965 - acc: 0.9733
# Epoch 181/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.1190 - acc: 0.9733
# Epoch 182/500
# 150/150 [==============================] - 0s 169us/sample - loss: 0.1340 - acc: 0.9533
# Epoch 183/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.1404 - acc: 0.9667
# Epoch 184/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.0829 - acc: 0.9800
# Epoch 185/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.0924 - acc: 0.9800
# Epoch 186/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.1568 - acc: 0.9600
# Epoch 187/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0826 - acc: 0.9733
# Epoch 188/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.1701 - acc: 0.9600
# Epoch 189/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.1516 - acc: 0.9800
# Epoch 190/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.1077 - acc: 0.9667
# Epoch 191/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.1831 - acc: 0.9600
# Epoch 192/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0677 - acc: 0.9800
# Epoch 193/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0768 - acc: 0.9867
# Epoch 194/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0956 - acc: 0.9600
# Epoch 195/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0822 - acc: 0.9800
# Epoch 196/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.0639 - acc: 0.9800
# Epoch 197/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0972 - acc: 0.9533
# Epoch 198/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.1316 - acc: 0.9600
# Epoch 199/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0712 - acc: 0.9867
# Epoch 200/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1564 - acc: 0.9533
# Epoch 201/500
# 150/150 [==============================] - 0s 158us/sample - loss: 0.0631 - acc: 0.9800
# Epoch 202/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0706 - acc: 0.9800
# Epoch 203/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.1063 - acc: 0.9733
# Epoch 204/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.1145 - acc: 0.9533
# Epoch 205/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0829 - acc: 0.9733
# Epoch 206/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0664 - acc: 0.9800
# Epoch 207/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1024 - acc: 0.9600
# Epoch 208/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.1759 - acc: 0.9533
# Epoch 209/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.0695 - acc: 0.9733
# Epoch 210/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0696 - acc: 0.9600
# Epoch 211/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.0750 - acc: 0.9667
# Epoch 212/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0697 - acc: 0.9667
# Epoch 213/500
# 150/150 [==============================] - 0s 190us/sample - loss: 0.0707 - acc: 0.9800
# Epoch 214/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.0825 - acc: 0.9733
# Epoch 215/500
# 150/150 [==============================] - 0s 180us/sample - loss: 0.0420 - acc: 0.9933
# Epoch 216/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.1796 - acc: 0.9600
# Epoch 217/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0677 - acc: 0.9800
# Epoch 218/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0624 - acc: 0.9867
# Epoch 219/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0971 - acc: 0.9733
# Epoch 220/500
# 150/150 [==============================] - 0s 177us/sample - loss: 0.1099 - acc: 0.9400
# Epoch 221/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.0897 - acc: 0.9667
# Epoch 222/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.0787 - acc: 0.9800
# Epoch 223/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.0648 - acc: 0.9733
# Epoch 224/500
# 150/150 [==============================] - 0s 167us/sample - loss: 0.1205 - acc: 0.9467
# Epoch 225/500
# 150/150 [==============================] - 0s 167us/sample - loss: 0.1377 - acc: 0.9600
# Epoch 226/500
# 150/150 [==============================] - 0s 192us/sample - loss: 0.0667 - acc: 0.9667
# Epoch 227/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.1315 - acc: 0.9533
# Epoch 228/500
# 150/150 [==============================] - 0s 177us/sample - loss: 0.1121 - acc: 0.9533
# Epoch 229/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.1807 - acc: 0.9400
# Epoch 230/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.1768 - acc: 0.9400
# Epoch 231/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0969 - acc: 0.9600
# Epoch 232/500
# 150/150 [==============================] - 0s 126us/sample - loss: 0.0499 - acc: 0.9733
# Epoch 233/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0967 - acc: 0.9733
# Epoch 234/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0992 - acc: 0.9733
# Epoch 235/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0870 - acc: 0.9733
# Epoch 236/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.1337 - acc: 0.9667
# Epoch 237/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0959 - acc: 0.9800
# Epoch 238/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0761 - acc: 0.9667
# Epoch 239/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0835 - acc: 0.9467
# Epoch 240/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.0664 - acc: 0.9800
# Epoch 241/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.1343 - acc: 0.9667
# Epoch 242/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0621 - acc: 0.9800
# Epoch 243/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.2044 - acc: 0.9400
# Epoch 244/500
# 150/150 [==============================] - 0s 179us/sample - loss: 0.1042 - acc: 0.9800
# Epoch 245/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1186 - acc: 0.9600
# Epoch 246/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.0910 - acc: 0.9800
# Epoch 247/500
# 150/150 [==============================] - 0s 182us/sample - loss: 0.0838 - acc: 0.9733
# Epoch 248/500
# 150/150 [==============================] - 0s 207us/sample - loss: 0.1738 - acc: 0.9467
# Epoch 249/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.0606 - acc: 0.9933
# Epoch 250/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1155 - acc: 0.9733
# Epoch 251/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0964 - acc: 0.9667
# Epoch 252/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.0741 - acc: 0.9667
# Epoch 253/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.0783 - acc: 0.9600
# Epoch 254/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.1262 - acc: 0.9800
# Epoch 255/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.1152 - acc: 0.9667
# Epoch 256/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0696 - acc: 0.9800
# Epoch 257/500
# 150/150 [==============================] - 0s 171us/sample - loss: 0.0648 - acc: 0.9733
# Epoch 258/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.1061 - acc: 0.9600
# Epoch 259/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0792 - acc: 0.9800
# Epoch 260/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0956 - acc: 0.9800
# Epoch 261/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0614 - acc: 0.9800
# Epoch 262/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.1047 - acc: 0.9800
# Epoch 263/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0816 - acc: 0.9600
# Epoch 264/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0568 - acc: 0.9867
# Epoch 265/500
# 150/150 [==============================] - 0s 128us/sample - loss: 0.1521 - acc: 0.9733
# Epoch 266/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1733 - acc: 0.9533
# Epoch 267/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0759 - acc: 0.9867
# Epoch 268/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0579 - acc: 0.9800
# Epoch 269/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.0630 - acc: 0.9800
# Epoch 270/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1723 - acc: 0.9467
# Epoch 271/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.0942 - acc: 0.9600
# Epoch 272/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.0686 - acc: 0.9867
# Epoch 273/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0420 - acc: 0.9867
# Epoch 274/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.0402 - acc: 0.9867
# Epoch 275/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.1061 - acc: 0.9733
# Epoch 276/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.0651 - acc: 0.9800
# Epoch 277/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.0871 - acc: 0.9733
# Epoch 278/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.1006 - acc: 0.9600
# Epoch 279/500
# 150/150 [==============================] - 0s 167us/sample - loss: 0.1059 - acc: 0.9733
# Epoch 280/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.0756 - acc: 0.9733
# Epoch 281/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1140 - acc: 0.9600
# Epoch 282/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.1224 - acc: 0.9733
# Epoch 283/500
# 150/150 [==============================] - 0s 171us/sample - loss: 0.1002 - acc: 0.9733
# Epoch 284/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.0734 - acc: 0.9867
# Epoch 285/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0459 - acc: 0.9800
# Epoch 286/500
# 150/150 [==============================] - 0s 196us/sample - loss: 0.0672 - acc: 0.9800
# Epoch 287/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1496 - acc: 0.9533
# Epoch 288/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.1078 - acc: 0.9733
# Epoch 289/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0773 - acc: 0.9733
# Epoch 290/500
# 150/150 [==============================] - 0s 184us/sample - loss: 0.1200 - acc: 0.9733
# Epoch 291/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.0754 - acc: 0.9733
# Epoch 292/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.1131 - acc: 0.9600
# Epoch 293/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.2780 - acc: 0.9133
# Epoch 294/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0946 - acc: 0.9733
# Epoch 295/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.0586 - acc: 0.9867
# Epoch 296/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0703 - acc: 0.9733
# Epoch 297/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.1446 - acc: 0.9733
# Epoch 298/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.1198 - acc: 0.9733
# Epoch 299/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0438 - acc: 0.9867
# Epoch 300/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0426 - acc: 0.9867
# Epoch 301/500
# 150/150 [==============================] - 0s 123us/sample - loss: 0.0784 - acc: 0.9733
# Epoch 302/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0515 - acc: 0.9867
# Epoch 303/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0916 - acc: 0.9667
# Epoch 304/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.0618 - acc: 0.9800
# Epoch 305/500
# 150/150 [==============================] - 0s 125us/sample - loss: 0.0519 - acc: 0.9800
# Epoch 306/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.1450 - acc: 0.9800
# Epoch 307/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.1396 - acc: 0.9533
# Epoch 308/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0659 - acc: 0.9733
# Epoch 309/500
# 150/150 [==============================] - 0s 206us/sample - loss: 0.0863 - acc: 0.9600
# Epoch 310/500
# 150/150 [==============================] - 0s 170us/sample - loss: 0.0798 - acc: 0.9600
# Epoch 311/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0494 - acc: 0.9867
# Epoch 312/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0531 - acc: 0.9933
# Epoch 313/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1004 - acc: 0.9733
# Epoch 314/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.0316 - acc: 0.9867
# Epoch 315/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0516 - acc: 0.9733
# Epoch 316/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.0455 - acc: 0.9933
# Epoch 317/500
# 150/150 [==============================] - 0s 122us/sample - loss: 0.0751 - acc: 0.9600
# Epoch 318/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.0895 - acc: 0.9667
# Epoch 319/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0720 - acc: 0.9800
# Epoch 320/500
# 150/150 [==============================] - 0s 120us/sample - loss: 0.0586 - acc: 0.9667
# Epoch 321/500
# 150/150 [==============================] - 0s 128us/sample - loss: 0.0976 - acc: 0.9800
# Epoch 322/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.0793 - acc: 0.9667
# Epoch 323/500
# 150/150 [==============================] - 0s 121us/sample - loss: 0.0544 - acc: 0.9867
# Epoch 324/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0410 - acc: 0.9867
# Epoch 325/500
# 150/150 [==============================] - 0s 181us/sample - loss: 0.0378 - acc: 0.9800
# Epoch 326/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.0819 - acc: 0.9733
# Epoch 327/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0487 - acc: 0.9800
# Epoch 328/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0916 - acc: 0.9800
# Epoch 329/500
# 150/150 [==============================] - 0s 175us/sample - loss: 0.0850 - acc: 0.9667
# Epoch 330/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.0731 - acc: 0.9667
# Epoch 331/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0778 - acc: 0.9800
# Epoch 332/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0389 - acc: 0.9800
# Epoch 333/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0477 - acc: 0.9867
# Epoch 334/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.0752 - acc: 0.9600
# Epoch 335/500
# 150/150 [==============================] - 0s 160us/sample - loss: 0.0945 - acc: 0.9667
# Epoch 336/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0678 - acc: 0.9867
# Epoch 337/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0954 - acc: 0.9600
# Epoch 338/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.0819 - acc: 0.9800
# Epoch 339/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0650 - acc: 0.9600
# Epoch 340/500
# 150/150 [==============================] - 0s 150us/sample - loss: 0.1324 - acc: 0.9600
# Epoch 341/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0509 - acc: 0.9867
# Epoch 342/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.1062 - acc: 0.9600
# Epoch 343/500
# 150/150 [==============================] - 0s 126us/sample - loss: 0.0911 - acc: 0.9733
# Epoch 344/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0490 - acc: 0.9800
# Epoch 345/500
# 150/150 [==============================] - 0s 163us/sample - loss: 0.1084 - acc: 0.9667
# Epoch 346/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.1975 - acc: 0.9467
# Epoch 347/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0493 - acc: 0.9867
# Epoch 348/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.0586 - acc: 0.9867
# Epoch 349/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.0585 - acc: 0.9733
# Epoch 350/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0812 - acc: 0.9667
# Epoch 351/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0932 - acc: 0.9867
# Epoch 352/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0540 - acc: 0.9733
# Epoch 353/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0547 - acc: 0.9733
# Epoch 354/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.1072 - acc: 0.9533
# Epoch 355/500
# 150/150 [==============================] - 0s 124us/sample - loss: 0.0903 - acc: 0.9800
# Epoch 356/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.1082 - acc: 0.9533
# Epoch 357/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.1303 - acc: 0.9733
# Epoch 358/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.1971 - acc: 0.9400
# Epoch 359/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0998 - acc: 0.9867
# Epoch 360/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0745 - acc: 0.9867
# Epoch 361/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.0663 - acc: 0.9800
# Epoch 362/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.0712 - acc: 0.9800
# Epoch 363/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0382 - acc: 0.9933
# Epoch 364/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0872 - acc: 0.9733
# Epoch 365/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.0790 - acc: 0.9533
# Epoch 366/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0604 - acc: 0.9800
# Epoch 367/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.1111 - acc: 0.9533
# Epoch 368/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.1112 - acc: 0.9733
# Epoch 369/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.0665 - acc: 0.9667
# Epoch 370/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.1025 - acc: 0.9667
# Epoch 371/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0887 - acc: 0.9667
# Epoch 372/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.1038 - acc: 0.9733
# Epoch 373/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0659 - acc: 0.9800
# Epoch 374/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.0569 - acc: 0.9733
# Epoch 375/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0946 - acc: 0.9667
# Epoch 376/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0401 - acc: 0.9800
# Epoch 377/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0365 - acc: 0.9867
# Epoch 378/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0789 - acc: 0.9800
# Epoch 379/500
# 150/150 [==============================] - 0s 229us/sample - loss: 0.0803 - acc: 0.9800
# Epoch 380/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0294 - acc: 0.9933
# Epoch 381/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0565 - acc: 0.9867
# Epoch 382/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0456 - acc: 0.9800
# Epoch 383/500
# 150/150 [==============================] - 0s 176us/sample - loss: 0.0500 - acc: 0.9867
# Epoch 384/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.1528 - acc: 0.9667
# Epoch 385/500
# 150/150 [==============================] - 0s 173us/sample - loss: 0.0829 - acc: 0.9800
# Epoch 386/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.0557 - acc: 0.9867
# Epoch 387/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.0697 - acc: 0.9800
# Epoch 388/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1062 - acc: 0.9600
# Epoch 389/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.0798 - acc: 0.9600
# Epoch 390/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0383 - acc: 1.0000
# Epoch 391/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.1129 - acc: 0.9800
# Epoch 392/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0426 - acc: 0.9800
# Epoch 393/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0633 - acc: 0.9733
# Epoch 394/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0427 - acc: 0.9867
# Epoch 395/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0573 - acc: 0.9733
# Epoch 396/500
# 150/150 [==============================] - 0s 170us/sample - loss: 0.0475 - acc: 0.9800
# Epoch 397/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0463 - acc: 0.9867
# Epoch 398/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0521 - acc: 0.9800
# Epoch 399/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.0697 - acc: 0.9600
# Epoch 400/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0654 - acc: 0.9867
# Epoch 401/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0378 - acc: 0.9867
# Epoch 402/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.0520 - acc: 0.9933
# Epoch 403/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0989 - acc: 0.9800
# Epoch 404/500
# 150/150 [==============================] - 0s 128us/sample - loss: 0.0642 - acc: 0.9733
# Epoch 405/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.1267 - acc: 0.9667
# Epoch 406/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.0379 - acc: 0.9867
# Epoch 407/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0450 - acc: 0.9867
# Epoch 408/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0734 - acc: 0.9800
# Epoch 409/500
# 150/150 [==============================] - 0s 139us/sample - loss: 0.0977 - acc: 0.9667
# Epoch 410/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.1093 - acc: 0.9733
# Epoch 411/500
# 150/150 [==============================] - 0s 127us/sample - loss: 0.0735 - acc: 0.9800
# Epoch 412/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0748 - acc: 0.9600
# Epoch 413/500
# 150/150 [==============================] - 0s 179us/sample - loss: 0.0769 - acc: 0.9733
# Epoch 414/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0500 - acc: 0.9800
# Epoch 415/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0821 - acc: 0.9733
# Epoch 416/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0644 - acc: 0.9667
# Epoch 417/500
# 150/150 [==============================] - 0s 159us/sample - loss: 0.0773 - acc: 0.9800
# Epoch 418/500
# 150/150 [==============================] - 0s 147us/sample - loss: 0.0374 - acc: 0.9867
# Epoch 419/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.0929 - acc: 0.9667
# Epoch 420/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.1958 - acc: 0.9667
# Epoch 421/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0771 - acc: 0.9667
# Epoch 422/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0411 - acc: 0.9933
# Epoch 423/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0364 - acc: 0.9867
# Epoch 424/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0361 - acc: 0.9933
# Epoch 425/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.0625 - acc: 0.9800
# Epoch 426/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0436 - acc: 0.9800
# Epoch 427/500
# 150/150 [==============================] - 0s 167us/sample - loss: 0.0440 - acc: 0.9733
# Epoch 428/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.1137 - acc: 0.9667
# Epoch 429/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.1145 - acc: 0.9667
# Epoch 430/500
# 150/150 [==============================] - 0s 155us/sample - loss: 0.1626 - acc: 0.9533
# Epoch 431/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0484 - acc: 0.9800
# Epoch 432/500
# 150/150 [==============================] - 0s 130us/sample - loss: 0.0459 - acc: 0.9800
# Epoch 433/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0657 - acc: 0.9867
# Epoch 434/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0705 - acc: 0.9733
# Epoch 435/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0575 - acc: 0.9733
# Epoch 436/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.0387 - acc: 0.9933
# Epoch 437/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0534 - acc: 0.9800
# Epoch 438/500
# 150/150 [==============================] - 0s 136us/sample - loss: 0.0365 - acc: 0.9933
# Epoch 439/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0576 - acc: 0.9733
# Epoch 440/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.1060 - acc: 0.9733
# Epoch 441/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0634 - acc: 0.9667
# Epoch 442/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0562 - acc: 0.9800
# Epoch 443/500
# 150/150 [==============================] - 0s 143us/sample - loss: 0.1008 - acc: 0.9867
# Epoch 444/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.0434 - acc: 0.9867
# Epoch 445/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0679 - acc: 0.9600
# Epoch 446/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0832 - acc: 0.9667
# Epoch 447/500
# 150/150 [==============================] - 0s 132us/sample - loss: 0.0480 - acc: 0.9867
# Epoch 448/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0825 - acc: 0.9733
# Epoch 449/500
# 150/150 [==============================] - 0s 158us/sample - loss: 0.0638 - acc: 0.9733
# Epoch 450/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.0706 - acc: 0.9600
# Epoch 451/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.1699 - acc: 0.9467
# Epoch 452/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0735 - acc: 0.9733
# Epoch 453/500
# 150/150 [==============================] - 0s 152us/sample - loss: 0.0523 - acc: 0.9800
# Epoch 454/500
# 150/150 [==============================] - 0s 140us/sample - loss: 0.0624 - acc: 0.9800
# Epoch 455/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.1284 - acc: 0.9733
# Epoch 456/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.1062 - acc: 0.9733
# Epoch 457/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.0614 - acc: 0.9867
# Epoch 458/500
# 150/150 [==============================] - 0s 133us/sample - loss: 0.0746 - acc: 0.9800
# Epoch 459/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0621 - acc: 0.9733
# Epoch 460/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0529 - acc: 0.9867
# Epoch 461/500
# 150/150 [==============================] - 0s 145us/sample - loss: 0.0354 - acc: 0.9867
# Epoch 462/500
# 150/150 [==============================] - 0s 142us/sample - loss: 0.0437 - acc: 0.9800
# Epoch 463/500
# 150/150 [==============================] - 0s 185us/sample - loss: 0.0399 - acc: 0.9867
# Epoch 464/500
# 150/150 [==============================] - 0s 146us/sample - loss: 0.1191 - acc: 0.9800
# Epoch 465/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.0453 - acc: 0.9800
# Epoch 466/500
# 150/150 [==============================] - 0s 149us/sample - loss: 0.0802 - acc: 0.9667
# Epoch 467/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.1492 - acc: 0.9467
# Epoch 468/500
# 150/150 [==============================] - 0s 183us/sample - loss: 0.1056 - acc: 0.9733
# Epoch 469/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.0768 - acc: 0.9733
# Epoch 470/500
# 150/150 [==============================] - 0s 165us/sample - loss: 0.0181 - acc: 1.0000
# Epoch 471/500
# 150/150 [==============================] - 0s 198us/sample - loss: 0.0498 - acc: 0.9800
# Epoch 472/500
# 150/150 [==============================] - 0s 164us/sample - loss: 0.0308 - acc: 0.9933
# Epoch 473/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.0286 - acc: 0.9933
# Epoch 474/500
# 150/150 [==============================] - 0s 169us/sample - loss: 0.0697 - acc: 0.9800
# Epoch 475/500
# 150/150 [==============================] - 0s 174us/sample - loss: 0.0493 - acc: 0.9800
# Epoch 476/500
# 150/150 [==============================] - 0s 161us/sample - loss: 0.0968 - acc: 0.9733
# Epoch 477/500
# 150/150 [==============================] - 0s 178us/sample - loss: 0.0497 - acc: 0.9933
# Epoch 478/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.2325 - acc: 0.9000
# Epoch 479/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.0858 - acc: 0.9800
# Epoch 480/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.1140 - acc: 0.9667
# Epoch 481/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.0687 - acc: 0.9867
# Epoch 482/500
# 150/150 [==============================] - 0s 173us/sample - loss: 0.1133 - acc: 0.9600
# Epoch 483/500
# 150/150 [==============================] - 0s 153us/sample - loss: 0.0845 - acc: 0.9800
# Epoch 484/500
# 150/150 [==============================] - 0s 157us/sample - loss: 0.2224 - acc: 0.9667
# Epoch 485/500
# 150/150 [==============================] - 0s 162us/sample - loss: 0.1541 - acc: 0.9667
# Epoch 486/500
# 150/150 [==============================] - 0s 148us/sample - loss: 0.1444 - acc: 0.9600
# Epoch 487/500
# 150/150 [==============================] - 0s 141us/sample - loss: 0.1881 - acc: 0.9600
# Epoch 488/500
# 150/150 [==============================] - 0s 129us/sample - loss: 0.0912 - acc: 0.9867
# Epoch 489/500
# 150/150 [==============================] - 0s 156us/sample - loss: 0.0790 - acc: 0.9800
# Epoch 490/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.1041 - acc: 0.9600
# Epoch 491/500
# 150/150 [==============================] - 0s 138us/sample - loss: 0.1227 - acc: 0.9600
# Epoch 492/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.0984 - acc: 0.9800
# Epoch 493/500
# 150/150 [==============================] - 0s 137us/sample - loss: 0.1701 - acc: 0.9733
# Epoch 494/500
# 150/150 [==============================] - 0s 131us/sample - loss: 0.0873 - acc: 0.9800
# Epoch 495/500
# 150/150 [==============================] - 0s 134us/sample - loss: 0.0562 - acc: 0.9867
# Epoch 496/500
# 150/150 [==============================] - 0s 163us/sample - loss: 0.0900 - acc: 0.9733
# Epoch 497/500
# 150/150 [==============================] - 0s 135us/sample - loss: 0.2096 - acc: 0.9267
# Epoch 498/500
# 150/150 [==============================] - 0s 151us/sample - loss: 0.2144 - acc: 0.9467
# Epoch 499/500
# 150/150 [==============================] - 0s 144us/sample - loss: 0.0952 - acc: 0.9800
# Epoch 500/500
# 150/150 [==============================] - 0s 166us/sample - loss: 0.1125 - acc: 0.9733

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense,BatchNormalization #Importar BatchNorm
# from keras.utils import to_categorical
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# modelo=Sequential()
# modelo.add(Dense(4,activation='relu',input_shape=(4,)))
# modelo.add(Dense(4,activation='relu'))
# modelo.add(BatchNormalization())
# modelo.add(Dense(4,activation='relu'))
# modelo.add(Dense(3,activation='softmax'))
# modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# ----->

# %% [markdown]
# # Regularización

# %% [markdown]
# **Ejercicio:** Entrene una red neuronal para el dataset iris con 3 capas ocultas de 4 neuronas cada una con función de activación ReLU y **regularización L2** en los pesos y **regularización L1** en los bias.

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense,BatchNormalization
# from keras.utils import to_categorical
# from keras.regularizers import l1,l2 #Importar Regularizadores
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# l2_reg=l2()
# l1_reg=l1(0.001)
# modelo=Sequential()
# modelo.add(Dense(4,activation='relu',kernel_regularizer=l2_reg,bias_regularizer=l1_reg,input_shape=(4,)))
# modelo.add(Dense(4,activation='relu',kernel_regularizer='l2',bias_regularizer='l1')) #puedo simplemente escribir "l1" o "l2"
# modelo.add(Dense(4,activation='relu',kernel_regularizer='l2',bias_regularizer='l1'))
# modelo.add(Dense(3,activation='softmax',kernel_regularizer='l2',bias_regularizer='l1'))
# modelo.compile('sgd',loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500)
# ----->

# %% [markdown]
# # Optimizadores

# %% [markdown]
# Vimos que la técnica de propagación hacia atrás utiliza el gradiente de descenso para ealizar la optimización de los pesos en cada pasada.
#
# La actualización mediante el gradiente de descenso lo hemos definico como:
#
# $$w_{t}=w_{t-1}-\eta  \nabla C(w)$$
#
# Donde $\eta$ es llamado la taza de aprendizaje, éste debe escogerse de tal forma que no sea tan pequeño como para hacer muy lenta la convergencia, ni muy grande como para hacer que nuestros pesos diverjan.
#
# Uno de los  mayores incovenientes con éste algoritmo es que en el caso de las funciones de coste no convexas es probable quedar atrapado en un mínimo local, y jamás llegar a un mínimo global, para mitigar dicha posibilidad se han creado algunas variaciones como el gradiente de descenso estocástico o el gradiente de descenso por minibatch.
#
# ### Gradiente de descenso estocástico.
#
# Como es planteado el gradiente de descenso solo hace un recalculo de los parámetros del modelo una vez ha hecho un paso completo de todos los ejemplos, ésto hace que el algorítmo sea de lenta convergencia y en caso de tener muchos ejemplos de entrenamiento pueda desbordar la memoria de la máquina.
#
# En el gradiente estocástico se realiza una actualización cada que se ha entregado un ejemplo a la red, con eésto se consigue una mayor varianza y por tanto las actualizaciones fluctuan en intensidad y es más difícil que el algoritmo quede atrapado en un mínimo local si éste no es bastante "profundo" lo cual garantiza mínimos más estables.
#
# ### Gradiente de descenso por minibatch.
#
# Una de las desventajas del SDG reside en que al hacer una actualización por ejemplo puede ser bastante lento, una solución intermedia es pasar unos cuantos ejemplos antes de hacer la actualización (entregar un batch), con ello aumentamos la velocidad de entrenamiento pero no perdemos la ventaja de generar varianza sobre las actualizaciones para evitar ser atrabados en un mínimo local.
#
# Todos éstos métodos utilizan la mísma ecuación y la mísma idea de fondo, se diferencian en la cantidad de ejemplos pasados por la red antes de realizar la actualización de los pesos.

# %% [markdown]
# ## Momentum.
#
# Dado que los métodos de descenso de gradiente calculan las variaciones en todas direcciones suelen oscilar de forma innecesaria, lo cual hace que su convergencia sea más lenta. Para solucionar ésto se usa la técnica de momentum, en analogía con el momentum de la física clásica.
#
# Cuando una pelota rudea por una pendiente su velocidad aumenta en la dirección de movimiento (su derivada), mientras que en las demás direcciones no lo hace. En el método se sigue la misma idea, la actualización se hará en las direcciones en las que el gradiente aumentó más la actualización pasada, así nos aseguramos de no actualizar (demasiado) los pesos de manera innecesaria en direcciones que no contribuyen a la busqueda del mínimo.
#
# Si ahora notamos el paso de actualización de los pesos como: $$w_t = w_{t-1}-V(t)$$
#
# El $V$ en la iteración $t$ estará dado por:
#
# $$V(t) = \gamma V(t-1)+\eta \nabla (w)$$
#
# Ahora tenémos un hiperparámetro nuevo $\gamma$ que se encargará de determinar qué tanto influencia la actualización pasada a la actual, generalmente será un número al rededor de $0.9$

# %% [markdown]
# ## Gradiente acelerado de Nesterov.
#
# En los años 80 el investigador Yurii Nesterov se dio cuenta que el momentum tenía un problema, al igual que en la analogía de la pelota, al llegar al mínimo el momento remanente empuja la pelota un poco más arriba del mínimo, también pasará lo mismo en el caso del error de la red, ésto puede demorar la convergencia o incluso hacer que el error no converja nunca.
#
# Para solucionar dícho problema Nasterov propuso no solo usar la influencia de la actualización pasada en la actualización presente si no que también se tendría en cuenta para el cálculo del gradiente (similar a tener en cuenta la aceleración para determinar que tan cerca se está de un cambio de direción).
#
# Así tenemos que:
#
# $$V(t) = \gamma V(t-1)+\eta \nabla (w- \gamma V(t-1))$$
#
# Por tanto la actualización disminuirá su "momentum" al acercarce al mínimo y por tanto no se alejará mucho de él.

# %% [markdown]
# ## Adagrad y Adadelta.
#
# Adagrad (adaptative gradient) nos permite actualizar de manera adaptativa cada parámetro, haciendo grandes modificaciones a parámetros infrecuentes mientras que lo hará con más cuidado a parámetros frecuentes. Ésto será útil cuando tratemos con datos dispersos (sparse data).
#
# Cada parámetro $w_i$ será actualizado así:
#
# $$w_{i,t} = w_{i,t-1}-\frac{\eta}{\sqrt{G_{ii}+\epsilon}}\frac{\partial C }{\partial  w_i}$$
#
# El termino $G_{ii}$ es la acumulación de los gradientes pasados, $\epsilon$ es un número pequeño para evitar la divergencia al dividir por cero.
#
# Un problema con ésta técnica es el hecho de que al acumular los gradientes en el denominador poco a poco el gradiente se hace más y más suave (también sufre de una especie de desvanecimiento) además de que el tiempo de entrenamiento también se hará mayor pues los pasos serán cada vez menores.
#
# Para atacar el problema del desvanecimiento usaremos **Adadelta**, en éste caso no tomaremos toda la acumulación de gradientes si no que se hará con una ventana de tamaño $\rho$, definida por nosotros, con ello tenemos que el denominador será el RMS (sobre la vetana) de los gradientes, así:
# $$w_{i,t} = w_{i,t-1}-\frac{\eta}{RMS(\frac{\partial C }{\partial  w_i})}\frac{\partial C }{\partial  w_i}$$
#
# Ambas técnicas tienen la ventaja de no ser necesaria la definición de una razón de aprendizaje, ya que de manera iterativa ésta será calculada.

# %% [markdown]
# ## Adam (Adaptative moment estimator).
#
# Adam calculará tanto el promedio de los gradientes pasados  (como Adadelta), así como el promedio del decaimiento de los graientes pasados (como momentum).
#
# Por tanto Adam es un estimador de momentos estadísticos adaptatico (en cada iteración).
#
# El primer momento acumulado será:
# $$\hat{m} =\frac{m_t}{1-\beta_1^t}$$
#
# y el segundo:
# $$\hat{v} =\frac{v_t}{1-\beta_2^t}$$
#
# y la actualización de los pesos será adaptada como:
# $$w_{i,t} = w_{i,t-1}-\frac{\eta}{\hat{v}+\epsilon}\hat{m}$$
#
# $\beta_i$ serpan hiperparámetros del optimizador.
#
# Adam es uno de los mejores optimizadores ya que es rápido, evita las fluctuaciones exageradas de los parámetros en direcciones no convenientes, y el desvanecimiento de los gradientes.

# %% [markdown]
# ![](https://miro.medium.com/max/620/1*XVFmo9NxLnwDr3SxzKy-rA.gif)
#
# ![](https://miro.medium.com/max/620/1*SjtKOauOXFVjWRR7iCtHiA.gif)

# %% [markdown]
# # Optimizadores en Keras.
#
# Como sabemos, uno de los pasos fundamentales en Keras para definir y entrenar un modelo es compilarlo, allí debemos decidir cual será el método de optimización a usar, además de la función de perdida y las métricas a usar.
#
# Los diferéntes optimizadores se importan como `from keras import optimizers` [https://keras.io/optimizers/](https://keras.io/optimizers/)
#
# Allí encontraremos los anteriores (y unos cuantos más).
#
# Podemos llamarlos en el compilador de dos maneras:
#
#
#
# *   Instanciandolos antes del compilador.
# *   Llamandolos dentro del compilador.
# Veamos:

# %%
from tensorflow.keras import optimizers

model = Sequential()
model.add(Dense(64, kernel_initializer='uniform', input_shape=(10,),activation='softmax'))
#Instanciamos previo a llamarlo en el compilador, en éste caso podemos cambiar los parámetros del optimizador
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)

# %%
#dando su nombre como parámetro al compilador, en éste caso los parámetros del optimizador usados serán sus valores por defecto
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
#Para llamar un gradiente estocástico
#Recuerden que la difencia estará en cómo pasemos los bathc, además podemos darle un momentum o un nesterov,
#SDG contiene entonces los optimizadores SDG, momentum, y Nesterov en una sola clase
keras.optimizers.SGD(learning_rate=0.01, momentum=0.0, nesterov=False)

# %%
#Adagrad se llamará como:
#el learning_rate es el valor inicial de dicho parámetro, 
#recuerde que éste método es adaptativo y éste valor cambiará con las iteraciones
keras.optimizers.Adagrad(learning_rate=0.01)

# %%
#Adadelta será:
#El parámetro $\rho$ controla la fracción de gradientes a tener en cuenta en cada paso de optimización.
keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95)

# %%
#finalmente Adam
#donde amsgrad determina si se aplica una modificaión al método o no basada en https://openreview.net/forum?id=ryQu7f-RZ
keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

# %% [markdown]
# Recuerde que cada optimizador tendrá sus ventajas o desventajas dependiendo del problema, la función de coste y nuestro poder computacional.
# Por lo general el usdo de Adam o SDG con momentum serán una buena elección como primera prueba.
#
# Finalmete, en todos los optimizadores es posible usar los parámetros clipnorm (todos los valores de los gradientes serán recortados a una norma máxima) y clipvalue (todos los valores de los gradientes serán recortados a un valor mínimo de -n y máximo de n)

# %%
#los valores de los gradientes estarán como máximo en una norma de 1
sgd = optimizers.SGD(lr=0.01, clipnorm=1.)
#los valores de los gradientes estarán mínimo en -0.5 y máximo en 0.5
sgd = optimizers.SGD(lr=0.01, clipvalue=0.5)

# %% [markdown]
# **Ejercicio:** Entrene una red neuronal para el dataset iris con 3 capas ocultas de 4 neuronas cada una con función de activación ReLU inicializadando los pesos con glorot_normal y los bias en cero. Aplicar regularización L2 de los pesos y L1 de los bias. Adicionalmente, aplique Batch Normalization en la segunda capa oculta. Entrene la red usando el optimizador **Adam** con Gradient Clipping y usando un 20% como datos de validación.

# %% [markdown]
# Haga click **aquí** si tiene problemas con la solución:
#
# <!-----
# from sklearn.datasets import load_iris
# from keras.models import Sequential
# from keras.layers import Dense,BatchNormalization
# from keras.optimizers import Adam
# from keras.utils import to_categorical
# data=load_iris()
# X,y=data.data,data.target
# X-=X.mean(axis=0)
# X/=X.std(axis=0)
# y=to_categorical(y)
# modelo=Sequential()
# modelo.add(Dense(4,activation='relu',kernel_regularizer='l2',bias_regularizer='l1',kernel_initializer='glorot_normal',bias_initializer='zero',input_shape=(4,)))
# modelo.add(Dense(4,activation='relu',kernel_regularizer='l2',bias_regularizer='l1',kernel_initializer='glorot_normal',bias_initializer='zero'))
# modelo.add(BatchNormalization())
# modelo.add(Dense(4,activation='relu',kernel_regularizer='l2',bias_regularizer='l1',kernel_initializer='glorot_normal',bias_initializer='zero'))
# modelo.add(Dense(3,activation='softmax',kernel_regularizer='l2',bias_regularizer='l1',kernel_initializer='glorot_normal',bias_initializer='zero'))
# optim=Adam(clipnorm=1)
# modelo.compile(optim,loss='categorical_crossentropy',metrics=['accuracy'])
# modelo.summary()
# modelo.fit(x=X,y=y, batch_size=10,epochs=500,validation_split=0.2)
# ----->

# %%
from sklearn.datasets import load_iris
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
data=load_iris()
X,y=data.data,data.target
X-=X.mean(axis=0)
X/=X.std(axis=0)
y=to_categorical(y)

# %%
modelo=Sequential()
modelo.add(Dense(4,input_dim=4,activation='relu',kernel_initializer='glorot_normal',bias_initializer='zero',kernel_regularizer='l2',bias_regularizer='l1'))
modelo.add(Dropout(0.2))
modelo.add(Dense(4,activation='relu',kernel_initializer='glorot_normal',bias_initializer='zero',kernel_regularizer='l2',bias_regularizer='l1'))
modelo.add(BatchNormalization())
modelo.add(Dropout(0.2))
modelo.add(Dense(4,activation='relu',kernel_initializer='glorot_normal',bias_initializer='zero',kernel_regularizer='l2',bias_regularizer='l1'))
modelo.add(Dropout(0.2))
modelo.add(Dense(3,activation='softmax',kernel_initializer='glorot_normal',bias_initializer='zero',kernel_regularizer='l2',bias_regularizer='l1'))
modelo.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
modelo.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_44 (Dense)             (None, 4)                 20
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4)                 16
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_45 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_46 (Dense)             (None, 3)                 15
# =================================================================
# Total params: 91
# Trainable params: 83
# Non-trainable params: 8
# _________________________________________________________________

# %%
history=modelo.fit(x=X,y=y,validation_split=0.2,epochs=500)
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/500
# 120/120 [==============================] - 1s 10ms/sample - loss: 1.2291 - accuracy: 0.2750 - val_loss: 1.1993 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 120/120 [==============================] - 0s 176us/sample - loss: 1.2405 - accuracy: 0.2083 - val_loss: 1.2024 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 120/120 [==============================] - 0s 202us/sample - loss: 1.2085 - accuracy: 0.1833 - val_loss: 1.2053 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 120/120 [==============================] - 0s 181us/sample - loss: 1.2313 - accuracy: 0.2250 - val_loss: 1.2083 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 120/120 [==============================] - 0s 241us/sample - loss: 1.2180 - accuracy: 0.1833 - val_loss: 1.2108 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 120/120 [==============================] - 0s 205us/sample - loss: 1.2148 - accuracy: 0.2333 - val_loss: 1.2138 - val_accuracy: 0.0000e+00
# Epoch 7/500
# 120/120 [==============================] - 0s 191us/sample - loss: 1.1907 - accuracy: 0.2583 - val_loss: 1.2166 - val_accuracy: 0.0000e+00
# Epoch 8/500
# 120/120 [==============================] - 0s 200us/sample - loss: 1.1755 - accuracy: 0.2417 - val_loss: 1.2198 - val_accuracy: 0.0000e+00
# Epoch 9/500
# 120/120 [==============================] - 0s 192us/sample - loss: 1.1684 - accuracy: 0.2833 - val_loss: 1.2230 - val_accuracy: 0.0000e+00
# Epoch 10/500
# 120/120 [==============================] - 0s 190us/sample - loss: 1.1830 - accuracy: 0.2083 - val_loss: 1.2260 - val_accuracy: 0.0000e+00
# Epoch 11/500
# 120/120 [==============================] - 0s 206us/sample - loss: 1.1688 - accuracy: 0.2833 - val_loss: 1.2293 - val_accuracy: 0.0000e+00
# Epoch 12/500
# 120/120 [==============================] - 0s 280us/sample - loss: 1.1781 - accuracy: 0.2417 - val_loss: 1.2328 - val_accuracy: 0.0000e+00
# Epoch 13/500
# 120/120 [==============================] - 0s 216us/sample - loss: 1.1597 - accuracy: 0.2917 - val_loss: 1.2360 - val_accuracy: 0.0000e+00
# Epoch 14/500
# 120/120 [==============================] - 0s 238us/sample - loss: 1.1531 - accuracy: 0.3333 - val_loss: 1.2394 - val_accuracy: 0.0000e+00
# Epoch 15/500
# 120/120 [==============================] - 0s 286us/sample - loss: 1.1488 - accuracy: 0.2833 - val_loss: 1.2431 - val_accuracy: 0.0000e+00
# Epoch 16/500
# 120/120 [==============================] - 0s 245us/sample - loss: 1.1503 - accuracy: 0.3167 - val_loss: 1.2465 - val_accuracy: 0.0000e+00
# Epoch 17/500
# 120/120 [==============================] - 0s 212us/sample - loss: 1.1393 - accuracy: 0.3000 - val_loss: 1.2498 - val_accuracy: 0.0000e+00
# Epoch 18/500
# 120/120 [==============================] - 0s 219us/sample - loss: 1.1367 - accuracy: 0.2917 - val_loss: 1.2534 - val_accuracy: 0.0000e+00
# Epoch 19/500
# 120/120 [==============================] - 0s 240us/sample - loss: 1.1153 - accuracy: 0.4250 - val_loss: 1.2571 - val_accuracy: 0.0000e+00
# Epoch 20/500
# 120/120 [==============================] - 0s 241us/sample - loss: 1.1134 - accuracy: 0.3833 - val_loss: 1.2607 - val_accuracy: 0.0000e+00
# Epoch 21/500
# 120/120 [==============================] - 0s 226us/sample - loss: 1.1400 - accuracy: 0.3417 - val_loss: 1.2640 - val_accuracy: 0.0000e+00
# Epoch 22/500
# 120/120 [==============================] - 0s 257us/sample - loss: 1.1240 - accuracy: 0.4000 - val_loss: 1.2677 - val_accuracy: 0.0000e+00
# Epoch 23/500
# 120/120 [==============================] - 0s 243us/sample - loss: 1.1130 - accuracy: 0.4750 - val_loss: 1.2711 - val_accuracy: 0.0000e+00
# Epoch 24/500
# 120/120 [==============================] - 0s 237us/sample - loss: 1.1012 - accuracy: 0.4083 - val_loss: 1.2746 - val_accuracy: 0.0000e+00
# Epoch 25/500
# 120/120 [==============================] - 0s 235us/sample - loss: 1.1054 - accuracy: 0.4000 - val_loss: 1.2777 - val_accuracy: 0.0000e+00
# Epoch 26/500
# 120/120 [==============================] - 0s 219us/sample - loss: 1.0928 - accuracy: 0.4500 - val_loss: 1.2813 - val_accuracy: 0.0000e+00
# Epoch 27/500
# 120/120 [==============================] - 0s 220us/sample - loss: 1.0940 - accuracy: 0.4083 - val_loss: 1.2846 - val_accuracy: 0.0000e+00
# Epoch 28/500
# 120/120 [==============================] - 0s 219us/sample - loss: 1.0868 - accuracy: 0.4500 - val_loss: 1.2880 - val_accuracy: 0.0000e+00
# Epoch 29/500
# 120/120 [==============================] - 0s 223us/sample - loss: 1.0662 - accuracy: 0.4500 - val_loss: 1.2916 - val_accuracy: 0.0000e+00
# Epoch 30/500
# 120/120 [==============================] - 0s 207us/sample - loss: 1.0775 - accuracy: 0.4333 - val_loss: 1.2947 - val_accuracy: 0.0000e+00
# Epoch 31/500
# 120/120 [==============================] - 0s 232us/sample - loss: 1.0901 - accuracy: 0.4417 - val_loss: 1.2976 - val_accuracy: 0.0000e+00
# Epoch 32/500
# 120/120 [==============================] - 0s 202us/sample - loss: 1.0598 - accuracy: 0.4333 - val_loss: 1.3003 - val_accuracy: 0.0000e+00
# Epoch 33/500
# 120/120 [==============================] - 0s 224us/sample - loss: 1.0496 - accuracy: 0.4500 - val_loss: 1.3033 - val_accuracy: 0.0000e+00
# Epoch 34/500
# 120/120 [==============================] - 0s 283us/sample - loss: 1.0280 - accuracy: 0.5250 - val_loss: 1.3056 - val_accuracy: 0.0000e+00
# Epoch 35/500
# 120/120 [==============================] - 0s 235us/sample - loss: 1.0600 - accuracy: 0.4250 - val_loss: 1.3082 - val_accuracy: 0.0000e+00
# Epoch 36/500
# 120/120 [==============================] - 0s 233us/sample - loss: 1.0294 - accuracy: 0.5000 - val_loss: 1.3104 - val_accuracy: 0.0000e+00
# Epoch 37/500
# 120/120 [==============================] - 0s 216us/sample - loss: 1.0235 - accuracy: 0.4833 - val_loss: 1.3126 - val_accuracy: 0.0000e+00
# Epoch 38/500
# 120/120 [==============================] - 0s 206us/sample - loss: 1.0152 - accuracy: 0.5167 - val_loss: 1.3151 - val_accuracy: 0.0000e+00
# Epoch 39/500
# 120/120 [==============================] - 0s 201us/sample - loss: 1.0061 - accuracy: 0.4500 - val_loss: 1.3172 - val_accuracy: 0.0000e+00
# Epoch 40/500
# 120/120 [==============================] - 0s 197us/sample - loss: 1.0111 - accuracy: 0.5167 - val_loss: 1.3191 - val_accuracy: 0.0000e+00
# Epoch 41/500
# 120/120 [==============================] - 0s 246us/sample - loss: 1.0065 - accuracy: 0.6250 - val_loss: 1.3214 - val_accuracy: 0.0000e+00
# Epoch 42/500
# 120/120 [==============================] - 0s 266us/sample - loss: 0.9768 - accuracy: 0.6583 - val_loss: 1.3237 - val_accuracy: 0.0000e+00
# Epoch 43/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.9858 - accuracy: 0.7250 - val_loss: 1.3258 - val_accuracy: 0.0000e+00
# Epoch 44/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.9890 - accuracy: 0.6500 - val_loss: 1.3276 - val_accuracy: 0.0000e+00
# Epoch 45/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.9598 - accuracy: 0.6333 - val_loss: 1.3296 - val_accuracy: 0.0000e+00
# Epoch 46/500
# 120/120 [==============================] - 0s 217us/sample - loss: 0.9706 - accuracy: 0.6500 - val_loss: 1.3313 - val_accuracy: 0.0000e+00
# Epoch 47/500
# 120/120 [==============================] - 0s 239us/sample - loss: 0.9442 - accuracy: 0.6833 - val_loss: 1.3329 - val_accuracy: 0.0000e+00
# Epoch 48/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.9456 - accuracy: 0.6667 - val_loss: 1.3341 - val_accuracy: 0.0000e+00
# Epoch 49/500
# 120/120 [==============================] - 0s 264us/sample - loss: 0.9457 - accuracy: 0.6583 - val_loss: 1.3352 - val_accuracy: 0.0000e+00
# Epoch 50/500
# 120/120 [==============================] - 0s 256us/sample - loss: 0.9323 - accuracy: 0.7250 - val_loss: 1.3360 - val_accuracy: 0.0000e+00
# Epoch 51/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.9421 - accuracy: 0.6583 - val_loss: 1.3365 - val_accuracy: 0.0000e+00
# Epoch 52/500
# 120/120 [==============================] - 0s 247us/sample - loss: 0.9091 - accuracy: 0.6750 - val_loss: 1.3369 - val_accuracy: 0.0000e+00
# Epoch 53/500
# 120/120 [==============================] - 0s 271us/sample - loss: 0.8854 - accuracy: 0.6917 - val_loss: 1.3373 - val_accuracy: 0.0000e+00
# Epoch 54/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.9324 - accuracy: 0.6750 - val_loss: 1.3373 - val_accuracy: 0.0000e+00
# Epoch 55/500
# 120/120 [==============================] - 0s 254us/sample - loss: 0.9330 - accuracy: 0.6833 - val_loss: 1.3372 - val_accuracy: 0.0000e+00
# Epoch 56/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.8785 - accuracy: 0.7083 - val_loss: 1.3365 - val_accuracy: 0.0000e+00
# Epoch 57/500
# 120/120 [==============================] - 0s 217us/sample - loss: 0.9073 - accuracy: 0.7083 - val_loss: 1.3363 - val_accuracy: 0.0000e+00
# Epoch 58/500
# 120/120 [==============================] - 0s 255us/sample - loss: 0.9115 - accuracy: 0.6750 - val_loss: 1.3358 - val_accuracy: 0.0000e+00
# Epoch 59/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.8898 - accuracy: 0.6917 - val_loss: 1.3361 - val_accuracy: 0.0000e+00
# Epoch 60/500
# 120/120 [==============================] - 0s 265us/sample - loss: 0.8614 - accuracy: 0.7250 - val_loss: 1.3364 - val_accuracy: 0.0000e+00
# Epoch 61/500
# 120/120 [==============================] - 0s 267us/sample - loss: 0.8739 - accuracy: 0.7500 - val_loss: 1.3370 - val_accuracy: 0.0000e+00
# Epoch 62/500
# 120/120 [==============================] - 0s 279us/sample - loss: 0.8535 - accuracy: 0.7417 - val_loss: 1.3369 - val_accuracy: 0.0000e+00
# Epoch 63/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.8408 - accuracy: 0.7500 - val_loss: 1.3367 - val_accuracy: 0.0000e+00
# Epoch 64/500
# 120/120 [==============================] - 0s 267us/sample - loss: 0.8504 - accuracy: 0.7167 - val_loss: 1.3370 - val_accuracy: 0.0000e+00
# Epoch 65/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.8509 - accuracy: 0.7167 - val_loss: 1.3369 - val_accuracy: 0.0000e+00
# Epoch 66/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.8602 - accuracy: 0.7333 - val_loss: 1.3365 - val_accuracy: 0.0000e+00
# Epoch 67/500
# 120/120 [==============================] - 0s 236us/sample - loss: 0.8304 - accuracy: 0.7333 - val_loss: 1.3366 - val_accuracy: 0.0000e+00
# Epoch 68/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.8086 - accuracy: 0.7833 - val_loss: 1.3368 - val_accuracy: 0.0000e+00
# Epoch 69/500
# 120/120 [==============================] - 0s 214us/sample - loss: 0.8372 - accuracy: 0.7667 - val_loss: 1.3374 - val_accuracy: 0.0000e+00
# Epoch 70/500
# 120/120 [==============================] - 0s 231us/sample - loss: 0.7972 - accuracy: 0.7667 - val_loss: 1.3378 - val_accuracy: 0.0000e+00
# Epoch 71/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.8178 - accuracy: 0.7333 - val_loss: 1.3373 - val_accuracy: 0.0000e+00
# Epoch 72/500
# 120/120 [==============================] - 0s 230us/sample - loss: 0.8363 - accuracy: 0.7250 - val_loss: 1.3375 - val_accuracy: 0.0000e+00
# Epoch 73/500
# 120/120 [==============================] - 0s 223us/sample - loss: 0.7873 - accuracy: 0.7833 - val_loss: 1.3374 - val_accuracy: 0.0000e+00
# Epoch 74/500
# 120/120 [==============================] - 0s 206us/sample - loss: 0.8310 - accuracy: 0.7083 - val_loss: 1.3374 - val_accuracy: 0.0000e+00
# Epoch 75/500
# 120/120 [==============================] - 0s 198us/sample - loss: 0.7920 - accuracy: 0.7583 - val_loss: 1.3372 - val_accuracy: 0.0000e+00
# Epoch 76/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.8156 - accuracy: 0.7750 - val_loss: 1.3369 - val_accuracy: 0.0000e+00
# Epoch 77/500
# 120/120 [==============================] - 0s 216us/sample - loss: 0.8302 - accuracy: 0.7250 - val_loss: 1.3375 - val_accuracy: 0.0000e+00
# Epoch 78/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.7755 - accuracy: 0.7750 - val_loss: 1.3370 - val_accuracy: 0.0000e+00
# Epoch 79/500
# 120/120 [==============================] - 0s 232us/sample - loss: 0.8197 - accuracy: 0.7500 - val_loss: 1.3360 - val_accuracy: 0.0000e+00
# Epoch 80/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.7925 - accuracy: 0.7500 - val_loss: 1.3356 - val_accuracy: 0.0000e+00
# Epoch 81/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.7904 - accuracy: 0.7583 - val_loss: 1.3353 - val_accuracy: 0.0000e+00
# Epoch 82/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.7694 - accuracy: 0.7583 - val_loss: 1.3360 - val_accuracy: 0.0000e+00
# Epoch 83/500
# 120/120 [==============================] - 0s 205us/sample - loss: 0.7644 - accuracy: 0.7583 - val_loss: 1.3360 - val_accuracy: 0.0000e+00
# Epoch 84/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.7678 - accuracy: 0.7583 - val_loss: 1.3353 - val_accuracy: 0.0000e+00
# Epoch 85/500
# 120/120 [==============================] - 0s 295us/sample - loss: 0.7875 - accuracy: 0.7833 - val_loss: 1.3338 - val_accuracy: 0.0000e+00
# Epoch 86/500
# 120/120 [==============================] - 0s 254us/sample - loss: 0.7878 - accuracy: 0.7167 - val_loss: 1.3333 - val_accuracy: 0.0000e+00
# Epoch 87/500
# 120/120 [==============================] - 0s 232us/sample - loss: 0.7477 - accuracy: 0.7667 - val_loss: 1.3330 - val_accuracy: 0.0000e+00
# Epoch 88/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.7450 - accuracy: 0.7917 - val_loss: 1.3330 - val_accuracy: 0.0000e+00
# Epoch 89/500
# 120/120 [==============================] - 0s 223us/sample - loss: 0.7445 - accuracy: 0.7667 - val_loss: 1.3330 - val_accuracy: 0.0000e+00
# Epoch 90/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.7796 - accuracy: 0.7500 - val_loss: 1.3328 - val_accuracy: 0.0000e+00
# Epoch 91/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.7768 - accuracy: 0.7333 - val_loss: 1.3336 - val_accuracy: 0.0000e+00
# Epoch 92/500
# 120/120 [==============================] - 0s 254us/sample - loss: 0.7661 - accuracy: 0.7500 - val_loss: 1.3342 - val_accuracy: 0.0000e+00
# Epoch 93/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.7656 - accuracy: 0.7833 - val_loss: 1.3349 - val_accuracy: 0.0000e+00
# Epoch 94/500
# 120/120 [==============================] - 0s 236us/sample - loss: 0.7113 - accuracy: 0.7833 - val_loss: 1.3355 - val_accuracy: 0.0000e+00
# Epoch 95/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.7937 - accuracy: 0.7333 - val_loss: 1.3361 - val_accuracy: 0.0000e+00
# Epoch 96/500
# 120/120 [==============================] - 0s 191us/sample - loss: 0.7538 - accuracy: 0.7667 - val_loss: 1.3376 - val_accuracy: 0.0000e+00
# Epoch 97/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.7224 - accuracy: 0.7750 - val_loss: 1.3386 - val_accuracy: 0.0000e+00
# Epoch 98/500
# 120/120 [==============================] - 0s 206us/sample - loss: 0.7222 - accuracy: 0.7500 - val_loss: 1.3372 - val_accuracy: 0.0000e+00
# Epoch 99/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.7448 - accuracy: 0.7917 - val_loss: 1.3382 - val_accuracy: 0.0000e+00
# Epoch 100/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.7103 - accuracy: 0.7833 - val_loss: 1.3386 - val_accuracy: 0.0000e+00
# Epoch 101/500
# 120/120 [==============================] - 0s 247us/sample - loss: 0.7218 - accuracy: 0.7917 - val_loss: 1.3381 - val_accuracy: 0.0000e+00
# Epoch 102/500
# 120/120 [==============================] - 0s 230us/sample - loss: 0.7019 - accuracy: 0.8000 - val_loss: 1.3372 - val_accuracy: 0.0000e+00
# Epoch 103/500
# 120/120 [==============================] - 0s 204us/sample - loss: 0.7010 - accuracy: 0.7833 - val_loss: 1.3383 - val_accuracy: 0.0000e+00
# Epoch 104/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.7092 - accuracy: 0.7667 - val_loss: 1.3396 - val_accuracy: 0.0000e+00
# Epoch 105/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.7250 - accuracy: 0.7833 - val_loss: 1.3407 - val_accuracy: 0.0000e+00
# Epoch 106/500
# 120/120 [==============================] - 0s 197us/sample - loss: 0.7211 - accuracy: 0.7917 - val_loss: 1.3412 - val_accuracy: 0.0000e+00
# Epoch 107/500
# 120/120 [==============================] - 0s 236us/sample - loss: 0.7048 - accuracy: 0.7917 - val_loss: 1.3399 - val_accuracy: 0.0000e+00
# Epoch 108/500
# 120/120 [==============================] - 0s 313us/sample - loss: 0.7306 - accuracy: 0.7667 - val_loss: 1.3387 - val_accuracy: 0.0000e+00
# Epoch 109/500
# 120/120 [==============================] - 0s 231us/sample - loss: 0.6698 - accuracy: 0.8000 - val_loss: 1.3379 - val_accuracy: 0.0000e+00
# Epoch 110/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.7373 - accuracy: 0.7667 - val_loss: 1.3356 - val_accuracy: 0.0000e+00
# Epoch 111/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.7578 - accuracy: 0.7667 - val_loss: 1.3342 - val_accuracy: 0.0000e+00
# Epoch 112/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.6835 - accuracy: 0.7750 - val_loss: 1.3356 - val_accuracy: 0.0000e+00
# Epoch 113/500
# 120/120 [==============================] - 0s 201us/sample - loss: 0.6736 - accuracy: 0.7917 - val_loss: 1.3376 - val_accuracy: 0.0000e+00
# Epoch 114/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.7384 - accuracy: 0.7250 - val_loss: 1.3388 - val_accuracy: 0.0000e+00
# Epoch 115/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.7088 - accuracy: 0.7500 - val_loss: 1.3403 - val_accuracy: 0.0000e+00
# Epoch 116/500
# 120/120 [==============================] - 0s 307us/sample - loss: 0.7246 - accuracy: 0.7500 - val_loss: 1.3409 - val_accuracy: 0.0000e+00
# Epoch 117/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.6484 - accuracy: 0.8083 - val_loss: 1.3421 - val_accuracy: 0.0000e+00
# Epoch 118/500
# 120/120 [==============================] - 0s 237us/sample - loss: 0.6616 - accuracy: 0.8167 - val_loss: 1.3421 - val_accuracy: 0.0000e+00
# Epoch 119/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.6911 - accuracy: 0.7667 - val_loss: 1.3408 - val_accuracy: 0.0000e+00
# Epoch 120/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.7335 - accuracy: 0.7917 - val_loss: 1.3408 - val_accuracy: 0.0000e+00
# Epoch 121/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.6522 - accuracy: 0.7917 - val_loss: 1.3405 - val_accuracy: 0.0000e+00
# Epoch 122/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.6585 - accuracy: 0.8167 - val_loss: 1.3388 - val_accuracy: 0.0000e+00
# Epoch 123/500
# 120/120 [==============================] - 0s 200us/sample - loss: 0.6669 - accuracy: 0.7917 - val_loss: 1.3398 - val_accuracy: 0.0000e+00
# Epoch 124/500
# 120/120 [==============================] - 0s 264us/sample - loss: 0.6624 - accuracy: 0.8000 - val_loss: 1.3410 - val_accuracy: 0.0000e+00
# Epoch 125/500
# 120/120 [==============================] - 0s 254us/sample - loss: 0.7021 - accuracy: 0.7750 - val_loss: 1.3438 - val_accuracy: 0.0000e+00
# Epoch 126/500
# 120/120 [==============================] - 0s 216us/sample - loss: 0.6803 - accuracy: 0.7500 - val_loss: 1.3451 - val_accuracy: 0.0000e+00
# Epoch 127/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.6463 - accuracy: 0.7917 - val_loss: 1.3460 - val_accuracy: 0.0000e+00
# Epoch 128/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.7581 - accuracy: 0.7417 - val_loss: 1.3457 - val_accuracy: 0.0000e+00
# Epoch 129/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.6579 - accuracy: 0.8000 - val_loss: 1.3476 - val_accuracy: 0.0000e+00
# Epoch 130/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6748 - accuracy: 0.7917 - val_loss: 1.3514 - val_accuracy: 0.0000e+00
# Epoch 131/500
# 120/120 [==============================] - 0s 246us/sample - loss: 0.7232 - accuracy: 0.7417 - val_loss: 1.3506 - val_accuracy: 0.0000e+00
# Epoch 132/500
# 120/120 [==============================] - 0s 244us/sample - loss: 0.6451 - accuracy: 0.8000 - val_loss: 1.3482 - val_accuracy: 0.0000e+00
# Epoch 133/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.6814 - accuracy: 0.7667 - val_loss: 1.3456 - val_accuracy: 0.0000e+00
# Epoch 134/500
# 120/120 [==============================] - 0s 233us/sample - loss: 0.6345 - accuracy: 0.8250 - val_loss: 1.3447 - val_accuracy: 0.0000e+00
# Epoch 135/500
# 120/120 [==============================] - 0s 262us/sample - loss: 0.6223 - accuracy: 0.8000 - val_loss: 1.3412 - val_accuracy: 0.0000e+00
# Epoch 136/500
# 120/120 [==============================] - 0s 308us/sample - loss: 0.6265 - accuracy: 0.8000 - val_loss: 1.3405 - val_accuracy: 0.0000e+00
# Epoch 137/500
# 120/120 [==============================] - 0s 291us/sample - loss: 0.6326 - accuracy: 0.8000 - val_loss: 1.3419 - val_accuracy: 0.0000e+00
# Epoch 138/500
# 120/120 [==============================] - 0s 244us/sample - loss: 0.6706 - accuracy: 0.7917 - val_loss: 1.3420 - val_accuracy: 0.0000e+00
# Epoch 139/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.6430 - accuracy: 0.7833 - val_loss: 1.3414 - val_accuracy: 0.0000e+00
# Epoch 140/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.6243 - accuracy: 0.8000 - val_loss: 1.3404 - val_accuracy: 0.0000e+00
# Epoch 141/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.7519 - accuracy: 0.7167 - val_loss: 1.3403 - val_accuracy: 0.0000e+00
# Epoch 142/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.6629 - accuracy: 0.7833 - val_loss: 1.3401 - val_accuracy: 0.0000e+00
# Epoch 143/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.6957 - accuracy: 0.7750 - val_loss: 1.3401 - val_accuracy: 0.0000e+00
# Epoch 144/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.6564 - accuracy: 0.7833 - val_loss: 1.3392 - val_accuracy: 0.0000e+00
# Epoch 145/500
# 120/120 [==============================] - 0s 230us/sample - loss: 0.6203 - accuracy: 0.7917 - val_loss: 1.3422 - val_accuracy: 0.0000e+00
# Epoch 146/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.6442 - accuracy: 0.7750 - val_loss: 1.3448 - val_accuracy: 0.0000e+00
# Epoch 147/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.6212 - accuracy: 0.8000 - val_loss: 1.3464 - val_accuracy: 0.0000e+00
# Epoch 148/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.5971 - accuracy: 0.8000 - val_loss: 1.3492 - val_accuracy: 0.0000e+00
# Epoch 149/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.6354 - accuracy: 0.8000 - val_loss: 1.3492 - val_accuracy: 0.0000e+00
# Epoch 150/500
# 120/120 [==============================] - 0s 271us/sample - loss: 0.6505 - accuracy: 0.8000 - val_loss: 1.3486 - val_accuracy: 0.0000e+00
# Epoch 151/500
# 120/120 [==============================] - 0s 271us/sample - loss: 0.6596 - accuracy: 0.8000 - val_loss: 1.3456 - val_accuracy: 0.0000e+00
# Epoch 152/500
# 120/120 [==============================] - 0s 253us/sample - loss: 0.6302 - accuracy: 0.8000 - val_loss: 1.3434 - val_accuracy: 0.0000e+00
# Epoch 153/500
# 120/120 [==============================] - 0s 325us/sample - loss: 0.6295 - accuracy: 0.8000 - val_loss: 1.3433 - val_accuracy: 0.0000e+00
# Epoch 154/500
# 120/120 [==============================] - 0s 251us/sample - loss: 0.6317 - accuracy: 0.7750 - val_loss: 1.3444 - val_accuracy: 0.0000e+00
# Epoch 155/500
# 120/120 [==============================] - 0s 266us/sample - loss: 0.6205 - accuracy: 0.7833 - val_loss: 1.3482 - val_accuracy: 0.0000e+00
# Epoch 156/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.5931 - accuracy: 0.8000 - val_loss: 1.3486 - val_accuracy: 0.0000e+00
# Epoch 157/500
# 120/120 [==============================] - 0s 251us/sample - loss: 0.6997 - accuracy: 0.7667 - val_loss: 1.3494 - val_accuracy: 0.0000e+00
# Epoch 158/500
# 120/120 [==============================] - 0s 260us/sample - loss: 0.6311 - accuracy: 0.7917 - val_loss: 1.3511 - val_accuracy: 0.0000e+00
# Epoch 159/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.6430 - accuracy: 0.7833 - val_loss: 1.3501 - val_accuracy: 0.0000e+00
# Epoch 160/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.6288 - accuracy: 0.8000 - val_loss: 1.3487 - val_accuracy: 0.0000e+00
# Epoch 161/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.6128 - accuracy: 0.7917 - val_loss: 1.3501 - val_accuracy: 0.0000e+00
# Epoch 162/500
# 120/120 [==============================] - 0s 199us/sample - loss: 0.6076 - accuracy: 0.8167 - val_loss: 1.3468 - val_accuracy: 0.0000e+00
# Epoch 163/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6392 - accuracy: 0.7917 - val_loss: 1.3430 - val_accuracy: 0.0000e+00
# Epoch 164/500
# 120/120 [==============================] - 0s 214us/sample - loss: 0.6174 - accuracy: 0.8083 - val_loss: 1.3370 - val_accuracy: 0.0000e+00
# Epoch 165/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.6118 - accuracy: 0.8083 - val_loss: 1.3362 - val_accuracy: 0.0000e+00
# Epoch 166/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.6018 - accuracy: 0.7917 - val_loss: 1.3367 - val_accuracy: 0.0000e+00
# Epoch 167/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.6241 - accuracy: 0.7833 - val_loss: 1.3348 - val_accuracy: 0.0000e+00
# Epoch 168/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.6509 - accuracy: 0.7917 - val_loss: 1.3286 - val_accuracy: 0.0000e+00
# Epoch 169/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6267 - accuracy: 0.8000 - val_loss: 1.3235 - val_accuracy: 0.0000e+00
# Epoch 170/500
# 120/120 [==============================] - 0s 201us/sample - loss: 0.6650 - accuracy: 0.7667 - val_loss: 1.3207 - val_accuracy: 0.0000e+00
# Epoch 171/500
# 120/120 [==============================] - 0s 255us/sample - loss: 0.6497 - accuracy: 0.7750 - val_loss: 1.3212 - val_accuracy: 0.0000e+00
# Epoch 172/500
# 120/120 [==============================] - 0s 196us/sample - loss: 0.6777 - accuracy: 0.7833 - val_loss: 1.3181 - val_accuracy: 0.0000e+00
# Epoch 173/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6158 - accuracy: 0.7750 - val_loss: 1.3133 - val_accuracy: 0.0000e+00
# Epoch 174/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.6032 - accuracy: 0.8167 - val_loss: 1.3101 - val_accuracy: 0.0000e+00
# Epoch 175/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.6140 - accuracy: 0.8083 - val_loss: 1.3058 - val_accuracy: 0.0000e+00
# Epoch 176/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.5894 - accuracy: 0.8250 - val_loss: 1.3024 - val_accuracy: 0.0000e+00
# Epoch 177/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.6038 - accuracy: 0.7917 - val_loss: 1.3014 - val_accuracy: 0.0000e+00
# Epoch 178/500
# 120/120 [==============================] - 0s 247us/sample - loss: 0.6335 - accuracy: 0.8167 - val_loss: 1.3012 - val_accuracy: 0.0000e+00
# Epoch 179/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5965 - accuracy: 0.8000 - val_loss: 1.3046 - val_accuracy: 0.0000e+00
# Epoch 180/500
# 120/120 [==============================] - 0s 223us/sample - loss: 0.5847 - accuracy: 0.8167 - val_loss: 1.3043 - val_accuracy: 0.0000e+00
# Epoch 181/500
# 120/120 [==============================] - 0s 276us/sample - loss: 0.6562 - accuracy: 0.7750 - val_loss: 1.3026 - val_accuracy: 0.0000e+00
# Epoch 182/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.5723 - accuracy: 0.8250 - val_loss: 1.3026 - val_accuracy: 0.0000e+00
# Epoch 183/500
# 120/120 [==============================] - 0s 248us/sample - loss: 0.6403 - accuracy: 0.7833 - val_loss: 1.2989 - val_accuracy: 0.0000e+00
# Epoch 184/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.6098 - accuracy: 0.8083 - val_loss: 1.2945 - val_accuracy: 0.0000e+00
# Epoch 185/500
# 120/120 [==============================] - 0s 235us/sample - loss: 0.5925 - accuracy: 0.7833 - val_loss: 1.2909 - val_accuracy: 0.0000e+00
# Epoch 186/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.6914 - accuracy: 0.7583 - val_loss: 1.2870 - val_accuracy: 0.0000e+00
# Epoch 187/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.6425 - accuracy: 0.7917 - val_loss: 1.2823 - val_accuracy: 0.0000e+00
# Epoch 188/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.6030 - accuracy: 0.8083 - val_loss: 1.2803 - val_accuracy: 0.0000e+00
# Epoch 189/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.5904 - accuracy: 0.8083 - val_loss: 1.2780 - val_accuracy: 0.0000e+00
# Epoch 190/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.6114 - accuracy: 0.7917 - val_loss: 1.2780 - val_accuracy: 0.0000e+00
# Epoch 191/500
# 120/120 [==============================] - 0s 188us/sample - loss: 0.5541 - accuracy: 0.8167 - val_loss: 1.2763 - val_accuracy: 0.0000e+00
# Epoch 192/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.6124 - accuracy: 0.7917 - val_loss: 1.2739 - val_accuracy: 0.0000e+00
# Epoch 193/500
# 120/120 [==============================] - 0s 246us/sample - loss: 0.5865 - accuracy: 0.8083 - val_loss: 1.2729 - val_accuracy: 0.0000e+00
# Epoch 194/500
# 120/120 [==============================] - 0s 248us/sample - loss: 0.5968 - accuracy: 0.7917 - val_loss: 1.2757 - val_accuracy: 0.0000e+00
# Epoch 195/500
# 120/120 [==============================] - 0s 233us/sample - loss: 0.6130 - accuracy: 0.8083 - val_loss: 1.2748 - val_accuracy: 0.0000e+00
# Epoch 196/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.5946 - accuracy: 0.8000 - val_loss: 1.2754 - val_accuracy: 0.0000e+00
# Epoch 197/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.6267 - accuracy: 0.7750 - val_loss: 1.2778 - val_accuracy: 0.0000e+00
# Epoch 198/500
# 120/120 [==============================] - 0s 248us/sample - loss: 0.5644 - accuracy: 0.8333 - val_loss: 1.2768 - val_accuracy: 0.0000e+00
# Epoch 199/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.5509 - accuracy: 0.8250 - val_loss: 1.2743 - val_accuracy: 0.0000e+00
# Epoch 200/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.6053 - accuracy: 0.8083 - val_loss: 1.2740 - val_accuracy: 0.0000e+00
# Epoch 201/500
# 120/120 [==============================] - 0s 224us/sample - loss: 0.6022 - accuracy: 0.8000 - val_loss: 1.2737 - val_accuracy: 0.0000e+00
# Epoch 202/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6178 - accuracy: 0.7833 - val_loss: 1.2726 - val_accuracy: 0.0000e+00
# Epoch 203/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.5836 - accuracy: 0.8167 - val_loss: 1.2704 - val_accuracy: 0.0000e+00
# Epoch 204/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5585 - accuracy: 0.8333 - val_loss: 1.2669 - val_accuracy: 0.0000e+00
# Epoch 205/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.5770 - accuracy: 0.8167 - val_loss: 1.2664 - val_accuracy: 0.0000e+00
# Epoch 206/500
# 120/120 [==============================] - 0s 285us/sample - loss: 0.5608 - accuracy: 0.8250 - val_loss: 1.2635 - val_accuracy: 0.0000e+00
# Epoch 207/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.5949 - accuracy: 0.8000 - val_loss: 1.2617 - val_accuracy: 0.0000e+00
# Epoch 208/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.5745 - accuracy: 0.8083 - val_loss: 1.2602 - val_accuracy: 0.0000e+00
# Epoch 209/500
# 120/120 [==============================] - 0s 261us/sample - loss: 0.5583 - accuracy: 0.8250 - val_loss: 1.2562 - val_accuracy: 0.0000e+00
# Epoch 210/500
# 120/120 [==============================] - 0s 268us/sample - loss: 0.5825 - accuracy: 0.8000 - val_loss: 1.2562 - val_accuracy: 0.0000e+00
# Epoch 211/500
# 120/120 [==============================] - 0s 261us/sample - loss: 0.5579 - accuracy: 0.8250 - val_loss: 1.2578 - val_accuracy: 0.0000e+00
# Epoch 212/500
# 120/120 [==============================] - 0s 282us/sample - loss: 0.6005 - accuracy: 0.8083 - val_loss: 1.2575 - val_accuracy: 0.0000e+00
# Epoch 213/500
# 120/120 [==============================] - 0s 262us/sample - loss: 0.6172 - accuracy: 0.7833 - val_loss: 1.2587 - val_accuracy: 0.0000e+00
# Epoch 214/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.6057 - accuracy: 0.7917 - val_loss: 1.2592 - val_accuracy: 0.0000e+00
# Epoch 215/500
# 120/120 [==============================] - 0s 263us/sample - loss: 0.6017 - accuracy: 0.7917 - val_loss: 1.2590 - val_accuracy: 0.0000e+00
# Epoch 216/500
# 120/120 [==============================] - 0s 261us/sample - loss: 0.5896 - accuracy: 0.7917 - val_loss: 1.2552 - val_accuracy: 0.0000e+00
# Epoch 217/500
# 120/120 [==============================] - 0s 250us/sample - loss: 0.5853 - accuracy: 0.8000 - val_loss: 1.2519 - val_accuracy: 0.0000e+00
# Epoch 218/500
# 120/120 [==============================] - 0s 239us/sample - loss: 0.5693 - accuracy: 0.8167 - val_loss: 1.2537 - val_accuracy: 0.0000e+00
# Epoch 219/500
# 120/120 [==============================] - 0s 269us/sample - loss: 0.5883 - accuracy: 0.8083 - val_loss: 1.2538 - val_accuracy: 0.0000e+00
# Epoch 220/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.5730 - accuracy: 0.8167 - val_loss: 1.2556 - val_accuracy: 0.0000e+00
# Epoch 221/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.5693 - accuracy: 0.8083 - val_loss: 1.2558 - val_accuracy: 0.0000e+00
# Epoch 222/500
# 120/120 [==============================] - 0s 241us/sample - loss: 0.5680 - accuracy: 0.8167 - val_loss: 1.2543 - val_accuracy: 0.0000e+00
# Epoch 223/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.6052 - accuracy: 0.7917 - val_loss: 1.2539 - val_accuracy: 0.0000e+00
# Epoch 224/500
# 120/120 [==============================] - 0s 262us/sample - loss: 0.5828 - accuracy: 0.8167 - val_loss: 1.2531 - val_accuracy: 0.0000e+00
# Epoch 225/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.6373 - accuracy: 0.8083 - val_loss: 1.2522 - val_accuracy: 0.0000e+00
# Epoch 226/500
# 120/120 [==============================] - 0s 232us/sample - loss: 0.5818 - accuracy: 0.7917 - val_loss: 1.2474 - val_accuracy: 0.0000e+00
# Epoch 227/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.6560 - accuracy: 0.7583 - val_loss: 1.2440 - val_accuracy: 0.0000e+00
# Epoch 228/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.5822 - accuracy: 0.8000 - val_loss: 1.2406 - val_accuracy: 0.0000e+00
# Epoch 229/500
# 120/120 [==============================] - 0s 244us/sample - loss: 0.5724 - accuracy: 0.8083 - val_loss: 1.2400 - val_accuracy: 0.0000e+00
# Epoch 230/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.5847 - accuracy: 0.8167 - val_loss: 1.2421 - val_accuracy: 0.0000e+00
# Epoch 231/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.6050 - accuracy: 0.8083 - val_loss: 1.2466 - val_accuracy: 0.0000e+00
# Epoch 232/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.6095 - accuracy: 0.7833 - val_loss: 1.2504 - val_accuracy: 0.0000e+00
# Epoch 233/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.5615 - accuracy: 0.8083 - val_loss: 1.2525 - val_accuracy: 0.0000e+00
# Epoch 234/500
# 120/120 [==============================] - 0s 204us/sample - loss: 0.5927 - accuracy: 0.7833 - val_loss: 1.2525 - val_accuracy: 0.0000e+00
# Epoch 235/500
# 120/120 [==============================] - 0s 245us/sample - loss: 0.6170 - accuracy: 0.7917 - val_loss: 1.2502 - val_accuracy: 0.0000e+00
# Epoch 236/500
# 120/120 [==============================] - 0s 244us/sample - loss: 0.6231 - accuracy: 0.7917 - val_loss: 1.2435 - val_accuracy: 0.0000e+00
# Epoch 237/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.6184 - accuracy: 0.7833 - val_loss: 1.2377 - val_accuracy: 0.0000e+00
# Epoch 238/500
# 120/120 [==============================] - 0s 248us/sample - loss: 0.5785 - accuracy: 0.7833 - val_loss: 1.2330 - val_accuracy: 0.0000e+00
# Epoch 239/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.5742 - accuracy: 0.8083 - val_loss: 1.2312 - val_accuracy: 0.0000e+00
# Epoch 240/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.5595 - accuracy: 0.8000 - val_loss: 1.2297 - val_accuracy: 0.0000e+00
# Epoch 241/500
# 120/120 [==============================] - 0s 202us/sample - loss: 0.5727 - accuracy: 0.8083 - val_loss: 1.2305 - val_accuracy: 0.0000e+00
# Epoch 242/500
# 120/120 [==============================] - 0s 263us/sample - loss: 0.6128 - accuracy: 0.7917 - val_loss: 1.2313 - val_accuracy: 0.0000e+00
# Epoch 243/500
# 120/120 [==============================] - 0s 266us/sample - loss: 0.5472 - accuracy: 0.8167 - val_loss: 1.2338 - val_accuracy: 0.0000e+00
# Epoch 244/500
# 120/120 [==============================] - 0s 184us/sample - loss: 0.6060 - accuracy: 0.7917 - val_loss: 1.2361 - val_accuracy: 0.0000e+00
# Epoch 245/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.5534 - accuracy: 0.8333 - val_loss: 1.2391 - val_accuracy: 0.0000e+00
# Epoch 246/500
# 120/120 [==============================] - 0s 231us/sample - loss: 0.5862 - accuracy: 0.8083 - val_loss: 1.2405 - val_accuracy: 0.0000e+00
# Epoch 247/500
# 120/120 [==============================] - 0s 239us/sample - loss: 0.5569 - accuracy: 0.8083 - val_loss: 1.2390 - val_accuracy: 0.0000e+00
# Epoch 248/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.5888 - accuracy: 0.8167 - val_loss: 1.2388 - val_accuracy: 0.0000e+00
# Epoch 249/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5977 - accuracy: 0.8000 - val_loss: 1.2385 - val_accuracy: 0.0000e+00
# Epoch 250/500
# 120/120 [==============================] - 0s 265us/sample - loss: 0.5687 - accuracy: 0.8250 - val_loss: 1.2358 - val_accuracy: 0.0000e+00
# Epoch 251/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5771 - accuracy: 0.7917 - val_loss: 1.2330 - val_accuracy: 0.0000e+00
# Epoch 252/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.5981 - accuracy: 0.7667 - val_loss: 1.2330 - val_accuracy: 0.0000e+00
# Epoch 253/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.5750 - accuracy: 0.8000 - val_loss: 1.2315 - val_accuracy: 0.0000e+00
# Epoch 254/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.6267 - accuracy: 0.7917 - val_loss: 1.2322 - val_accuracy: 0.0000e+00
# Epoch 255/500
# 120/120 [==============================] - 0s 217us/sample - loss: 0.5720 - accuracy: 0.8000 - val_loss: 1.2331 - val_accuracy: 0.0000e+00
# Epoch 256/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5750 - accuracy: 0.7917 - val_loss: 1.2357 - val_accuracy: 0.0000e+00
# Epoch 257/500
# 120/120 [==============================] - 0s 258us/sample - loss: 0.6013 - accuracy: 0.7750 - val_loss: 1.2385 - val_accuracy: 0.0000e+00
# Epoch 258/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.5453 - accuracy: 0.8167 - val_loss: 1.2417 - val_accuracy: 0.0000e+00
# Epoch 259/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.5607 - accuracy: 0.8000 - val_loss: 1.2421 - val_accuracy: 0.0000e+00
# Epoch 260/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.6471 - accuracy: 0.7833 - val_loss: 1.2402 - val_accuracy: 0.0000e+00
# Epoch 261/500
# 120/120 [==============================] - 0s 202us/sample - loss: 0.5778 - accuracy: 0.8167 - val_loss: 1.2356 - val_accuracy: 0.0000e+00
# Epoch 262/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.5578 - accuracy: 0.8083 - val_loss: 1.2322 - val_accuracy: 0.0000e+00
# Epoch 263/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.6027 - accuracy: 0.8000 - val_loss: 1.2294 - val_accuracy: 0.0000e+00
# Epoch 264/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.5381 - accuracy: 0.8250 - val_loss: 1.2282 - val_accuracy: 0.0000e+00
# Epoch 265/500
# 120/120 [==============================] - 0s 251us/sample - loss: 0.5790 - accuracy: 0.8000 - val_loss: 1.2272 - val_accuracy: 0.0000e+00
# Epoch 266/500
# 120/120 [==============================] - 0s 285us/sample - loss: 0.6112 - accuracy: 0.8000 - val_loss: 1.2263 - val_accuracy: 0.0000e+00
# Epoch 267/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.6207 - accuracy: 0.7667 - val_loss: 1.2254 - val_accuracy: 0.0000e+00
# Epoch 268/500
# 120/120 [==============================] - 0s 224us/sample - loss: 0.5752 - accuracy: 0.8000 - val_loss: 1.2288 - val_accuracy: 0.0000e+00
# Epoch 269/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.5791 - accuracy: 0.8000 - val_loss: 1.2285 - val_accuracy: 0.0000e+00
# Epoch 270/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.6317 - accuracy: 0.7833 - val_loss: 1.2277 - val_accuracy: 0.0000e+00
# Epoch 271/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.5773 - accuracy: 0.8000 - val_loss: 1.2260 - val_accuracy: 0.0000e+00
# Epoch 272/500
# 120/120 [==============================] - 0s 206us/sample - loss: 0.6028 - accuracy: 0.7583 - val_loss: 1.2246 - val_accuracy: 0.0000e+00
# Epoch 273/500
# 120/120 [==============================] - 0s 246us/sample - loss: 0.5486 - accuracy: 0.8167 - val_loss: 1.2219 - val_accuracy: 0.0000e+00
# Epoch 274/500
# 120/120 [==============================] - 0s 256us/sample - loss: 0.5880 - accuracy: 0.7917 - val_loss: 1.2193 - val_accuracy: 0.0000e+00
# Epoch 275/500
# 120/120 [==============================] - 0s 265us/sample - loss: 0.6255 - accuracy: 0.7750 - val_loss: 1.2165 - val_accuracy: 0.0000e+00
# Epoch 276/500
# 120/120 [==============================] - 0s 279us/sample - loss: 0.5547 - accuracy: 0.8250 - val_loss: 1.2129 - val_accuracy: 0.0000e+00
# Epoch 277/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.5431 - accuracy: 0.8083 - val_loss: 1.2110 - val_accuracy: 0.0000e+00
# Epoch 278/500
# 120/120 [==============================] - 0s 202us/sample - loss: 0.6025 - accuracy: 0.8000 - val_loss: 1.2111 - val_accuracy: 0.0000e+00
# Epoch 279/500
# 120/120 [==============================] - 0s 195us/sample - loss: 0.5719 - accuracy: 0.8000 - val_loss: 1.2097 - val_accuracy: 0.0000e+00
# Epoch 280/500
# 120/120 [==============================] - 0s 203us/sample - loss: 0.5653 - accuracy: 0.8000 - val_loss: 1.2047 - val_accuracy: 0.0000e+00
# Epoch 281/500
# 120/120 [==============================] - 0s 216us/sample - loss: 0.5632 - accuracy: 0.8083 - val_loss: 1.2025 - val_accuracy: 0.0000e+00
# Epoch 282/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.6006 - accuracy: 0.8000 - val_loss: 1.1990 - val_accuracy: 0.0000e+00
# Epoch 283/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.5447 - accuracy: 0.8083 - val_loss: 1.1977 - val_accuracy: 0.0000e+00
# Epoch 284/500
# 120/120 [==============================] - 0s 267us/sample - loss: 0.5893 - accuracy: 0.7917 - val_loss: 1.2005 - val_accuracy: 0.0000e+00
# Epoch 285/500
# 120/120 [==============================] - 0s 237us/sample - loss: 0.5340 - accuracy: 0.8333 - val_loss: 1.2028 - val_accuracy: 0.0000e+00
# Epoch 286/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.5718 - accuracy: 0.7917 - val_loss: 1.2054 - val_accuracy: 0.0000e+00
# Epoch 287/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.5673 - accuracy: 0.8000 - val_loss: 1.2078 - val_accuracy: 0.0000e+00
# Epoch 288/500
# 120/120 [==============================] - 0s 203us/sample - loss: 0.5802 - accuracy: 0.7750 - val_loss: 1.2082 - val_accuracy: 0.0000e+00
# Epoch 289/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5784 - accuracy: 0.8000 - val_loss: 1.2056 - val_accuracy: 0.0000e+00
# Epoch 290/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5381 - accuracy: 0.8250 - val_loss: 1.2056 - val_accuracy: 0.0000e+00
# Epoch 291/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.6289 - accuracy: 0.7917 - val_loss: 1.2080 - val_accuracy: 0.0000e+00
# Epoch 292/500
# 120/120 [==============================] - 0s 248us/sample - loss: 0.5572 - accuracy: 0.8167 - val_loss: 1.2100 - val_accuracy: 0.0000e+00
# Epoch 293/500
# 120/120 [==============================] - 0s 281us/sample - loss: 0.5429 - accuracy: 0.8167 - val_loss: 1.2122 - val_accuracy: 0.0000e+00
# Epoch 294/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.5749 - accuracy: 0.8000 - val_loss: 1.2137 - val_accuracy: 0.0000e+00
# Epoch 295/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.5950 - accuracy: 0.8000 - val_loss: 1.2146 - val_accuracy: 0.0000e+00
# Epoch 296/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5708 - accuracy: 0.8000 - val_loss: 1.2135 - val_accuracy: 0.0000e+00
# Epoch 297/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5399 - accuracy: 0.8083 - val_loss: 1.2107 - val_accuracy: 0.0000e+00
# Epoch 298/500
# 120/120 [==============================] - 0s 217us/sample - loss: 0.5987 - accuracy: 0.7833 - val_loss: 1.2085 - val_accuracy: 0.0000e+00
# Epoch 299/500
# 120/120 [==============================] - 0s 230us/sample - loss: 0.5616 - accuracy: 0.8083 - val_loss: 1.2064 - val_accuracy: 0.0000e+00
# Epoch 300/500
# 120/120 [==============================] - 0s 241us/sample - loss: 0.5478 - accuracy: 0.8333 - val_loss: 1.2064 - val_accuracy: 0.0000e+00
# Epoch 301/500
# 120/120 [==============================] - 0s 246us/sample - loss: 0.5769 - accuracy: 0.8083 - val_loss: 1.2075 - val_accuracy: 0.0000e+00
# Epoch 302/500
# 120/120 [==============================] - 0s 250us/sample - loss: 0.5744 - accuracy: 0.8083 - val_loss: 1.2073 - val_accuracy: 0.0000e+00
# Epoch 303/500
# 120/120 [==============================] - 0s 235us/sample - loss: 0.5859 - accuracy: 0.7833 - val_loss: 1.2070 - val_accuracy: 0.0000e+00
# Epoch 304/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.5540 - accuracy: 0.8167 - val_loss: 1.2040 - val_accuracy: 0.0000e+00
# Epoch 305/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5876 - accuracy: 0.8000 - val_loss: 1.2081 - val_accuracy: 0.0000e+00
# Epoch 306/500
# 120/120 [==============================] - 0s 289us/sample - loss: 0.5406 - accuracy: 0.8333 - val_loss: 1.2112 - val_accuracy: 0.0000e+00
# Epoch 307/500
# 120/120 [==============================] - 0s 318us/sample - loss: 0.5731 - accuracy: 0.8000 - val_loss: 1.2143 - val_accuracy: 0.0000e+00
# Epoch 308/500
# 120/120 [==============================] - 0s 253us/sample - loss: 0.5539 - accuracy: 0.8083 - val_loss: 1.2172 - val_accuracy: 0.0000e+00
# Epoch 309/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.5534 - accuracy: 0.8083 - val_loss: 1.2179 - val_accuracy: 0.0000e+00
# Epoch 310/500
# 120/120 [==============================] - 0s 239us/sample - loss: 0.5648 - accuracy: 0.8083 - val_loss: 1.2196 - val_accuracy: 0.0000e+00
# Epoch 311/500
# 120/120 [==============================] - 0s 259us/sample - loss: 0.6159 - accuracy: 0.7833 - val_loss: 1.2225 - val_accuracy: 0.0000e+00
# Epoch 312/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5818 - accuracy: 0.8000 - val_loss: 1.2209 - val_accuracy: 0.0000e+00
# Epoch 313/500
# 120/120 [==============================] - 0s 295us/sample - loss: 0.5300 - accuracy: 0.8083 - val_loss: 1.2172 - val_accuracy: 0.0000e+00
# Epoch 314/500
# 120/120 [==============================] - 0s 309us/sample - loss: 0.5398 - accuracy: 0.8167 - val_loss: 1.2150 - val_accuracy: 0.0000e+00
# Epoch 315/500
# ...
# Epoch 397/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.5252 - accuracy: 0.8250 - val_loss: 1.0908 - val_accuracy: 0.0000e+00
# Epoch 398/500
# 120/120 [==============================] - 0s 199us/sample - loss: 0.5436 - accuracy: 0.8083 - val_loss: 1.0921 - val_accuracy: 0.0000e+00
# Epoch 399/500
# 120/120 [==============================] - 0s 224us/sample - loss: 0.5058 - accuracy: 0.8167 - val_loss: 1.0945 - val_accuracy: 0.0000e+00
# Epoch 400/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.5802 - accuracy: 0.8000 - val_loss: 1.0977 - val_accuracy: 0.0000e+00
# Epoch 401/500
# 120/120 [==============================] - 0s 264us/sample - loss: 0.5589 - accuracy: 0.8333 - val_loss: 1.0968 - val_accuracy: 0.0000e+00
# Epoch 402/500
# 120/120 [==============================] - 0s 251us/sample - loss: 0.5233 - accuracy: 0.8417 - val_loss: 1.0913 - val_accuracy: 0.0000e+00
# Epoch 403/500
# 120/120 [==============================] - 0s 272us/sample - loss: 0.5283 - accuracy: 0.8167 - val_loss: 1.0859 - val_accuracy: 0.0000e+00
# Epoch 404/500
# 120/120 [==============================] - 0s 222us/sample - loss: 0.5389 - accuracy: 0.7917 - val_loss: 1.0888 - val_accuracy: 0.0000e+00
# Epoch 405/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5495 - accuracy: 0.8083 - val_loss: 1.0912 - val_accuracy: 0.0000e+00
# Epoch 406/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.5530 - accuracy: 0.7917 - val_loss: 1.0879 - val_accuracy: 0.0000e+00
# Epoch 407/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5078 - accuracy: 0.8250 - val_loss: 1.0868 - val_accuracy: 0.0000e+00
# Epoch 408/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.5581 - accuracy: 0.8083 - val_loss: 1.0797 - val_accuracy: 0.0000e+00
# Epoch 409/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.5017 - accuracy: 0.8333 - val_loss: 1.0694 - val_accuracy: 0.0000e+00
# Epoch 410/500
# 120/120 [==============================] - 0s 216us/sample - loss: 0.5079 - accuracy: 0.8083 - val_loss: 1.0621 - val_accuracy: 0.0000e+00
# Epoch 411/500
# 120/120 [==============================] - 0s 278us/sample - loss: 0.5333 - accuracy: 0.8333 - val_loss: 1.0549 - val_accuracy: 0.0000e+00
# Epoch 412/500
# 120/120 [==============================] - 0s 262us/sample - loss: 0.5527 - accuracy: 0.8167 - val_loss: 1.0482 - val_accuracy: 0.0000e+00
# Epoch 413/500
# 120/120 [==============================] - 0s 247us/sample - loss: 0.5206 - accuracy: 0.8250 - val_loss: 1.0462 - val_accuracy: 0.0000e+00
# Epoch 414/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.4934 - accuracy: 0.8667 - val_loss: 1.0389 - val_accuracy: 0.0000e+00
# Epoch 415/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5116 - accuracy: 0.8333 - val_loss: 1.0348 - val_accuracy: 0.0000e+00
# Epoch 416/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.5375 - accuracy: 0.8333 - val_loss: 1.0313 - val_accuracy: 0.0000e+00
# Epoch 417/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.5362 - accuracy: 0.8250 - val_loss: 1.0297 - val_accuracy: 0.0000e+00
# Epoch 418/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.5429 - accuracy: 0.8167 - val_loss: 1.0343 - val_accuracy: 0.0000e+00
# Epoch 419/500
# 120/120 [==============================] - 0s 235us/sample - loss: 0.5492 - accuracy: 0.8417 - val_loss: 1.0439 - val_accuracy: 0.0000e+00
# Epoch 420/500
# 120/120 [==============================] - 0s 269us/sample - loss: 0.5087 - accuracy: 0.8417 - val_loss: 1.0519 - val_accuracy: 0.0000e+00
# Epoch 421/500
# 120/120 [==============================] - 0s 231us/sample - loss: 0.5378 - accuracy: 0.8167 - val_loss: 1.0537 - val_accuracy: 0.0000e+00
# Epoch 422/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5814 - accuracy: 0.8000 - val_loss: 1.0620 - val_accuracy: 0.0000e+00
# Epoch 423/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.5369 - accuracy: 0.8333 - val_loss: 1.0698 - val_accuracy: 0.0000e+00
# Epoch 424/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.5075 - accuracy: 0.8417 - val_loss: 1.0763 - val_accuracy: 0.0000e+00
# Epoch 425/500
# 120/120 [==============================] - 0s 200us/sample - loss: 0.5540 - accuracy: 0.8333 - val_loss: 1.0828 - val_accuracy: 0.0000e+00
# Epoch 426/500
# 120/120 [==============================] - 0s 243us/sample - loss: 0.5571 - accuracy: 0.8500 - val_loss: 1.0866 - val_accuracy: 0.0000e+00
# Epoch 427/500
# 120/120 [==============================] - 0s 235us/sample - loss: 0.5471 - accuracy: 0.8250 - val_loss: 1.0892 - val_accuracy: 0.0000e+00
# Epoch 428/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5150 - accuracy: 0.8417 - val_loss: 1.0894 - val_accuracy: 0.0000e+00
# Epoch 429/500
# 120/120 [==============================] - 0s 216us/sample - loss: 0.5406 - accuracy: 0.7917 - val_loss: 1.0864 - val_accuracy: 0.0000e+00
# Epoch 430/500
# 120/120 [==============================] - 0s 274us/sample - loss: 0.5516 - accuracy: 0.8417 - val_loss: 1.0843 - val_accuracy: 0.0000e+00
# Epoch 431/500
# 120/120 [==============================] - 0s 237us/sample - loss: 0.5483 - accuracy: 0.8000 - val_loss: 1.0861 - val_accuracy: 0.0000e+00
# Epoch 432/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.5168 - accuracy: 0.8083 - val_loss: 1.0853 - val_accuracy: 0.0000e+00
# Epoch 433/500
# 120/120 [==============================] - 0s 220us/sample - loss: 0.5274 - accuracy: 0.8333 - val_loss: 1.0846 - val_accuracy: 0.0000e+00
# Epoch 434/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.5267 - accuracy: 0.8167 - val_loss: 1.0840 - val_accuracy: 0.0000e+00
# Epoch 435/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.5928 - accuracy: 0.8167 - val_loss: 1.0859 - val_accuracy: 0.0000e+00
# Epoch 436/500
# 120/120 [==============================] - 0s 215us/sample - loss: 0.5133 - accuracy: 0.8333 - val_loss: 1.0888 - val_accuracy: 0.0000e+00
# Epoch 437/500
# 120/120 [==============================] - 0s 228us/sample - loss: 0.5209 - accuracy: 0.8250 - val_loss: 1.0869 - val_accuracy: 0.0000e+00
# Epoch 438/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5009 - accuracy: 0.8333 - val_loss: 1.0838 - val_accuracy: 0.0000e+00
# Epoch 439/500
# 120/120 [==============================] - 0s 258us/sample - loss: 0.5104 - accuracy: 0.8333 - val_loss: 1.0771 - val_accuracy: 0.0000e+00
# Epoch 440/500
# 120/120 [==============================] - 0s 251us/sample - loss: 0.5142 - accuracy: 0.8167 - val_loss: 1.0708 - val_accuracy: 0.0000e+00
# Epoch 441/500
# 120/120 [==============================] - 0s 262us/sample - loss: 0.5237 - accuracy: 0.8167 - val_loss: 1.0662 - val_accuracy: 0.0000e+00
# Epoch 442/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.5128 - accuracy: 0.8417 - val_loss: 1.0642 - val_accuracy: 0.0000e+00
# Epoch 443/500
# 120/120 [==============================] - 0s 246us/sample - loss: 0.5753 - accuracy: 0.7833 - val_loss: 1.0663 - val_accuracy: 0.0000e+00
# Epoch 444/500
# 120/120 [==============================] - 0s 229us/sample - loss: 0.4656 - accuracy: 0.8667 - val_loss: 1.0635 - val_accuracy: 0.0000e+00
# Epoch 445/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.4816 - accuracy: 0.8500 - val_loss: 1.0575 - val_accuracy: 0.0000e+00
# Epoch 446/500
# 120/120 [==============================] - 0s 224us/sample - loss: 0.5032 - accuracy: 0.8417 - val_loss: 1.0532 - val_accuracy: 0.0000e+00
# Epoch 447/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.5059 - accuracy: 0.8417 - val_loss: 1.0482 - val_accuracy: 0.0000e+00
# Epoch 448/500
# 120/120 [==============================] - 0s 224us/sample - loss: 0.5227 - accuracy: 0.8333 - val_loss: 1.0457 - val_accuracy: 0.0000e+00
# Epoch 449/500
# 120/120 [==============================] - 0s 212us/sample - loss: 0.5813 - accuracy: 0.8583 - val_loss: 1.0450 - val_accuracy: 0.0000e+00
# Epoch 450/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.4946 - accuracy: 0.8500 - val_loss: 1.0448 - val_accuracy: 0.0000e+00
# Epoch 451/500
# 120/120 [==============================] - 0s 205us/sample - loss: 0.5774 - accuracy: 0.8167 - val_loss: 1.0421 - val_accuracy: 0.0000e+00
# Epoch 452/500
# 120/120 [==============================] - 0s 238us/sample - loss: 0.5700 - accuracy: 0.7750 - val_loss: 1.0414 - val_accuracy: 0.0000e+00
# Epoch 453/500
# 120/120 [==============================] - 0s 226us/sample - loss: 0.5221 - accuracy: 0.8417 - val_loss: 1.0377 - val_accuracy: 0.0000e+00
# Epoch 454/500
# 120/120 [==============================] - 0s 237us/sample - loss: 0.5270 - accuracy: 0.8250 - val_loss: 1.0381 - val_accuracy: 0.0000e+00
# Epoch 455/500
# 120/120 [==============================] - 0s 241us/sample - loss: 0.5055 - accuracy: 0.8500 - val_loss: 1.0378 - val_accuracy: 0.0000e+00
# Epoch 456/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5514 - accuracy: 0.8500 - val_loss: 1.0405 - val_accuracy: 0.0000e+00
# Epoch 457/500
# 120/120 [==============================] - 0s 208us/sample - loss: 0.5087 - accuracy: 0.8500 - val_loss: 1.0418 - val_accuracy: 0.0000e+00
# Epoch 458/500
# 120/120 [==============================] - 0s 234us/sample - loss: 0.5805 - accuracy: 0.8250 - val_loss: 1.0438 - val_accuracy: 0.0000e+00
# Epoch 459/500
# 120/120 [==============================] - 0s 199us/sample - loss: 0.4947 - accuracy: 0.8667 - val_loss: 1.0394 - val_accuracy: 0.0000e+00
# Epoch 460/500
# 120/120 [==============================] - 0s 288us/sample - loss: 0.5924 - accuracy: 0.7833 - val_loss: 1.0392 - val_accuracy: 0.0000e+00
# Epoch 461/500
# 120/120 [==============================] - 0s 239us/sample - loss: 0.4598 - accuracy: 0.8833 - val_loss: 1.0415 - val_accuracy: 0.0000e+00
# Epoch 462/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5358 - accuracy: 0.8417 - val_loss: 1.0439 - val_accuracy: 0.0000e+00
# Epoch 463/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.5097 - accuracy: 0.8667 - val_loss: 1.0421 - val_accuracy: 0.0000e+00
# Epoch 464/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.4961 - accuracy: 0.8500 - val_loss: 1.0401 - val_accuracy: 0.0000e+00
# Epoch 465/500
# 120/120 [==============================] - 0s 221us/sample - loss: 0.6032 - accuracy: 0.8250 - val_loss: 1.0403 - val_accuracy: 0.0000e+00
# Epoch 466/500
# 120/120 [==============================] - 0s 218us/sample - loss: 0.4870 - accuracy: 0.8417 - val_loss: 1.0422 - val_accuracy: 0.0000e+00
# Epoch 467/500
# 120/120 [==============================] - 0s 205us/sample - loss: 0.5270 - accuracy: 0.8333 - val_loss: 1.0439 - val_accuracy: 0.0000e+00
# Epoch 468/500
# 120/120 [==============================] - 0s 236us/sample - loss: 0.6075 - accuracy: 0.8083 - val_loss: 1.0408 - val_accuracy: 0.0000e+00
# Epoch 469/500
# 120/120 [==============================] - 0s 296us/sample - loss: 0.4899 - accuracy: 0.8750 - val_loss: 1.0405 - val_accuracy: 0.0000e+00
# Epoch 470/500
# 120/120 [==============================] - 0s 253us/sample - loss: 0.5074 - accuracy: 0.8417 - val_loss: 1.0382 - val_accuracy: 0.0000e+00
# Epoch 471/500
# 120/120 [==============================] - 0s 223us/sample - loss: 0.4923 - accuracy: 0.8667 - val_loss: 1.0358 - val_accuracy: 0.0000e+00
# Epoch 472/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.5171 - accuracy: 0.8417 - val_loss: 1.0310 - val_accuracy: 0.0000e+00
# Epoch 473/500
# 120/120 [==============================] - 0s 206us/sample - loss: 0.4882 - accuracy: 0.8500 - val_loss: 1.0336 - val_accuracy: 0.0000e+00
# Epoch 474/500
# 120/120 [==============================] - 0s 297us/sample - loss: 0.5337 - accuracy: 0.8417 - val_loss: 1.0350 - val_accuracy: 0.0000e+00
# Epoch 475/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.5358 - accuracy: 0.8167 - val_loss: 1.0368 - val_accuracy: 0.0000e+00
# Epoch 476/500
# 120/120 [==============================] - 0s 205us/sample - loss: 0.4521 - accuracy: 0.8833 - val_loss: 1.0338 - val_accuracy: 0.0000e+00
# Epoch 477/500
# 120/120 [==============================] - 0s 287us/sample - loss: 0.5280 - accuracy: 0.8417 - val_loss: 1.0336 - val_accuracy: 0.0000e+00
# Epoch 478/500
# 120/120 [==============================] - 0s 209us/sample - loss: 0.4828 - accuracy: 0.8500 - val_loss: 1.0285 - val_accuracy: 0.0000e+00
# Epoch 479/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.5048 - accuracy: 0.8333 - val_loss: 1.0225 - val_accuracy: 0.0000e+00
# Epoch 480/500
# 120/120 [==============================] - 0s 217us/sample - loss: 0.4896 - accuracy: 0.8750 - val_loss: 1.0161 - val_accuracy: 0.0000e+00
# Epoch 481/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.4820 - accuracy: 0.8667 - val_loss: 1.0117 - val_accuracy: 0.0000e+00
# Epoch 482/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.5218 - accuracy: 0.8500 - val_loss: 1.0030 - val_accuracy: 0.0000e+00
# Epoch 483/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.5212 - accuracy: 0.8333 - val_loss: 0.9985 - val_accuracy: 0.0000e+00
# Epoch 484/500
# 120/120 [==============================] - 0s 235us/sample - loss: 0.5228 - accuracy: 0.8500 - val_loss: 0.9970 - val_accuracy: 0.0000e+00
# Epoch 485/500
# 120/120 [==============================] - 0s 252us/sample - loss: 0.4866 - accuracy: 0.8667 - val_loss: 0.9951 - val_accuracy: 0.0000e+00
# Epoch 486/500
# 120/120 [==============================] - 0s 268us/sample - loss: 0.4763 - accuracy: 0.8500 - val_loss: 0.9997 - val_accuracy: 0.0000e+00
# Epoch 487/500
# 120/120 [==============================] - 0s 242us/sample - loss: 0.5133 - accuracy: 0.8583 - val_loss: 1.0046 - val_accuracy: 0.0000e+00
# Epoch 488/500
# 120/120 [==============================] - 0s 204us/sample - loss: 0.4858 - accuracy: 0.8667 - val_loss: 1.0064 - val_accuracy: 0.0000e+00
# Epoch 489/500
# 120/120 [==============================] - 0s 223us/sample - loss: 0.4631 - accuracy: 0.8750 - val_loss: 1.0056 - val_accuracy: 0.0000e+00
# Epoch 490/500
# 120/120 [==============================] - 0s 210us/sample - loss: 0.5051 - accuracy: 0.8500 - val_loss: 1.0001 - val_accuracy: 0.0000e+00
# Epoch 491/500
# 120/120 [==============================] - 0s 230us/sample - loss: 0.5331 - accuracy: 0.8333 - val_loss: 0.9984 - val_accuracy: 0.0000e+00
# Epoch 492/500
# 120/120 [==============================] - 0s 219us/sample - loss: 0.5088 - accuracy: 0.8750 - val_loss: 0.9957 - val_accuracy: 0.0000e+00
# Epoch 493/500
# 120/120 [==============================] - 0s 213us/sample - loss: 0.5164 - accuracy: 0.8167 - val_loss: 1.0027 - val_accuracy: 0.0000e+00
# Epoch 494/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.5027 - accuracy: 0.8750 - val_loss: 1.0086 - val_accuracy: 0.0000e+00
# Epoch 495/500
# 120/120 [==============================] - 0s 211us/sample - loss: 0.5505 - accuracy: 0.8417 - val_loss: 1.0122 - val_accuracy: 0.0000e+00
# Epoch 496/500
# 120/120 [==============================] - 0s 227us/sample - loss: 0.4787 - accuracy: 0.8750 - val_loss: 1.0124 - val_accuracy: 0.0000e+00
# Epoch 497/500
# 120/120 [==============================] - 0s 250us/sample - loss: 0.4755 - accuracy: 0.8833 - val_loss: 1.0077 - val_accuracy: 0.0000e+00
# Epoch 498/500
# 120/120 [==============================] - 0s 240us/sample - loss: 0.5374 - accuracy: 0.8667 - val_loss: 1.0087 - val_accuracy: 0.0000e+00
# Epoch 499/500
# 120/120 [==============================] - 0s 225us/sample - loss: 0.5956 - accuracy: 0.7833 - val_loss: 1.0094 - val_accuracy: 0.0000e+00
# Epoch 500/500
# 120/120 [==============================] - 0s 207us/sample - loss: 0.4635 - accuracy: 0.8667 - val_loss: 1.0106 - val_accuracy: 0.0000e+00

# %%
pd.DataFrame(history.history).plot(figsize=(10,10))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()
